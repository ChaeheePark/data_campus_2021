# %% [markdown]
# ### 라이브러리 import

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 크롤링 URL 주소

# %%
base_url = 'https://kr.investing.com'
uri = '/analysis/cryptocurrency'
url = base_url + uri
url
# Out:
# 'https://kr.investing.com/analysis/cryptocurrency'

# %% [markdown]
# ### 세션 연결

# %%
session = requests.session()
session

# %% [markdown]
# ### 응답 받기

# %%
response = session.get(url)
response
# Out:
# <Response [403]>

# %% [markdown]
# ### 세션 헤더 설정

# %%
session.headers['User-Agent']= 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'

# %% [markdown]
# ### 다시 응답받기

# %%
response = session.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### html을 텍스트로 parsing

# %%
html = response.text

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
#  <!DOCTYPE HTML>
#
# <html class="kr" dir="ltr" geo="KR" lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <script type="text/javascript">
#     function OptanonWrapper() { }
#
#     // temp for checks
#     </script>
# <style>
# 	.ot-floating-button {
# 		z-index:12 !important;
# 	}
# </style>
# <script src="https://i-invdn-com.investing.com/js/jquery-6.4.9.04.min.js"></script>
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     </script>
# <script type="text/javascript">
#         window.helpers = {
#             'getCookie': function (k){var v="; "+document.cookie;var p=v.split("; "+k+"=");if(p.length===2)return p.pop().split(";").shift();else return null},
#             'setCookie': function (k,v,d){var e='';if(typeof d!=='undefined'){var n=new Date;n.setTime(n.getTime()+864e5*d);e+=';expires="';e+=n.toGMTString();e+='"';}document.cookie=k+'='+v+';path=/' + e},
#             'delCookie': function (k){document.cookie=k+'=;path=/;expires=-1'},
#             'isNumber': function (n){return !isNaN(n)&&typeof n!==undefined&&n!==null&&n!==''},
#             'removeClass': function (e,c){if(document.documentElement.classList){e.classList.remove(c);}else{var r=new RegExp('(^|\\s)'+c+'(\\s|$)', 'g');e.className=e.className.replace(r, c)}},
#             'addClass': function (e,c){if(document.documentElement.classList){e.classList.add(c);}else{if(e.className.indexOf(c)<0){if((e.className!==''&&e.className.charAt[e.className.length-1]===' ')||e.className===''){e.className+=c}else{e.className+=' '+c}}}},
#             'hasClass': function (e,c){if(document.documentElement.classList){e.classList.contains(c);}else{return e.className.indexOf(c)>=0}},
#         };
#     </script>
# <script src="https://i-invdn-com.investing.com/js/n/toolset-1.20.min.js"></script>
# <script src="https://i-invdn-com.investing.com/js/protectedMedia.js"></script>
# <script src="https://i-invdn-com.investing.com/js/logger-1.02.min.js"></script>
# <script>
#
# /**
#  * Protected Media Score politics:
#  * 1. fraudScore means: fraud [2 - clean - 100 fraud]
#  * 2. suspScore means: suspicious [2 - clean - 100 suspicious]
#  * 3. se means means: load by search engine or ad crawler (for Google Publishers recommended to not block this
#  * so Google can score your page for quality
#  *
#  * JIRA: ADTECH-625
#  */
# const PM_COOKIE_NAME = "protectedMedia";
# const protectedMediaCookie = getCookie(PM_COOKIE_NAME);
# window.fraud = 0;
# if(protectedMediaCookie === "") { // only hit once per user
# 	PMScore({
# 			callback: function(result) {
# 		if(result.status.indexOf("timeout") !== -1) {
# 			console.log("timeout: " + JSON.stringify(result));
# 		}
# 		else { // success PM call
# 			if(result.status.indexOf("se") !== -1 && result.se !== 0) {
# 				// Load by Search engine or ad crawler (for Google Publishers, recommended to not block this so Google
# 				// can score your page for quality
# 				console.log("google bot / ad crawler detected");
# 				return;
# 			}
# 			// mark the PM score to user (first time)
# 			setCookie(PM_COOKIE_NAME, result.fraudScore ,365, "/");
#
# 			if (result.fraudScore > 70) { // result.suspScore > 70
# 				console.log("fraud: " + JSON.stringify(result));
# 			}
# 			else {
# 				console.log("clean: " + JSON.stringify(result));
# 			}
# 		}
# 	},
# 			mode: "rt",
# 			timeout: 4000,
# 		})
# 	}
# else { // user or bot already tagged by protected media (used for second load only)
# 	if(protectedMediaCookie > 70) {
# 		window.fraud = 1;
# 	}
# }
# </script>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <script>
#     window.isGDPR   = 0;
#     window.isCCPA 	= 0;
#
#     const loadGpt = () => {
# 		let gptScript = document.createElement( 'script' );
# 		gptScript.onload = function () {
# 			console.log('gpt loaded');
# 		};
# 		gptScript.async = true;
# 		gptScript.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js';
# 		document.head.appendChild(gptScript);
#     }
#
#     if( window.isGDPR ){
#         const consentSetInterval = setInterval(() => {
#             if( typeof window.__tcfapi !== 'undefined' )
#             {
#                 clearInterval(consentSetInterval);
#                 window.__tcfapi( 'addEventListener', 2, function( tcData,listenerSuccess )
#                 {
# 					if(listenerSuccess) {
# 						if( tcData && (tcData.eventStatus === 'tcloaded' || tcData.eventStatus === 'useractioncomplete') ) {
# 							var hasDeviceStorageAndAccessConsent = tcData.purpose.consents[1] || false;
# 							// Google Requires Consent for Purpose 1
# 							if (hasDeviceStorageAndAccessConsent) {
# 								// GLOBAL VENDOR LIST - https://iabeurope.eu/vendor-list-tcf-v2-0/
# 								// CHECK FOR GOOGLE ADVERTISING PRODUCTS CONSENT. (IAB Vendor ID 755)
# 								var hasGoogleAdvertisingProductsConsent = tcData.vendor.consents[755] || false;
# 								// Check if the user gave Google Advertising Products consent (iab vendor 755)
# 								if(hasGoogleAdvertisingProductsConsent) {
# 									console.log("gpt loaded gdpr-ccpa")
# 									loadGpt();
# 								}
# 							}
# 						}
# 					}
#                 })
#             }
#
#         }, 50);
#
#     } else {
#         loadGpt();
#     }
#
#
#     var allKeyValue = {"Section":"content","Sub_Section":"","Charts_Page":"no","Page_URL":"\/analysis\/cryptocurrency","Domain":"kr.investing.com","smd":"5e34977c07741b1476f9dba528e595b8-1625922001","protected_media":"0","udid":"5e34977c07741b1476f9dba528e595b8","edition_id":"18","Traffic_Type":"OG","User_type":"Not_Logged_in","prebid_page":"0"};
#     var googletagGA = window.helpers.getCookie('_ga');
#
#     if (googletagGA) {
#         allKeyValue.CID = googletagGA.substr(6);
#     }
#
#     // todo: change the screen width logic and move it from here to separate task
#     var screenWidthForAds= screen.width || 1366,
#         screenWidthValue,
#         adBreakPoints = [1336,1440,1920];
#
#     if (screenWidthForAds < adBreakPoints[0]){ screenWidthValue = 'small' }
#     else if (screenWidthForAds >= adBreakPoints[0] && screenWidthForAds <= adBreakPoints[1]) {
#         screenWidthValue = 'medium'
#     }
#     else if (screenWidthForAds > adBreakPoints[1]) {
#         screenWidthValue = 'big'
#     }
#
#     allKeyValue.screen_width = screenWidthValue;
# </script>
# <script type="text/javascript">
#         window.googletag = window.googletag || {};
#         window.googletag.cmd = window.googletag.cmd || [];
#
#         window.loadSideBlockAd3 = function () {
#             googletag.cmd.push(function () {
#                 _.defineSlot({"platform":"desktop","sizes":[[300,250],[300,600]],"adSlotDivID":"div-gpt-ad-1370187203350-sb3","adUnitDivAttributes":{"advertisementText":"\uad11\uace0"},"print":true,"preBid":false,"excludedSections":["ccpa"],"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Sideblock_3_viewable"});
#                 googletag.display('div-gpt-ad-1370187203350-sb3');
#
# 				                _addAdvertisementText('div-gpt-ad-1370187203350-sb3', '광고');
# 				            });
#
#             scrollng_ad('scrollingRightBox', 'footerWrapper');
#         };
#
#         window.a892ffe2982c = {
# 			defineSlots: function () {
#
# 				_.attachEvents();
# 				_.each( allKeyValue, function (val, key) { _.setTargeting(key, val) });
# 				_.each({"Billboard_Default":{"platform":"desktop","sizes":[[970,250],[970,90],[728,90]],"adSlotDivID":"div-gpt-ad-1441189641022-6","print":true,"preBid":true,"adUnitDivAttributes":{"advertisementText":"\uad11\uace0","resize":"1","style":"height:276px;"},"collapseDiv":[true],"excludedSections":["ccpa","webinars"],"overrideRules":[{"conditions":{"relevantSections":["FX","indices","equities","etfs","Commodities","funds","ratesbonds","Crypto","certificates"]},"rewrite":{"adUnitDivAttributes":{"closeButton":"1","advertisementText":"\uad11\uace0","resize":"1"}}}],"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Billboard_Default"},"Sideblock_1_Default":{"platform":"desktop","sizes":[300,600],"adSlotDivID":"div-gpt-ad-1370187203350-sb1","excludedSections":["Education","portfolio","brokers","directory"],"adUnitDivAttributes":{"style":"margin-top:18px;","advertisementText":"\uad11\uace0"},"print":true,"preBid":true,"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Sideblock_1_Default"},"Sideblock_2_Default":{"platform":"desktop","sizes":[300,250],"adSlotDivID":"div-gpt-ad-1370187203350-sb2","excludedSections":["Education","portfolio","brokers","directory"],"adUnitDivAttributes":{"advertisementText":"\uad11\uace0"},"print":true,"preBid":true,"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Sideblock_2_Default"},"TNB_Right_Rail_1":{"platform":"desktop","sizes":["fluid"],"adSlotDivID":"div-gpt-ad-1587967538923-0","collapseDiv":[true,true],"adUnitDivAttributes":{"style":"width:300px;height:85px;"},"print":true,"preBid":false,"excludedSections":["ccpa","webinars"],"overrideRules":[{"conditions":{"relevantSites":[1]},"rewrite":{"excludedSections":["ccpa","webinars","Homepage"]}}],"defineSlot":"\/6938\/FP_KR_site\/FP_KR_TNB_Right_Rail_1"},"Not_Out_of_page_video_Content_Float_No_SF":{"platform":"desktop","sizes":[[300,169],[1,1]],"adSlotDivID":"div-gpt-ad-1531124357521-0","collapseDiv":[true],"excludedSites":[6],"excludedSections":["Homepage","Education","portfolio","brokers","webinars","majorIndices","indicesFuture"],"adUnitDivAttributes":{"style":"width:300px;height:180px;"},"overrideRules":[{"conditions":{"relevantSites":[70,62,72,2,37,13,4,10,49,8,32,53,5,9,7,50,52,30,51,68]},"rewrite":{"excludedSections":["Homepage","Education","portfolio","brokers","webinars"]}},{"conditions":{"relevantSites":[1,18]},"rewrite":{"excludedSections":["Homepage","Education","portfolio","brokers","webinars","majorIndices","indicesFuture"]}}],"print":true,"preBid":false,"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Not_Out_of_page_video_Content_Float_No_SF"}}, _.defineSlot);
# 			},
#             isPrebid: false
# 		}
#
#         window.googletag.cmd.push(function () {
#
#                 window.a892ffe2982c.defineSlots();
#             //if is not gdpr compliant - get personal ads
#             if (!window.isGDPR || (window.isGDPR && getCookie('CMP_CONSENT') === '1')) {
#                 window.googletag.pubads().setRequestNonPersonalizedAds(0);
#             }
#
#             // ADX ccpa (optout - 1YYN) restricted data processing
#             if( window.isCCPA && getCookie('usprivacy') === '1YYN')
#             {
#                 console.log('CCPA privacy restrict data processing');
#                 window.googletag.pubads().setPrivacySettings({
#                     'restrictDataProcessing': true
#                 });
#             }
#             window.googletag.pubads().enableSingleRequest();
#             window.googletag.enableServices();
#         })
#
#         function _addAdvertisementText(elementKey, text) {
#             let dfpElement = document.getElementById(elementKey);
#             if (dfpElement) {
#                 let advertisementDiv = _.createAdvertisementPrefix(text);
#                 dfpElement.parentElement.prepend(advertisementDiv);
#             }
#         }
#     </script>
# <link href="https://i-invdn-com.investing.com" rel="dns-prefetch">
# <link href="https://a-invdn-com.investing.com" rel="dns-prefetch"/>
# <title>암호화폐 분석과 예측 - Investing.com</title>
# <link href="https://kr.investing.com/rss/302.rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="https://kr.investing.com/analysis/cryptocurrency" rel="canonical"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@Investing_Korea" name="twitter:site"/>
# <meta content="암호화폐 분석과 예측 - Investing.com" name="twitter:title"/>
# <meta content="비트코인, 이더리움, 라이트코인, 리플, ICO를 포함한 주요 암호화폐에 대한 심층적인 최신 암호화폐 시장 분석과 의견을 확인하세오." name="twitter:description"/>
# <meta content="https://i-invdn-com.investing.com/redesign/images/seo/investing_300X300.png" name="twitter:image"/>
# <meta content="암호화폐 분석과 예측 - Investing.com" property="og:title"/>
# <meta content="비트코인, 이더리움, 라이트코인, 리플, ICO를 포함한 주요 암호화폐에 대한 심층적인 최신 암호화폐 시장 분석과 의견을 확인하세오." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://kr.investing.com/analysis/cryptocurrency" property="og:url"/>
# <meta content="https://i-invdn-com.investing.com/redesign/images/seo/investing_300X300.png" property="og:image"/>
# <meta content="Investing.com 한국어" property="og:site_name"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://i-invdn-com.investing.com/logos/favicon.ico" rel="shortcut icon"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="ko-kr" http-equiv="content-language"/>
# <link href="https://m.kr.investing.com/analysis/cryptocurrency" media="only screen and (max-width: 640px)" rel="alternate"/> <meta content="비트코인, 이더리움, 라이트코인, 리플, ICO를 포함한 주요 암호화폐에 대한 심층적인 최신 암호화폐 시장 분석과 의견을 확인하세오." name="description"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="867e13c8aeefe44c96c098634fb27ffe" name="baidu_ssp_verify"/> <link href="https://kr.investing.com/analysis/cryptocurrency/2" rel="next"/>
# <meta content="DTRxWXB3vjNUsTCPICWo9yzZmIllylXYkRevEXo7szg" name="google-site-verification"/>
# <link href="https://i-invdn-com.investing.com/css/mainOldMin_v3b.css" rel="stylesheet" type="text/css"/>
# <link href="https://i-invdn-com.investing.com/css/newMainCssMin_v76y.css" rel="stylesheet" type="text/css"/>
# <link href="https://i-invdn-com.investing.com/css/printContent_v10.css" media="print" rel="stylesheet" type="text/css">
# <script type="text/javascript">
#         var domainId = "18";
#         window.CDN_URL = "https://i-invdn-com.investing.com";
#     </script>
# <script>
#             (function() {
#                 var po = document.createElement('script');
#                 po.type = 'text/javascript';
#                 po.async = true;
#                 po.defer = true;
#                 po.src = 'https://apis.google.com/js/platform.js?onload=loadAfterGApiReady';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(po, s);
#             })();
#
#             function loadAfterGApiReady() {
#                 gapi.load('auth2', function () {
#                     auth2 = gapi.auth2.init({
#                         'client_id' : '606447380154-9825jtap5as2sm0f868m536j6v8ptgo7.apps.googleusercontent.com',
#                         'cookiepolicy' : 'single_host_origin',
#                         'requestvisibleactions' : 'http://schemas.google.com/AddActivity',
#                         'apppackagename' : 'com.fusionmedia.investing',
#                         'scope' : 'email'
#                     });
#
#                     if (window.isSignupPage) {
#                         window.btnEventList.push('customBtn2');
#                     }
#                     window.renderButtons && window.renderButtons();
#                 });
#             }
#
#         </script>
# <script src="https://i-invdn-com.investing.com/js/n/notifications-1.02.min.js" type="text/javascript"></script>
# <script async="" src="https://i-invdn-com.investing.com/js/lazysizes.min.js" type="text/javascript"></script>
# <script src="https://i-invdn-com.investing.com/js/n/utils-0.16.min.js" type="text/javascript"></script>
# <script src="https://i-invdn-com.investing.com/js/main-1.17.279.min.js" type="text/javascript"></script>
# <script src="https://i-invdn-com.investing.com/js/ArticleFilters-1.5.04.min.js" type="text/javascript"></script>
# <!--[if (gte IE 6)&(lte IE 7)]>
# <script src="https://i-invdn-com.investing.com/js/jquery.pseudo-1.1.min.js"></script>
# <![endif]-->
# <script type="text/javascript">
#         window.login_url = '/members-admin/login';
# 		        window.close_word = '닫기';
#         window.lightbox_image = '이미지';
#         window.lightbox_from = '어떤 통화를';
# 		        var FP = {
#             global  : {
#                 _defaultDomain  : 'kr.investing.com',
#                 _textAlign      : 'left'
#             }
#         };
#         var userType;
#         var userSupportedType ;
#     </script>
# <script type="text/javascript">
#         /* Modernizr 2.0.6 (Custom Build) | MIT & BSD
# 		 * Build: http://www.modernizr.com/download/#-csstransitions-iepp-cssclasses-testprop-testallprops-domprefixes
# 		 */
#         window.Modernizr=function(a,b,c){function A(a,b){var c=a.charAt(0).toUpperCase()+a.substr(1),d=(a+" "+n.join(c+" ")+c).split(" ");return z(d,b)}function z(a,b){for(var d in a)if(k[a[d]]!==c)return b=="pfx"?a[d]:!0;return!1}function y(a,b){return!!~(""+a).indexOf(b)}function x(a,b){return typeof a===b}function w(a,b){return v(prefixes.join(a+";")+(b||""))}function v(a){k.cssText=a}var d="2.0.6",e={},f=!0,g=b.documentElement,h=b.head||b.getElementsByTagName("head")[0],i="modernizr",j=b.createElement(i),k=j.style,l,m=Object.prototype.toString,n="Webkit Moz O ms Khtml".split(" "),o={},p={},q={},r=[],s,t={}.hasOwnProperty,u;!x(t,c)&&!x(t.call,c)?u=function(a,b){return t.call(a,b)}:u=function(a,b){return b in a&&x(a.constructor.prototype[b],c)},o.csstransitions=function(){return A("transitionProperty")};for(var B in o)u(o,B)&&(s=B.toLowerCase(),e[s]=o[B](),r.push((e[s]?"":"no-")+s));v(""),j=l=null,a.attachEvent&&function(){var a=b.createElement("div");a.innerHTML="<elem></elem>";return a.childNodes.length!==1}()&&function(a,b){function s(a){var b=-1;while(++b<g)a.createElement(f[b])}a.iepp=a.iepp||{};var d=a.iepp,e=d.html5elements||"abbr|article|aside|audio|canvas|datalist|details|figcaption|figure|footer|header|hgroup|mark|meter|nav|output|progress|section|summary|time|video",f=e.split("|"),g=f.length,h=new RegExp("(^|\\s)("+e+")","gi"),i=new RegExp("<(/*)("+e+")","gi"),j=/^\s*[\{\}]\s*$/,k=new RegExp("(^|[^\\n]*?\\s)("+e+")([^\\n]*)({[\\n\\w\\W]*?})","gi"),l=b.createDocumentFragment(),m=b.documentElement,n=m.firstChild,o=b.createElement("body"),p=b.createElement("style"),q=/print|all/,r;d.getCSS=function(a,b){if(a+""===c)return"";var e=-1,f=a.length,g,h=[];while(++e<f){g=a[e];if(g.disabled)continue;b=g.media||b,q.test(b)&&h.push(d.getCSS(g.imports,b),g.cssText),b="all"}return h.join("")},d.parseCSS=function(a){var b=[],c;while((c=k.exec(a))!=null)b.push(((j.exec(c[1])?"\n":c[1])+c[2]+c[3]).replace(h,"$1.iepp_$2")+c[4]);return b.join("\n")},d.writeHTML=function(){var a=-1;r=r||b.body;while(++a<g){var c=b.getElementsByTagName(f[a]),d=c.length,e=-1;while(++e<d)c[e].className.indexOf("iepp_")<0&&(c[e].className+=" iepp_"+f[a])}l.appendChild(r),m.appendChild(o),o.className=r.className,o.id=r.id,o.innerHTML=r.innerHTML.replace(i,"<$1font")},d._beforePrint=function(){p.styleSheet.cssText=d.parseCSS(d.getCSS(b.styleSheets,"all")),d.writeHTML()},d.restoreHTML=function(){o.innerHTML="",m.removeChild(o),m.appendChild(r)},d._afterPrint=function(){d.restoreHTML(),p.styleSheet.cssText=""},s(b),s(l);d.disablePP||(n.insertBefore(p,n.firstChild),p.media="print",p.className="iepp-printshim",a.attachEvent("onbeforeprint",d._beforePrint),a.attachEvent("onafterprint",d._afterPrint))}(a,b),e._version=d,e._domPrefixes=n,e.testProp=function(a){return z([a])},e.testAllProps=A,g.className=g.className.replace(/\bno-js\b/,"")+(f?" js "+r.join(" "):"");return e}(this,this.document);
#         window.ie = (function(){var undef,v = 3,div = document.createElement('div'),all = div.getElementsByTagName('i');while (div.innerHTML = '<!--[if gt IE ' + (++v) + ']><i></i><![endif]-->',all[0]);return v > 4 ? v : undef;}());
#     </script>
# <style>
#         .googleContentRec {display:inline-block;width:650px;height:300px;}
#
#     </style>
# <style>
#         /* INPUTS OVERWRITES */
#         .combineSearchBox {border:1px solid #737373;} /* overwrite main css */
#         .combineSearchBox.newInput.inputTextBox, .portfolioSearch .newInput.inputTextBox  {padding:0;}
#     </style>
# <!--[if (IE 8)|(IE 9)]>
# <link rel="stylesheet" type="text/css" href="https://i-invdn-com.investing.com/css/ie8-9main_v2b.css">
# <![endif]-->
# <!--[if IE 8]>
# <link rel="stylesheet" type="text/css" href="https://i-invdn-com.investing.com/css/ie8main_v2a.css">
# <![endif]-->
# <!--[if IE 7]>
# <link rel="stylesheet" type="text/css" href="https://i-invdn-com.investing.com/css/ie7main_v1i.css">
# <![endif]-->
# <style>
#         .MainTableDirectory .HeadTitlesRow TH {text-align:center; font-weight:bold;}
#     </style>
# <style>
#         .openTbl TH.icon {text-align:center;}         .openTbl TH.icon SPAN {position:relative; top:2px;}
#     </style>
# <script>
#         var oldIE = false, explorerEight = false ,explorerNine = false, sponsoredArticle;
#     </script>
# <!--[if lte IE 7]>
# 	<script>
# 		oldIE = true;
# 	</script>
# 	<![endif]-->
# <!--[if (IE 8)]>
# 	<script>
# 		explorerEight = true;
# 	</script>
# 	<![endif]-->
# <!--[if (IE 9)]>
# 	<script>
# 		explorerNine = true;
# 	</script>
# 	<![endif]-->
# <script>var c1507bafdb5373e65539f1ec9bf03bb="3d208e78efcf75160e652f849d87888b";</script>
# <script data-obct="" type="text/javascript">
#     /** DO NOT MODIFY THIS CODE**/
#     !function(_window, _document) {
#         var OB_ADV_ID='00d807ecaf50797b1d395f73b69546fffe';
#         if (_window.obApi) {var toArray = function(object) {return Object.prototype.toString.call(object) === '[object Array]' ? object : [object];};_window.obApi.marketerId = toArray(_window.obApi.marketerId).concat(toArray(OB_ADV_ID));return;}
#         var api = _window.obApi = function() {api.dispatch ? api.dispatch.apply(api, arguments) : api.queue.push(arguments);};api.version = '1.1';api.loaded = true;api.marketerId = OB_ADV_ID;api.queue = [];var tag = _document.createElement('script');tag.async = true;tag.src = '//amplify.outbrain.com/cp/obtp.js';tag.type = 'text/javascript';var script = _document.getElementsByTagName('script')[0];script.parentNode.insertBefore(tag, script);}(window, document);
#     obApi('track', 'PAGE_VIEW');
# </script><script></script>
# <script type="text/javascript">
#         window.pubsubDebugData = {
#             dfp:{
#                 iframes:[],
#                 scripts:[]
#             },
#             code:{
#                 scripts:[]
#             }
#         };
#
#         function sendPrimisEventToPubSub(params)
#         {
#             $.ajax({
#                 url: "/pubsub/Service/message",
#                 type:'POST',
#                 data: params
#             });
#         }
#
#         function getSekindoParamsFromDFPScript()
#         {
#             var sekindoParams = {};
#             var iframes = $('body').find('iframe');
#             for (var i = 0; i < iframes.length; i++) {
#                 window.pubsubDebugData.dfp.iframes[i] = iframes[i].id;
#                 if(iframes[i].id && (iframes[i].id.indexOf('_video_') !== -1)){
#                     var scripts = iframes[i].contentWindow.document.getElementsByTagName("script");
#                     for (var q = 0; q < scripts.length; q++) {
#                         window.pubsubDebugData.dfp.scripts[i] = scripts[q].src;
#                         if (scripts[q].src && (scripts[q].src.indexOf('https://live.sekindo.com/live/liveView.php') !== -1)) {
#                             var url = new URL(scripts[q].src);
#                             var queryParams = new URLSearchParams(url.search);
#                             if(queryParams.get('s') && queryParams.get('vp_template')){
#                                 sekindoParams.media_placement_id = queryParams.get('s');
#                                 sekindoParams.vp_template = queryParams.get('vp_template');
#                                 sekindoParams.delivery_system = 'dfp';
#                                 break;
#                             }
#                         }
#                     }
#                 }
#             }
#
#             return sekindoParams;
#         }
#
#         function getSekindoParamsFromCodeScript()
#         {
#             var params = {};
#             var scripts = $('body').find('script');
#             for (var i = 0; i < scripts.length; i++) {
#                 window.pubsubDebugData.code.scripts[i] = scripts[i].src;
#                 if (scripts[i].src && (scripts[i].src.indexOf('https://live.sekindo.com/live/liveView.php') !== -1)) {
#                     var url = new URL(scripts[i].src)
#                     var queryParams = new URLSearchParams(url.search);
#                     if(queryParams.get('s') && queryParams.get('vp_template')){
#                         params.media_placement_id = queryParams.get('s');
#                         params.vp_template = queryParams.get('vp_template');
#                         params.delivery_system = 'code';
#                         break;
#                     }
#                 }
#             }
#
#             return params;
#         }
#
#         window.addEventListener('primisPlayerInit', function (e) {
#             var player = e.detail;
#
#             /**
#              * Ad started event
#              */
#             player.addEventListener('adStarted', function (val){
#                 var sekindoParams = getSekindoParamsFromDFPScript();
#                 if($.isEmptyObject(sekindoParams)){
#                     sekindoParams = getSekindoParamsFromCodeScript();
#                 }
#
#                 cb_params = {};
#                 cb_params.impValue = val.impValue;
#                 cb_params.servingFee = val.servingFee;
#                 sekindoParams.cb_params = cb_params;
#                 sekindoParams.event_type = 'adStarted';
#                 sekindoParams.debug = window.pubsubDebugData;
#
#                 sendPrimisEventToPubSub(sekindoParams);
#             });
#
#             /**
#              * Video Start event
#              */
#             player.addEventListener('videoStart', function (val){
#                 console.log('Playing video: ' + val.title);
#             });
#         });
#     </script>
# <script async="" src="/cdn-cgi/bm/cv/669835187/api.js"></script></link></link></head>
# <body class="takeover dfpTakeovers ">
# <div class="sideNotificationZone" id="sideNotificationZone">
# <div class="floatingAlertWrapper alertWrapper js-notification-item displayNone">
# <div class="alertNotifIcon"><span class="js-icon"></span></div>
# <div class="alertNotifData">
# <a class="alertDataTitle js-title"></a>
# <span class="alertDataDetails js-small-text"></span>
# </div>
# <a class="js-manage-alerts gearIconSmall genToolTip oneliner reverseToolTip" data-tooltip="알림 관리"></a>
# <span class="alertCloseIconSmall js-close"></span>
# </div>
# </div>
# <div class="breakingNews">
# <div class="floatingAlertWrapper">
# <span class="breakingNewsTitle bold">긴급 속보</span>
# <span class="breakingNewsText js-breaking-news-content"></span>
# </div>
# <span class="closeIcon js-close"></span>
# </div>
# <div class="generalOverlay js-general-overlay displayNone"></div>
# <script>
#         $('.js-general-overlay').on('click', $.stopProp);
#     </script>
# <div class="earAdv left js-floaty-flyer">
# </div>
# <script>
#             $('.js-floaty-flyer').css('position', $(window).height() <= 909 ? 'absolute' : 'fixed');
#         </script>
# <div class="wrapper">
# <header>
# <div class="topBar">
# <div class="topBarInnerWrapper">
# <a class="topBarLogo" href="/">
# <img alt="Investing.com-선두의 금융 포털" class="investingLogo" src="https://i-invdn-com.investing.com/logos/investing-com-logo.png"/>
# </a>
# <div id="topBarPopup" load="topBarSpinner"></div>
# <div class="js-search-overlay topSearchOverlay displayNone"></div>
# <div class="searchDiv newSearchDiv js-main-search-wrapper">
# <div class="searchBoxContainer topBarSearch topBarInputSelected">
# <input autocomplete="off" class="searchText arial_12 lightgrayFont js-main-search-bar" placeholder="웹사이트 검색" type="text" value=""/>
# <label class="searchGlassIcon js-magnifying-glass-icon"> </label>
# <i class="cssSpinner"></i>
# </div>
# <div class="js-results-dialog displayNone">
# <div class="js-query-results newSearch_topBar newSearch_topBarResults displayNone">
# <div class="searchMain">
# <div class="js-query-quotes-header textBox groupHeader searchPopup_results">
# <a class="js-quote-header-link">시세</a>
# <div class="js-quote-types-dropdown newSearchSelect selectWrap">
# <a class="newBtnDropdown noHover">
# <span class="js-dropdown-text-input inputDropDown">모든 상품 유형</span>
# <i class="bottunImageDoubleArrow buttonWhiteImageDownArrow"></i>
# </a>
# <ul class="dropdownBtnList displayNone js-quote-types-dropdown-ul">
# <li data-value="all">모든 상품 유형</li><li data-value="indice">지수</li><li data-value="equities">주식</li><li data-value="etf">ETFs</li><li data-value="fund">펀드</li><li data-value="commodity">원자재</li><li data-value="currency">통화</li><li data-value="crypto">암호화폐</li><li data-value="bond">채권</li><li data-value="certificate">증서</li> </ul>
# </div>
# </div>
# <div class="js-scrollable-results-wrapper newResultsContainer">
# <div class="js-table-results tableWrapper"></div>
# </div>
# <div class="js-query-no-results noResults displayNone">
# <i class="searchNoResultsNew"></i>
# <p class="lighterGrayFont">다시 검색해주세요</p>
# </div>
# <div class="searchResultsFooter">
# <i class="blueSearchGlassIcon middle"></i>
# <a class="js-footer-link" href="/">~을 위한 웹사이트를 검색하십시오: <span class="js-footer-link-text bold"></span></a>
# </div>
# </div>
# <div class="js-right-side-results searchAside"></div>
# </div>
# <div class="js-default-search-results newSearch_topBar">
# <div class="searchMain js-main-group-results"></div>
# <div class="searchAside">
# <div class="searchAside_item">
# <a class="asideTitle" href="/news/most-popular-news">
# <div class="js-search-ga-header groupHeader" ga-label="Popular News">인기 있는 뉴스</div>
# <span class="js-search-ga-more" ga-label="Popular News - More">더 많은</span>
# </a>
# <div class="js-search-ga-items articles mediumTitle1" ga-label="Popular News - Article"><article class="js-article-item articleItem " data-id="663965">
# <a class="img" href="/news/economy/article-663965"><img alt="카카오 익절한 투자자에…" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEB5S0BB_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';" 단언한="" 돼"="" 쉽게="" 안="" 이유"="" 팔아선=""/></a> <div class="textDiv">
# <a class="title" href="/news/economy/article-663965" title="카카오 익절한 투자자에…" 단언한="" 돼"="" 쉽게="" 안="" 이유"="" 팔아선="">카카오 익절한 투자자에…"쉽게 팔아선 안 돼" 단언한 이유</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="663989">
# <a class="img" href="/news/stock-market-news/article-663989"><img alt="미국 시장은 위로 마감하였습니다. 다우 존스는 1.30% 위로." class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEA6Q02Q_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
# <a class="title" href="/news/stock-market-news/article-663989" title="미국 시장은 위로 마감하였습니다. 다우 존스는 1.30% 위로.">미국 시장은 위로 마감하였습니다. 다우 존스는 1.30% 위로.</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="664037">
# <a class="img" href="/news/economy/article-664037"><img [한경우의="" alt="" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC0Q0MJ_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';" 日="" 넘을="" 도약="" 수="" 스터디]"="" 없다더니"…'k-배터리'로="" 죽어도="" 케이스="" 한수위=""/></a> <div class="textDiv">
# <a [한경우의="" class="title" href="/news/economy/article-664037" title="" 日="" 넘을="" 도약="" 수="" 스터디]"="" 없다더니"…'k-배터리'로="" 죽어도="" 케이스="" 한수위="">"日 죽어도 넘을 수 없다더니"…'K-배터리'로 한수위 도약 [한경우의 케이스 스터디]</a>
# </div>
# <div class="clear"></div>
# </article></div>
# </div>
# <div class="searchAside_item js-popular-analysis-wrapper">
# <a class="asideTitle" href="/analysis/most-popular-analysis">
# <div class="js-search-ga-header groupHeader" ga-label="Popular Analysis">인기 있는 분석</div>
# <span class="js-search-ga-more" ga-label="Popular Analysis - More">더 많은</span>
# </a>
# <div class="js-search-ga-items articles smallTitle1 analysisImg js-popular-analysis-items" ga-label="Popular Analysis - Article"><article class="js-article-item articleItem " data-id="200436762">
# <a class="img" href="/analysis/article-200436762"><img class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/64d1bde737a0a390b098991e222b1deb.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436762" title="코로나 확산 발 증시 조정: 7월 증시 각오했어도 투자심리를 흔드는데.">코로나 확산 발 증시 조정: 7월 증시 각오했어도 투자심리를 흔드는데.</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="200436773">
# <a class="img" href="/analysis/article-200436773"><img class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/64d1bde737a0a390b098991e222b1deb.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436773" title="이틀 연속 증시 급락, 정작 두려운 것은 사람들의 마음">이틀 연속 증시 급락, 정작 두려운 것은 사람들의 마음</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="200436747">
# <a class="img" href="/analysis/article-200436747"><img class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/b7b3772ca3a5b5e670b8d6203582dce1.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436747" title="한국이 선진국 지위 얻고 잃는 것들">한국이 선진국 지위 얻고 잃는 것들</a>
# </div>
# <div class="clear"></div>
# </article></div>
# </div>
# </div>
# </div>
# </div>
# <div class="js-group-template textBox displayNone">
# <div class="js-group-title groupHeader"></div>
# <div class="js-group-results newResultsContainer">
# </div>
# </div>
# <div class="js-news-items-group-template searchAside_item displayNone">
# <a class="asideTitle js-group-more-link">
# <div class="js-group-title groupHeader"></div>
# <span>더 많은</span>
# </a>
# <div class="js-group-results articles smallTitle1 analysisImg"></div>
# </div>
# <a class="row js-quote-row-template js-quote-item displayNone">
# <span class="first flag"><i class="ceFlags middle js-quote-item-flag"></i></span>
# <span class="second js-quote-item-symbol symbolName"></span>
# <span class="third js-quote-item-name"></span>
# <span class="fourth typeExchange js-quote-item-type"></span>
# </a>
# <article class="js-news-item-template articleItem displayNone">
# <a class="js-news-item-link" href="/">
# <img class="js-news-item-img" src="https://d1-invdn-com.investing.com/company_logo/d01b563261bcf223986f7ac222680343.jpg"/>
# <div class="js-news-item-name textDiv"></div>
# </a>
# </article>
# <div class="js-tool-item-template displayNone">
# <a class="js-tool-item-link eventsAndTools">
# <span class="js-tool-item-name"></span>
# </a>
# </div>
# </div>
# <script type="text/javascript">
# 	window.topBarSearchData = {
# 		texts: {
# 			recentSearchText: '나의 최근 검색',
# 			popularSearchText: '인기 검색',
#             newsSearchText: '뉴스',
#             analysisSearchText: '분석',
#             economicEventsSearchText: '경제 이벤트',
#             toolsSearchText: '도구 및 섹션',
# 			authorsSearchText: '저자',
# 			webinarsSearchText: '웹세미나'
# 		},
# 		popularSearches: [{"pairId":"6957","link":"\/equities\/dassault-system","symbol":"DAST","name":"Dassault Systemes SE","flag":"France","type":"\uc8fc\uc2dd - \ud30c\ub9ac","ci":"22"},{"pairId":"13147","link":"\/equities\/enquest","symbol":"ENQ","name":"EnQuest","flag":"UK","type":"\uc8fc\uc2dd - \ub7f0\ub358","ci":"4"},{"pairId":"13887","link":"\/equities\/china-cosco-holdings","symbol":"1919","name":"COSCO SHIPPING Holdings Co Ltd H","flag":"Hong_Kong","type":"\uc8fc\uc2dd - \ud64d\ucf69","ci":"39"},{"pairId":"961882","link":"\/equities\/leopard-resources-nl","symbol":"CIODD","name":"Connected IO Ltd","flag":"Australia","type":"\uc8fc\uc2dd - \uc2dc\ub4dc\ub2c8","ci":"25"},{"pairId":"1056240","link":"\/equities\/nanosphere-health","symbol":"NSHS","name":"Nanosphere Health Sciences Inc","flag":"Canada","type":"\uc8fc\uc2dd - CSE","ci":"6"}]	};
# </script> <div class="topBarTools">
# <span class="topBarUserAvatar js-open-auth-trigger-inside" data-page-type="topBar" id="userAccount">
# <div class="topBarText"><a class="login bold" href="javascript:void(0);" onclick="overlay.overlayLogin();">로그인</a>/<a class="register bold" href="javascript:void(0);" onclick="overlay.overlayRegister(); topBarPopup.trackTopBarGAEvent('Sign Up')">무료 등록</a></div> </span>
# <span class="topBarIconWrap" id="topBarAlertCenterBtn">
# <i class="topBarAlertsIcon"></i><i class="topBarAlertBadge js-badge arial_10 displayNone">0</i></span>
# <div class="newSigninPopup tooltipPopup displayNone js-top-bar-signin-popup bigArrowTopbar js-open-auth-trigger-inside">
# <div class="header js-header">최근 알림</div>
# <div class="content">
# <span class="signinIcon js-icon"></span>
# <div class="signInText js-explain-text">상품, 경제 이벤트 및 팔로우하는 저자의 콘텐츠에 대한 알림을 만들려면 등록하세요.</div>
# <a class="newButton orange" href="javascript:void(0);" id="signUPBtn" onclick="overlay.overlayRegister();">무료 등록</a> <div class="align_center">이미 계정이 있으세요? <a class="bold" href="javascript:overlay.overlayLogin();">로그인</a></div>
# </div>
# </div> <span class="topBarIconWrap" id="portfolioTopBarBtn">
# <i class="topBarPortfolioIcon"></i></span>
# <span class="topBarIconWrap" id="topBarMarketBtn">
# <i class="topBarWorldMarketsIcon"></i></span>
# <div class="langSelect inlineblock">
# <div class="inlineblock pointer" id="langSelect" onmouseout="flagsDropDown.render();" onmouseover="$('#editionContainer').fadeOut('fast'); flagsDropDown.render();"><span class="ceFlags South_Korea middle inlineblock"></span></div>
# <div class="tooltipPopup countrySelPopup bigArrowTopbar noHeader displayNone" id="TopFlagsContainer" onmouseout="flagsDropDown.render();" onmouseover="flagsDropDown.render();">
# <div class="content">
# <ul><li><a href="https://www.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to www.investing.com'); setTimeout('document.location = \'https://www.investing.com\'', 500);return false;"><span class="ceFlags USA"></span>English (USA)</a></li><li><a href="https://br.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to br.investing.com'); setTimeout('document.location = \'https://br.investing.com\'', 500);return false;"><span class="ceFlags Brazil"></span>Português (Brasil)</a></li><li><a href="https://uk.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to uk.investing.com'); setTimeout('document.location = \'https://uk.investing.com\'', 500);return false;"><span class="ceFlags UK"></span>English (UK)</a></li><li><a href="https://ru.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to ru.investing.com'); setTimeout('document.location = \'https://ru.investing.com\'', 500);return false;"><span class="ceFlags Russian_Federation"></span>Русский</a></li><li><a href="https://in.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to in.investing.com'); setTimeout('document.location = \'https://in.investing.com\'', 500);return false;"><span class="ceFlags India"></span>English (India)</a></li><li><a href="https://tr.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to tr.investing.com'); setTimeout('document.location = \'https://tr.investing.com\'', 500);return false;"><span class="ceFlags Turkey"></span>Türkçe</a></li><li><a href="https://ca.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to ca.investing.com'); setTimeout('document.location = \'https://ca.investing.com\'', 500);return false;"><span class="ceFlags Canada"></span>English (Canada)</a></li><li><a href="https://sa.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to sa.investing.com'); setTimeout('document.location = \'https://sa.investing.com\'', 500);return false;"><span class="ceFlags Saudi_Arabia"></span>‏العربية‏</a></li><li><a href="https://au.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to au.investing.com'); setTimeout('document.location = \'https://au.investing.com\'', 500);return false;"><span class="ceFlags Australia"></span>English (Australia)</a></li><li><a href="https://gr.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to gr.investing.com'); setTimeout('document.location = \'https://gr.investing.com\'', 500);return false;"><span class="ceFlags Greece"></span>Ελληνικά</a></li><li><a href="https://za.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to za.investing.com'); setTimeout('document.location = \'https://za.investing.com\'', 500);return false;"><span class="ceFlags South_Africa"></span>English (South Africa)</a></li><li><a href="https://se.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to se.investing.com'); setTimeout('document.location = \'https://se.investing.com\'', 500);return false;"><span class="ceFlags Sweden"></span>Svenska</a></li><li><a href="https://ph.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to ph.investing.com'); setTimeout('document.location = \'https://ph.investing.com\'', 500);return false;"><span class="ceFlags Philippines"></span>English (Philippines)</a></li><li><a href="https://fi.investing.com" onclick="ga('allSitesTrack ...
# </div>
# <div class="topBarTableBox chooseEdition tooltipPopup bigArrowTopbar " id="topAlertBarContainer" style="display:none;">
# <div class="popupInnerWrapper">
# <div class="header"><span><i class="ceFlags South_Korea"></i></span><span class="chooseEditionHeaderText">한국어판 이용가능</span><a class="bugCloseIcon" href="javascript:void(0);" onclick="postponeEdition(14, 'Click on X')"></a> </div>
# <div class="content">
# Investing.com을 <span class="bold">한국어</span> 버전으로 보시겠습니까? </div>
# <div class="topPortfolioFooter">
# <a alt="아니오" class="newBtn LightGray noIcon" href="javascript:void(0);" onclick="postponeEdition(14, 'No Thanks')">아니오</a><a alt="예" class="newBtn LightGray noIcon" href="javascript:void(0);" onclick='setEdition("kr" , "https")'>예</a> </div>
# </div>
# </div>
# <script type="text/javascript">
#     function setEdition(target, d_p) {
#         // set cookie for default edition
#         //document.cookie ="myEdition="+target+"; expires=Fri, 1 Jan 2038 01:23:45 GMT; path=/";
#         if(!d_p) d_p = 'http';
#         var days=90;
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         var expires = "; expires="+date.toGMTString();
#         var currentTime = (new Date).getTime();
#         document.cookie = "editionPostpone="+currentTime+expires+"; path=/";
#
#         ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'System Recommend', 'Redirect to '+target+'.investing.com');
# 		setTimeout('document.location = "'+d_p+'://'+ target +'.investing.com?ref=www"', 500);
# 	}
#
#     function postponeEdition(days, reason) {
#         if (days!=14) days=1;
#         //$('#editionLoading').removeClass("displayNone").addClass("inlineblock");
#         // set cookie for days not to show bar again
#         //change time from 7 days to 14 (2 weeks), Gil Palikaras, JIRA-26314
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         var expires = "; expires="+date.toGMTString();
#         var currentTime = (new Date).getTime();
#         document.cookie = "editionPostpone="+currentTime+expires+"; path=/";
#         closeTopAlert();
#         ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'System Recommend', reason);
#     }
#     function closeTopAlert(){
#         $('#topAlertBarContainer').fadeOut('fast');
#     }
#
#     $(document).ready (function(){
#                 var timer = setInterval(function() {
#             if ($('#mainPopUpBannerDIV').is( ":hidden" )==true) {
#                 clearInterval(timer);
#                 //openTopAlert(2000);
#             }
#         }, 200);
#             });
# </script>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	loader([{
# 		type: 'component', value: 'Translate'
# 	}]).ready(function(Translate) {
# 		Translate
# 			.setDictionary('TopBarAlertsSignInPopup', {
# 				'popupHeader': '최근 알림',
# 				'notLoggedInText': "\uc0c1\ud488, \uacbd\uc81c \uc774\ubca4\ud2b8 \ubc0f \ud314\ub85c\uc6b0\ud558\ub294 \uc800\uc790\uc758 \ucf58\ud150\uce20\uc5d0 \ub300\ud55c \uc54c\ub9bc\uc744 \ub9cc\ub4e4\ub824\uba74 \ub4f1\ub85d\ud558\uc138\uc694.",
# 				'iconClasses': 'signinIcon',
# 				'popupClasses': 'topBarAlertsSignInPopup'
# 			})
# 			.setDictionary('TopBarPortfolioSignInPopup', {
# 				'popupHeader': '포트폴리오',
# 				'notLoggedInText': "investing.com\uc758 \ud3ec\ud2b8\ud3f4\ub9ac\uc624 \ub3c4\uad6c\ub85c \uc790\uc2e0\ub9cc\uc758 \uad00\uc2ec\ubaa9\ub85d\uacfc \ubcf4\uc720\uc885\ubaa9\uc744 \ub9cc\ub4e4\uace0 \uad00\ub9ac\ud558\ub824\uba74 \ub4f1\ub85d\ud558\uc2ed\uc2dc\uc624.",
# 				'iconClasses': 'signinIconPortfolio',
# 				'popupClasses': 'topBarPortfolioBox'
# 			});
# 	})
# </script>
# <div class="navBar" id="navBar">
# <nav class="navMenuWrapper" id="navMenu">
# <ul class="navMenuUL">
# <li>
# <a class="nav" href="/markets/">시장</a>
# <ul class="subMenuNav">
# <li class="row">
# <a href="/currencies/">외환</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/currencies/single-currency-crosses">단일 환율</a></li>
# <li><a href="/currencies/streaming-forex-rates-majors">주요 통화 환율</a></li>
# <li><a href="/currencies/live-currency-cross-rates">실시간 환율 시세</a></li>
# <li><a href="/currencies/exchange-rates-table">환율표</a></li>
# <li><a href="/currencies/us-dollar-index">미국 달러 지수</a></li>
# <li><a href="/currencies/fx-futures">외환선물</a></li>
# <li><a href="/currencies/forex-options">Forex 옵션</a></li> </ul>
# <ul class="popular">
# <li><a href="/currencies/usd-krw">달러/원</a></li>
# <li><a href="/currencies/eur-krw">유로/원</a></li>
# <li><a href="/currencies/jpy-krw">엔/원</a></li>
# <li><a href="/currencies/eur-usd">유로/달러</a></li>
# <li><a href="/currencies/usd-jpy">달러/엔</a></li>
# <li><a href="/currencies/cny-krw">중국 위안/원</a></li>
# <li><a href="/currencies/usd-cny">달러/중국 위안</a></li>
# <li><a href="/crypto/bitcoin/btc-usd">비트코인/달러</a></li>
# </ul>
# </div> </li>
# <li class="row">
# <a href="/commodities/">원자재</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/commodities/real-time-futures">실시간 상품</a></li>
# <li><a href="/commodities/metals">금속</a></li>
# <li><a href="/commodities/softs">농산물</a></li>
# <li><a href="/commodities/meats">육류</a></li>
# <li><a href="/commodities/energy">에너지</a></li>
# <li><a href="/commodities/grains">곡물</a></li>
# <li><a href="/indices/commodities-indices">원자재 지수</a></li> </ul>
# <ul class="popular">
# <li><a href="/commodities/gold">금</a></li>
# <li><a href="/commodities/crude-oil">WTI유</a></li>
# <li><a href="/commodities/silver">은</a></li>
# <li><a href="/commodities/natural-gas">천연가스</a></li>
# <li><a href="/commodities/copper">구리</a></li>
# <li><a href="/commodities/us-wheat">미국 소맥</a></li>
# </ul>
# </div> </li>
# <li class="row">
# <a href="/indices/">지수</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/indices/south-korea-indices">한국 지수</a></li>
# <li><a href="/indices/major-indices">세계 주요 지수</a></li>
# <li><a href="/indices/global-indices">글로벌 지표</a></li>
# <li><a href="/indices/indices-futures">지수 선물</a></li>
# <li><a href="/indices/indices-cfds">지수 CFD</a></li> </ul>
# <ul class="popular">
# <li><a href="/indices/germany-30">DAX</a></li>
# <li><a href="/indices/us-30">다우존스</a></li>
# <li><a href="/indices/us-spx-500">S&amp;P; 500</a></li>
# <li><a href="/indices/nq-100">나스닥 100</a></li>
# <li><a href="/indices/uk-100">영국 FTSE</a></li>
# <li><a href="/indices/korea-200-futures">코스피200 선물 (F)</a></li>
# <li><a href="/indices/japan-ni225">닛케이</a></li>
# <li><a href="/indices/vn">VN</a></li>
# </ul>
# </div> </li>
# <li class="row">
# <a href="/equities/">주식</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/stock-screener/">주식 종목검색기</a></li>
# <li><a href="/equities/trending-stocks">추세주</a></li>
# <li><a href="/equities/south-korea">한국</a></li>
# ...
#
#
#         ga('allSitesTracker.set', 'dimension127', 0);
#     ga('require', 'displayfeatures');
#     ga('allSitesTracker.set', 'dimension73','Web');
#     ga('allSitesTracker.set', 'dimension17', getCookie('_ga').substr(6));
#     ga('allSitesTracker.set', 'dimension1', 0);
# 		ga('allSitesTracker.set', 'dimension49', '5e34977c07741b1476f9dba528e595b8-1625922001');
# 	ga('allSitesTracker.set', 'dimension58', '1');	ga('allSitesTracker.set', 'dimension38', '5e34977c07741b1476f9dba528e595b8');	ga('allSitesTracker.set', 'dimension95', '18');
#
#     	ga('set', 'dimension73','Web');
#
# 	ga('allSitesTracker.set', 'dimension106', 'No');
# 	ga('allSitesTracker.set', 'dimension54', 'No');
#
# 	var myDate = new Date();
# 	ga('allSitesTracker.set', 'dimension81',myDate.getFullYear() + '/' +('0' + (myDate.getMonth()+1)).slice(-2)+ '/' +  ('0' + (myDate.getDate()+1)).slice(-2) + ' '+('0' + (myDate.getHours()+1)).slice(-2)+ ':'+('0' + (myDate.getMinutes())).slice(-2)+ ':'+('0' + (myDate.getSeconds()+1)).slice(-2));
#
#     ga('send', 'pageview');
#     ga('allSitesTracker.set','&uid', 0);
# 	<!-- Crypto Dimension LD -->
# 	    <!--Adblock Check-->
#
# 	jQuery(document).ready(checkAds());
#
# 	function checkAds(){
#
# 		function isIE() {
# 			var ua = window.navigator.userAgent;
# 			var trident = ua.indexOf('Trident/');
# 			var edge = ua.indexOf('Edge/');
# 			var msie = ua.indexOf('MSIE ');
# 			return Math.max(msie,edge,trident)>0;
#
# 		}
#
# 		var isIE = isIE();
# 		var isChrome = /Chrome/.test(navigator.userAgent) && /Google Inc/.test(navigator.vendor) && !isIE;
# 		var isFireFox = /Firefox/.test(navigator.userAgent);
# 		var isSafari = /Safari/.test(navigator.userAgent) && /Apple Computer/.test(navigator.vendor);
# 		var isOneOfThoseBrowsers = [isIE,isChrome,isFireFox,isSafari].indexOf(true)>-1;
#
# 		var b = 2;
#
# 		//var hasAdsenseBlock = !!$('#adsense').length;
# 		//var hasShadowDom = (!!$("html")[0].shadowRoot);
# 		//var headerIsShown = ($(".midHeader").height() > 0 && $(".midHeader").css('display') !== 'none');
#
#
# 		if (window.google_ad_status == 1){
#
#     		var adbBlk = getCookie('adbBLk');
#     		if(isOneOfThoseBrowsers && adbBlk>0){
#         		ga('allSitesTracker.set', 'dimension22', '18_Blk_No');
#         		setCookie('adbBLk',18,-1000);
#     		}
#
#     	}else{
#
#     	    b = 1;
#             $('#TopTextAd').css('display','flex');
#
# 			if(isOneOfThoseBrowsers) {
# 				setCookie('adbBLk',18,1000,'/');
# 				ga('allSitesTracker.set', 'dimension21', '18_Blk_Yes');
#
# 							}
#     	}
#
# 		$.ajax({
# 		    url: "/jp.php?b="+b+"&k=YjRlMmY0ZWxkMWhtYTQ0NGQ8MDg1YWdnZ2Y3ZTNmZz84ajYyZGQ3MT87PWRvZWE9YjdkZjE2NG89OGQ9YTEybmJ9ZSxmaGViZC9oJGFwNGlkYTB2NXVnMGc0N2gzYWc6OG82M2QrNy8_bT1pbzJhaGI0ZGAxYzQwPWhkb2F5MiZiJGVuZnRlfQ==&d=1&i=1625922001&e=3667184710&lip=hk-prod-weblegacy-58d7f44ff7-qshtt&ti=1625922001",
# 		    type: 'get',
# 		    cache: false,
# 		    type: 'GET',
# 		    dataType: 'html',
# 		    success: function (data) {
# 		    	  console.log('server jp b1 hk-prod-weblegacy-58d7f44ff7-qshtt');
# 		    }
# 		});
#
#     }
#
#
# 	ga('allSitesTracker.send', 'pageview');
# 	<!--End Adblock Check-->
#
#
# </script>
# <script>
# //disabled is a temporary argument for testing purposes
# var BoxesEvents = function($,ga,disabled)
# {
# 	var e_stack = []; //each event is pushed to this stack
# 	//this objcet links urls to event types
#     var boxes = {"side_central_banks":"centralbanks","webmaster_tools":"wmt","Most_Popular_News":"mostpop","broker_promotions":"sb_promotions","marketMoversBoxWrapper":"sb_marketmovers","QBS_2_inner":"sb_indices","QBS_3_inner":"sb_commodities","QBS_1_inner":"sb_forex","QBS_4_inner":"sb_bonds","TSB_1_inner":"tsb_fx","TSB_2_inner":"tsb_commodities","TSB_3_inner":"tsb_indices","TSB_4_inner":"tsb_stocks"};
#
#     var resume_click_event = function(ev)
#     {
#     	if (ev['link']==='') {return;}
#         window.location.href = ev['link'];
#     }
#
#
# 	var register_events = function()
# 	{
# 	    for (var id in boxes)
# 	    {
# 		    (function(id){
# 			    var _$b = $('#'+id);
# 			    if (_$b.length < 1) {return;}
#
# 			    //box click event
# 			    _$b.mouseup(function(e){
# 					if (e.button === 2) {return true;} //right mouse button
# 					var middleMouse = e.button === 1;
# 				    if (!middleMouse) {e.preventDefault();}
# 				    var box_event = boxes[id];
# 				    e_stack.push({'event':box_event,'link':''});
# 				    var ce = null; //current event
# 				    //function creator
# 				    var callbackCreate = function(data) {return function() {resume_click_event(data);}}
# 		            var hitCallback = null;
#
# 				    while(ce = e_stack.pop())
# 				    {
# 						if (ce['link'].substr(0,10) === "javascript") {continue;}//if the link is javascript call ignore it
# 						hitCallback = middleMouse ? function(){} : callbackCreate(ce);
# 				    	//if a link with no event do nothing
# 					    if (ce['event'] == '') {hitCallback(); return true;}
#
# 				    					        window.ga('t0.send',{
#                             'hitType': 'event',
#                             'eventCategory': 'side-box-events',
#                             'eventAction': ce['event'],
#                             'eventValue' : 1,
#                             'hitCallback': hitCallback //resume click event
# 				            }
# 				        );
# 				        //fallback if ga doesn't work
# 				        window.setTimeout(hitCallback,1500);
# 				    }
# 				    return middleMouse;
# 			    });
#
# 			    //link event
#                 _$b.on('mouseup','a',function(e){
# 					if (e.button === 2) {return true;} //right mouse button
#                 	e.preventDefault();
# 					var url = this.getAttribute('href');
# 					var event = this.getAttribute('data-gae');
# 					e_stack.push({'event':'','link':url});
# 					if (event)
# 					{
# 						e_stack.pop();
# 						e_stack.push({'event':event,'link':url});
# 					}
# 				  });
#
# 		    })(id);
# 	    }
# 	};
#
#     var init = function()
#     {
#         if (disabled) {return;}
#         if (typeof $ !== 'function') {return;}
#         if (typeof ga !== 'function') {return;}
#         register_events();
#     }();
# }(window.jQuery,window.ga,true);
# </script>
#
# <script type="text/javascript">
# 	if(!window.googletag) {
# 		window.googletag = {cmd: []};
# 	}
# 	googletag.cmd.push(function() {  googletag.pubads().enableSingleRequest();  googletag.enableServices();
# 	            	});        if (sponsoredArticle) {
#         googletag.cmd.push(function() { googletag.display(sponsoredArticle); });
#         }
#         </script><script type="text/javascript">
# 	$(document).ready(function () {
# 	googletag.cmd.push(function() {  googletag.pubads().enableSingleRequest();  googletag.enableServices();
# 	            	});
# 		});</script> <script type="text/javascript">
#             (function () {
#             	let $ad3;
#                 $(window).on('scroll.ad3', $.throttle(function () {
#                     if (typeof(loadFooterBanner) === 'function'){
#                         loadFooterBanner();
#                         loadFooterBanner = function(){}
#                     }
#                     if (!$ad3) {
#                     	$ad3 = $('#ad3');
#                     }
#                     if (window.loadSideBlockAd3 && typeof(googletag.defineSlot) === 'function' && $.isInView($ad3, true, 20)) {
#                         window.loadSideBlockAd3();
#                         window.loadSideBlockAd3 = null;
# 						$(window).off('scroll.ad3');
#                     }
#                 }, 16))
#             })()
#         </script>
# <div class="signupWrap js-gen-popup displayNone" id="PromoteSignUpPopUp"> <div class="left">
# <ul class="textsWrap">
# <li class="title"><span>무료</span>로 등록하시고 다음 혜택을 누리세요.</li>
# <li><i class="regBellIcon"></i> <span>실시간 알림</span></li>
# <li><i class="regPortfolioIcon"></i> <span>고급 포트폴리오 기능</span></li>
# <li><i class="regChartIcon"></i> <span>맞춤형 차트</span></li>
# <li><i class="regSyncIcon"></i> <span>완벽하게 동기화된 앱</span></li>
# </ul>
# <span class="bigGraph"></span>
# </div>
# <div class="right">
# <i class="popupCloseIcon largeBannerCloser"></i>
# <div class="signingPopup">
# <div _button="fb" class="signingBtn facebookBtn">
# <span class="logo"></span>
# <span class="text">페이스북에 가입</span>
# </div>
# <div _button="go" class="signingBtn googleBtn" id="googleAuthBtn">
# <span class="logo"></span>
# <span class="text">구글에 가입</span>
# </div>
# <div class="orSeparator">
# <span>혹은</span>
# </div>
# <a _button="email" class="newBtn newButton orange" href="javascript:void(0);">이메일로 가입</a> </div>
# </div>
# </div>
# <script>
# (function(){
# 	var buttonsToGaLabelMap = {
# 		'fb': 'Continue with Facebook',
#         'go': 'Continue with Google',
#         'email': 'Sign up with Email',
#         'vk': 'Continue with VK'
#     };
#
# 	function showPromoteSignUpPopUp(className) {
# 		var isBrokerPromotionPopupVisible = $('.js-promotion-popup').is(':visible'),
#             isInBrokerPromotionPage = window.siteData.pageType.is(['chart', 'streaming-chart', 'technical']); // According to product we don't want to display this popup on pages where we might show broker promotion
#
# 		if (!(isBrokerPromotionPopupVisible || isInBrokerPromotionPage)) {
# 			setCookie('r_p_s_n', 1, 30);
# 			window.btnEventList.push('googleAuthBtn');
# 			$.getScript('https://i-invdn-com.investing.com/js/google_plus_login-1.32.min.js', function () {
# 			});
# 			if ((function (a) {
# 					if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0, 4))) return true; else return false;
# 				})(navigator.userAgent || navigator.vendor || window.opera)) {//disable for mobile devices
# 				return;
# 			}
#
# 			var $popUp = $('#PromoteSignUpPopUp').addClass(className);
#
# 			$popUp.find('.popupCloseIcon').click(function () {
# 				components.GeneralOverlay.hide();
# 				//ga()
# 			});
#
# 			$popUp.find('[_button]').click(function () {
# 				var button = $(this).attr('_button');
# 				overlay.authCompleteAction = {"type": 'promoteSignUpPopUp'};
# 				sendGaOnSocialButtons(button);
#
# 				switch (button) {
# 					case 'vk':
# 						overlay.vk_login();
# 						break;
# 					case 'fb':
# 						overlay.facebook_login();
# 						break;
# 					case 'email':
# 						components.GeneralOverlay.hide();
# 						overlay.overlayRegister();
# 						registrationFormJs.emailSigningUP();
# 						break;
# 				}
# 			});
#
# 			$('.generalOverlay').addClass('js-promotional');
# 			components.GeneralOverlay.show({
# 				$popup: $popUp, center: true, onHide: function () {
# 					$('.generalOverlay').removeClass('js-promotional');
# 				}
# 			});
#
# 			ga('allSitesTracker.send', 'event', 'Registration Pop Up', 'Pop Up Impression', {
# 				'metric11': 1,
#                 'nonInteraction': true
# 			});
# 		}
# 	}
#
# 	function sendGaOnSocialButtons(button) {
# 		buttonsToGaLabelMap[button] && window.ga && window.ga('allSitesTracker.send', 'event', 'Registration Pop Up', 'Clicks on Registration CTAs', buttonsToGaLabelMap[button]);
# 	}
#
#     $(window).on('mouseleave', function(e) {
#         var $signinPopup = $('.signingPopup'),
#             y = e.pageY - $(document).scrollTop();
#             if ( !$signinPopup.is(':visible')
#                 &&
#                 (((y - 10) < 1 || y >= $(window).height())
#                 ||
#                 (e.pageX < 1 || e.pageX >= $(window).width()))
#             ) {
#                 $(window).off('mouseleave');
#                 showPromoteSignUpPopUp('dark_graph');
#             }
#     });
# })()
# </script>
# <script type="text/javascript">(function(){window['__CF$cv$params']={r:'66c9f8faac4361c4',m:'c3fd34645e4f2675c1b0c6bab803278eebc6a11a-1625922001-1800-ATGQuP1mMKbCI4RLQMcejWwvWhn8wDCeqGm9p9VqQbobyUV6sJ3CIOPR7kGep4It4uLY50q3LODG15lXtn5ze4q/R23SicgyDxPJZq64RtX1Qy5i+YaDASiLBP/wfqWcB9sE34Ngv2BHM7S23XyFtpg=',s:[0x7b4188f2a5,0x776ad96a1c],}})();</script><script data-cf-beacon='{"rayId":"66c9f8faac4361c4","token":"00ab903b5e184b1a9d53b0a7a5085300","version":"2021.6.0","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script>
#
# <img height="1" src="https://secure.adnxs.com/seg?t=2&amp;add=19833489" width="1">
# <script>var TimeZoneID = +"88";window.timezoneOffset = +"32400";window.stream = "https://stream224.forexpros.com:443";</script><script>window.uid = 0</script><script>
#
# 			$(function(){
# 				$(window).trigger("socketRetry",[["pid-37426:","pid-8987:","pid-8839:","pid-8874:","pid-172:","pid-178:","pid-8827:","isOpenExch-60:","isOpenExch-4:","isOpenExch-20:","isOpenPair-8987:","isOpenPair-8839:","isOpenPair-8874:","isOpenPair-8827:","domain-18:"]]);
# 			});
# 			</script><script>function refresher() { void (0);}</script><script>
#     	var _comscore = _comscore || [];
#     	_comscore.push(
#     	{ c1: "2", c2: "16896267" }
#
#     	);
#     	(function()
#     	{ var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); }
#
#     	)();
#     	</script> <script type="text/javascript">
#                 var google_conversion_id = 1000940071;
#                 var google_custom_params = window.google_tag_params;
#                 var google_remarketing_only = true;
#             </script><script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript"></script>
# <noscript><div style="display:inline;"><img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1000940071/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/></div></noscript>
# <script>
# 		!function(f,b,e,v,n,t,s)
# 		{if(f.fbq)return;n=f.fbq=function()
# 		{n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 		if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 		n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];
# 		s.parentNode.insertBefore(t,s)}(window, document,'script',
# 		'https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '751110881643258');
# 		fbq('track', 'PageView');
# 	</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=751110881643258&amp;ev=PageView&amp;noscript=1" style="display:none" width="1">
# </img></noscript>
# <script type="text/javascript">
#         fbq = window.fbq || $.noop;
#     </script>
# </img>

# %% [markdown]
# ### 기사 title 가져오기

# %%
len(soup.select('#contentSection > article'))
# Out:
# 16

# %%
soup.select('#contentSection > article')[0]
# Out:
# <article class="js-article-item articleItem " data-id="200436761">
# <a class="img" href="/analysis/article-200436761"><img alt="Tommy Trader" class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/2316266cc5f8f341fa70510a80725dd9.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436761" title="[ 비트코인 ] 21/07/08 TOMMY의 비트코인 매매전략">[ 비트코인 ] 21/07/08 TOMMY의 비트코인 매매전략</a>
# <span class="articleDetails"><span>부터 <a href="/members/contributors/205973186">Tommy Trader</a></span><span class="date"> - 2021년 07월 08일</span></span> <p>- 비트코인 4시간 봉입니다.- 장기적 수렴(초록색)과 단기적 수렴(보라색)의 하방 이탈을 시도하고 있는 모습입니다.- 1시간 봉에선 단기적 수렴(보라색)의 하단까지 이탈 마감한 ...</p> </div>
# <div class="clear"></div>
# </article>

# %%
soup.select('#contentSection > article')[0].select('.title')[0].get_text().strip()
# Out:
# '[ 비트코인 ] 21/07/08 TOMMY의 비트코인 매매전략'

# %% [markdown]
# ### 기사 url 가져오기

# %%
soup.select('#contentSection > article')[0].select('a')[0].attrs['href'].strip()
# Out:
# '/analysis/article-200436761'

# %% [markdown]
# ### 기사 요약 가져오기

# %%
soup.select('#contentSection > article')[0].select('p')[0].text.strip()
# Out:
# '- 비트코인 4시간 봉입니다.- 장기적 수렴(초록색)과 단기적 수렴(보라색)의 하방 이탈을 시도하고 있는 모습입니다.- 1시간 봉에선 단기적 수렴(보라색)의 하단까지 이탈 마감한 ...'

# %% [markdown]
# ### result에 데이터 담기

# %%
title = soup.select('#contentSection > article')[0].select('.title')[0].get_text().strip()
url = base_url + soup.select('#contentSection > article')[0].select('a')[0].attrs['href'].strip()
summary = soup.select('#contentSection > article')[0].select('p')[0].text.strip()

# %%
result = []
for i in range(0, len(soup.select('#contentSection > article'))):
    title = soup.select('#contentSection > article')[i].select('.title')[0].get_text().strip()
    url = base_url + soup.select('#contentSection > article')[i].select('a')[0].attrs['href'].strip()
    summary = soup.select('#contentSection > article')[i].select('p')[0].text.strip()
    
    analysis = {
        'title': title,
        'url': url,
        'summary': summary
    }
    result.append(analysis)

# %%
result
# Out:
# [{'title': '[ 비트코인 ] 21/07/08 TOMMY의 비트코인 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200436761',
#   'summary': '- 비트코인 4시간 봉입니다.- 장기적 수렴(초록색)과 단기적 수렴(보라색)의 하방 이탈을 시도하고 있는 모습입니다.- 1시간 봉에선 단기적 수렴(보라색)의 하단까지 이탈 마감한 ...'},
#  {'title': '2분기 암호화폐 리뷰: 높은 변동성, 당면한 이슈 4가지',
#   'url': 'https://kr.investing.com/analysis/article-200436731',
#   'summary': '(2021년 7월 5일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글신기록 달성, 분기 성적은 약세\n서로 다른 방향으로 움직이는 상위 토큰\n도지코인의...'},
#  {'title': '[TOMMY] 21/07/07 비트코인 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200436748',
#   'summary': '- 장기적수렴(초록색)과 단기적수렴(보라색)의 가능성을 모두다 보여주고 있는 비트코인입니다. - 장기적수렴(초록색)의 방향성 이탈이 출현한다 하여도 단기적수렴(보라색)의 상단/하단...'},
#  {'title': '키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행',
#   'url': 'https://kr.investing.com/jp.php?v2=NXVhPzJlYTtiNjw1bzU5OTNgYjllYjIxPCthM2RuM3o2cGNqZz9kIjc_PSNiPmU_NEc0azI6MiRiNG48MHE3dDVyYT8yYmE_YjY8M28qOXgzb2I6ZWIyMjwrYSJkbg==',
#   'summary': '키움증권(대표이사 이현)은 6월 14일부터 8월 6일까지 해외선물옵션 신규/휴면 고객을 대상으로 최대 200만원을 증정하는 첫 거래 이벤트를 진행한다고 밝혔다.'},
#  {'title': '암호화폐 시장, 상반기 리뷰 및 하반기 주의 사항/ THE PULSE',
#   'url': 'https://kr.investing.com/analysis/article-200436730',
#   'summary': '오늘은 암호화폐 시장의 상반기 실적을 정리해보고 하반기 주의 사항을 살펴보겠습니다.\n- 비트코인, 11년 전 5센트로 시작→ 6만 5천 달러 정점\n- 코인베이스 주가, 43...'},
#  {'title': '비트코인 가격 변동을 반영하는 저렴한 신규 ETF',
#   'url': 'https://kr.investing.com/analysis/article-200436625',
#   'summary': '(2021년)\nInvesting.com 게재를 위해 작성된 글4월 14일부터 약세 추세\n가격 밀집일까, 아니면 폭락일까?\nBITQ: 신규 ETF\n비트코인 가격을 따르는 움직임\n견실...'},
#  {'title': '오늘의 차트: 비트코인 하락에도 전반적 강세론 지속 가능',
#   'url': 'https://kr.investing.com/analysis/article-200436616',
#   'summary': '(2021년 6월 22일 작성된 영문 기사의 번역본)비트코인은 오늘 다시 하락했다. 가격이 31,300달러까지 떨어지면서 1월 이후 최저 수준을 나타냈다. 지금 비트코인 가격을 압...'},
#  {'title': '오늘의 차트: 단기 약세론 털어낸 비트코인 페이크아웃 패턴',
#   'url': 'https://kr.investing.com/analysis/article-200436538',
#   'summary': '(2021년 6월 14일 작성된 영문 기사의 번역본)비트코인 가격은 거칠게 움직이며 추세선 위아래를 넘나들고 있다.우리는 지난 4월 11일 비트코인 가격 하락에 대한 경고를 시작했...'},
#  {'title': '이더리움, 암호화폐 리더 비트코인의 위상을 넘볼 수 있을까?',
#   'url': 'https://kr.investing.com/analysis/article-200436507',
#   'summary': '(2021년 6월 10일 작성된 영문 기사의 번역본)이 글은 Investing.com 단독 기고문입니다. · 포물선 랠리의 종료 – 반토막난 비트코인, 다소...'},
#  {'title': '토큰 수 증가와 비트코인 가격 밀집',
#   'url': 'https://kr.investing.com/analysis/article-200436425',
#   'summary': '(2021년 6월 3일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글비트코인 하락세, 일론 머스크보다 중국 영향이 커\n$30,000 유지중\n미결제약정...'},
#  {'title': '베이커리토큰, 레이븐코인: 시총 10억 달러의 상위권 암호화폐',
#   'url': 'https://kr.investing.com/analysis/article-200436294',
#   'summary': '(2021년 5월 20일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글시가총액 10억 달러를 돌파한 암호화폐는 99종\n그린스펀은 "비이성적 과열", ...'},
#  {'title': '오늘의 차트: 최근 급락 이후 회복 준비하는 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200436295',
#   'summary': '(2021년 5월 20일 작성된 영문 기사의 번역본)최근 비트코인이 갖가지 비관적인 뉴스에 시달리면서 공포에 질린 투자자들의 매도가 줄을 이었다.디지털 토큰을 대표하는 비트코인의 ...'},
#  {'title': '암호화폐: 거품일까, 아니면 새로운 개척지일까?',
#   'url': 'https://kr.investing.com/analysis/article-200436262',
#   'summary': '(2021년 5월 17일 작성된 영문 기사의 번역본)이 글은 Investing.com 단독 기고문입니다.암호화폐는 상품일까, 아니면 무엇일까?\n규제당국이 답해야 하는 중요한 질문 ...'},
#  {'title': '바이낸스 코인, 유니스왑: 암호화폐 유동성 제공하는 성공담 2가지',
#   'url': 'https://kr.investing.com/analysis/article-200436119',
#   'summary': '(2021년 5월 6일 작성된 영문 기사의 번역본)\nInvesting.com 게제를 위해 작성된 글시가총액 220억 달러 돌파한 토큰은 11종 뿐\n자산군 중에서는 작은 규모\n상위 ...'},
#  {'title': '오늘의 차트: 비트코인 하락세 유의, 3만 달러까지 하락 가능',
#   'url': 'https://kr.investing.com/analysis/article-200436120',
#   'summary': '(2021년 5월 6일 작성된 영문 기사의 번역본)이 칼럼에서 비트코인에 관한 마지막 글은 지난 3월 말에 작성되었다. 당시에는 암호화폐의 미래를 낙관적으로 전망했고, 실제로도 이...'},
#  {'title': 'CRYPTO 암호화폐 (가상자산) 규제, 바꿔야 한다',
#   'url': 'https://kr.investing.com/analysis/article-200436126',
#   'summary': '최근 "가상자산 매매는 투자가 아닌 잘못된 길이며 어른들이 가르쳐 주어야 한다"는 금융당국 수장의 발언이 구설수에 올랐다. 부동산 가격 상승으로 부동산 투자의 길이 막힌 후 가상자...'}]

# %%
soup.select('.pagination')
# Out:
# [<a class="pagination selected" href="javascript:void();">1</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/2" title="결과를 보여줍니다 18 으로 34 의 227">2</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/3" title="결과를 보여줍니다 35 으로 51 의 227">3</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/4" title="결과를 보여줍니다 52 으로 68 의 227">4</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/5" title="결과를 보여줍니다 69 으로 85 의 227">5</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/6" title="결과를 보여줍니다 86 으로 102 의 227">6</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/7" title="결과를 보여줍니다 103 으로 119 의 227">7</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/8" title="결과를 보여줍니다 120 으로 136 의 227">8</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/9" title="결과를 보여줍니다 137 으로 153 의 227">9</a>,
#  <a class="pagination" href="/analysis/cryptocurrency/10" title="결과를 보여줍니다 154 으로 170 의 227">10</a>]

# %%
result = []
last_page_num = int(soup.select('.pagination')[-1].text)
for page_num in range(1, last_page_num):
    url = base_url + '/analysis/cryptocurrency/'+ str(page_num)
    response = session.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    
    for i in range(0, len(soup.select('#contentSection > article'))):
        title = soup.select('#contentSection > article')[i].select('.title')[0].get_text().strip()
        url = base_url + soup.select('#contentSection > article')[i].select('a')[0].attrs['href'].strip()
        summary = soup.select('#contentSection > article')[i].select('p')[0].text.strip()

        analysis = {
            'title': title,
            'url': url,
            'summary': summary
        }
        result.append(analysis)

# %%
result[3]
# Out:
# {'title': '키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행',
#  'url': 'https://kr.investing.com/jp.php?v2=ZydiPGI1NmwyZmlgZjxjYz5tN2xlY2VjYHdgMmdtYyplIzA5bzdmIDY-bnBiPmM5YhEybWVtMiRiNGAyOntuLWcgYjxiMjZoMmZpZmYjYyI-YjdvZWJlZWB3YCNnbQ==',
#  'summary': '키움증권(대표이사 이현)은 6월 14일부터 8월 6일까지 해외선물옵션 신규/휴면 고객을 대상으로 최대 200만원을 증정하는 첫 거래 이벤트를 진행한다고 밝혔다.'}

# %%
result = []
last_page_num = int(soup.select('.pagination')[-1].text)
for page_num in range(1, last_page_num):
    url = base_url + '/analysis/cryptocurrency/'+ str(page_num)
    response = session.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    
    for i in range(0, len(soup.select('#contentSection > article'))):
        title = soup.select('#contentSection > article')[i].select('.title')[0].get_text().strip()
        url = base_url + soup.select('#contentSection > article')[i].select('a')[0].attrs['href'].strip()
        summary = soup.select('#contentSection > article')[i].select('p')[0].text.strip()

        analysis = {
            'title': title,
            'url': url,
            'summary': summary
        }
        if 'jp.php' in analysis['url']:
            pass
        else:
            result.append(analysis)

# %%
result
# Out:
# [{'title': '[ 비트코인 ] 21/07/08 TOMMY의 비트코인 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200436761',
#   'summary': '- 비트코인 4시간 봉입니다.- 장기적 수렴(초록색)과 단기적 수렴(보라색)의 하방 이탈을 시도하고 있는 모습입니다.- 1시간 봉에선 단기적 수렴(보라색)의 하단까지 이탈 마감한 ...'},
#  {'title': '2분기 암호화폐 리뷰: 높은 변동성, 당면한 이슈 4가지',
#   'url': 'https://kr.investing.com/analysis/article-200436731',
#   'summary': '(2021년 7월 5일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글신기록 달성, 분기 성적은 약세\n서로 다른 방향으로 움직이는 상위 토큰\n도지코인의...'},
#  {'title': '[TOMMY] 21/07/07 비트코인 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200436748',
#   'summary': '- 장기적수렴(초록색)과 단기적수렴(보라색)의 가능성을 모두다 보여주고 있는 비트코인입니다. - 장기적수렴(초록색)의 방향성 이탈이 출현한다 하여도 단기적수렴(보라색)의 상단/하단...'},
#  {'title': '암호화폐 시장, 상반기 리뷰 및 하반기 주의 사항/ THE PULSE',
#   'url': 'https://kr.investing.com/analysis/article-200436730',
#   'summary': '오늘은 암호화폐 시장의 상반기 실적을 정리해보고 하반기 주의 사항을 살펴보겠습니다.\n- 비트코인, 11년 전 5센트로 시작→ 6만 5천 달러 정점\n- 코인베이스 주가, 43...'},
#  {'title': '비트코인 가격 변동을 반영하는 저렴한 신규 ETF',
#   'url': 'https://kr.investing.com/analysis/article-200436625',
#   'summary': '(2021년)\nInvesting.com 게재를 위해 작성된 글4월 14일부터 약세 추세\n가격 밀집일까, 아니면 폭락일까?\nBITQ: 신규 ETF\n비트코인 가격을 따르는 움직임\n견실...'},
#  {'title': '오늘의 차트: 비트코인 하락에도 전반적 강세론 지속 가능',
#   'url': 'https://kr.investing.com/analysis/article-200436616',
#   'summary': '(2021년 6월 22일 작성된 영문 기사의 번역본)비트코인은 오늘 다시 하락했다. 가격이 31,300달러까지 떨어지면서 1월 이후 최저 수준을 나타냈다. 지금 비트코인 가격을 압...'},
#  {'title': '오늘의 차트: 단기 약세론 털어낸 비트코인 페이크아웃 패턴',
#   'url': 'https://kr.investing.com/analysis/article-200436538',
#   'summary': '(2021년 6월 14일 작성된 영문 기사의 번역본)비트코인 가격은 거칠게 움직이며 추세선 위아래를 넘나들고 있다.우리는 지난 4월 11일 비트코인 가격 하락에 대한 경고를 시작했...'},
#  {'title': '이더리움, 암호화폐 리더 비트코인의 위상을 넘볼 수 있을까?',
#   'url': 'https://kr.investing.com/analysis/article-200436507',
#   'summary': '(2021년 6월 10일 작성된 영문 기사의 번역본)이 글은 Investing.com 단독 기고문입니다. · 포물선 랠리의 종료 – 반토막난 비트코인, 다소...'},
#  {'title': '토큰 수 증가와 비트코인 가격 밀집',
#   'url': 'https://kr.investing.com/analysis/article-200436425',
#   'summary': '(2021년 6월 3일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글비트코인 하락세, 일론 머스크보다 중국 영향이 커\n$30,000 유지중\n미결제약정...'},
#  {'title': '베이커리토큰, 레이븐코인: 시총 10억 달러의 상위권 암호화폐',
#   'url': 'https://kr.investing.com/analysis/article-200436294',
#   'summary': '(2021년 5월 20일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글시가총액 10억 달러를 돌파한 암호화폐는 99종\n그린스펀은 "비이성적 과열", ...'},
#  {'title': '오늘의 차트: 최근 급락 이후 회복 준비하는 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200436295',
#   'summary': '(2021년 5월 20일 작성된 영문 기사의 번역본)최근 비트코인이 갖가지 비관적인 뉴스에 시달리면서 공포에 질린 투자자들의 매도가 줄을 이었다.디지털 토큰을 대표하는 비트코인의 ...'},
#  {'title': '암호화폐: 거품일까, 아니면 새로운 개척지일까?',
#   'url': 'https://kr.investing.com/analysis/article-200436262',
#   'summary': '(2021년 5월 17일 작성된 영문 기사의 번역본)이 글은 Investing.com 단독 기고문입니다.암호화폐는 상품일까, 아니면 무엇일까?\n규제당국이 답해야 하는 중요한 질문 ...'},
#  {'title': '바이낸스 코인, 유니스왑: 암호화폐 유동성 제공하는 성공담 2가지',
#   'url': 'https://kr.investing.com/analysis/article-200436119',
#   'summary': '(2021년 5월 6일 작성된 영문 기사의 번역본)\nInvesting.com 게제를 위해 작성된 글시가총액 220억 달러 돌파한 토큰은 11종 뿐\n자산군 중에서는 작은 규모\n상위 ...'},
#  {'title': '오늘의 차트: 비트코인 하락세 유의, 3만 달러까지 하락 가능',
#   'url': 'https://kr.investing.com/analysis/article-200436120',
#   'summary': '(2021년 5월 6일 작성된 영문 기사의 번역본)이 칼럼에서 비트코인에 관한 마지막 글은 지난 3월 말에 작성되었다. 당시에는 암호화폐의 미래를 낙관적으로 전망했고, 실제로도 이...'},
#  {'title': 'CRYPTO 암호화폐 (가상자산) 규제, 바꿔야 한다',
#   'url': 'https://kr.investing.com/analysis/article-200436126',
#   'summary': '최근 "가상자산 매매는 투자가 아닌 잘못된 길이며 어른들이 가르쳐 주어야 한다"는 금융당국 수장의 발언이 구설수에 올랐다. 부동산 가격 상승으로 부동산 투자의 길이 막힌 후 가상자...'},
#  {'title': '암호화폐의 움직임, 도가 지나친 것은 아닐까?',
#   'url': 'https://kr.investing.com/analysis/article-200436075',
#   'summary': '(2021년 5월 3일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글비트코인, 코인베이스 상장 시점에 천정 도달\n이더리움 강세 유지\n포물선 움직임이 ...'},
#  {'title': '중국 CBDC 디지털화폐 전쟁의 서막인가... "2022년 베이징 동계올림픽에서 검증"',
#   'url': 'https://kr.investing.com/analysis/article-200435906',
#   'summary': '중국 인민은행 부총재가 비트코인 등 가상자산을 대체 투자 자산으로 인식하고 있다는 견해를 나타냈다. 오는 2022년 베이징 동계 올림픽에서 디지털 위안화를 공식 유통할 것이라는 계...'},
#  {'title': '코인베이스와 도지코인 (DOGE)',
#   'url': 'https://kr.investing.com/analysis/article-200435886',
#   'summary': '암호화폐 시장의 주인공은 비트코인(Bitcoin, BTC)이 아니었다. \xa0 알트코인(비트코인 이외의 코인) 중에는 단연 도지코인(Dogecoin, DOGE)이 폭발적인 가격 상승에...'},
#  {'title': '높은 매력과 리스크 겸비한 코인베이스',
#   'url': 'https://kr.investing.com/analysis/article-200435852',
#   'summary': '(2021년 4월 15일 작성된 영문 기사의 번역본)\n디지털 화폐가 시장을 움직일 것이라고 예상한다면 코인베이스 글로벌(Coinbase Global, NASDAQ:COIN)은 매우...'},
#  {'title': '가상화폐의 조심스러운 투자가 필요한 시점',
#   'url': 'https://kr.investing.com/analysis/article-200435492',
#   'summary': '국내 거래소에서 비트코인이 사상 처음으로 개당 7000만원을 넘어서는 등 가상화폐의 가격이 연일 폭등하고 있다.전문가들은 이런 상승 배경으로 ▲코로나19 확산 이후 넘치는 유동성에...'},
#  {'title': '인플루언스의 비트코인 이야기',
#   'url': 'https://kr.investing.com/analysis/article-200435371',
#   'summary': '요즘 온라인에서 ‘인플루언서(influencer)’란 용어를 심심찮게 볼 수 있습니다. 주로 특정 분야에서 남보다 강한 영향력을 지닌 사람을 말하는데요. 지금의 가상자산(암호화폐)...'},
#  {'title': 'FInsight 비트코인 분석 210222',
#   'url': 'https://kr.investing.com/analysis/article-200435182',
#   'summary': '안녕하세요, Finsight입니다. 2월의 마지막 주가 시작되었습니다.\xa0 비트코인은 지속적으로 랠리를 지속하는 가운데, 랠리의 끝은 어떤 가격에서 언제 끝날지는 아직 정확히 예측하...'},
#  {'title': '바이든 부양책 표결과 비트코인 5만달러',
#   'url': 'https://kr.investing.com/analysis/article-200435117',
#   'summary': '바이든 부양책 표결 \xa0 미 하원은 바이든 대통령이 제안한 1.9조 달러의 경기부양책을\xa02월 26일\xa0표결에 부칠 계획이다. \xa0 소식통에 따르면 Steny Hoyer 민주당 하원 원내...'},
#  {'title': '김에코의 코인 시황분석 (Coin Market Analysis) 2020/08/28',
#   'url': 'https://kr.investing.com/analysis/article-200433197',
#   'summary': '안녕하세요, TECWAVE의 김에코 입니다.비트코인은 전일 파웰 연설로 인하여 큰 폭으로 꼬리가 형성되었습니다. 때문에 강하게 상승추세 발현 가능성을 기대했으나, 재차 하락하면서 ...'},
#  {'title': '김에코의 코인 시황분석 (Coin Market Analysis) 2020/08/26',
#   'url': 'https://kr.investing.com/analysis/article-200433167',
#   'summary': '안녕하세요, TECWAVE의 김에코 입니다.비트코인은 추가 상승시도에 실패하면서 25일 밤사이 강한 하락이 출현했습니다. 아쉽게도 전일 방송은 컴퓨터 문제로 인하여 진행하지 않았기...'},
#  {'title': '김에코의 코인 시황분석 (Coin Market Analysis) 2020/08/24',
#   'url': 'https://kr.investing.com/analysis/article-200433138',
#   'summary': '안녕하세요, TECWAVE의 김에코 입니다.비트코인은 21일 제시드렸던 하단의 초록 박스 구간까지 하락했습니다. 하지만 주말간 추가적인 하락 보다는 지지받는 모습입니다. 때문에 현...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/21',
#   'url': 'https://kr.investing.com/analysis/article-200433120',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 19일 브리핑 후 일시 하락하며 1차 목표 구간에 도달하였으나, 현재 약반등 진행 중에 있습니다. 하지만 크게 유의미...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/19',
#   'url': 'https://kr.investing.com/analysis/article-200433096',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 결국 강한 저항을 확인하면서 18일 이후 큰 폭으로 조정이 출현 중에 있습니다. 때문에 단기 관점에서의 하락 연장을 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/14',
#   'url': 'https://kr.investing.com/analysis/article-200433061',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다. 비트코인은 수요일 브리핑에서 말씀드린 단기 상승이 이루어진 상황입니다. 현재는 2차례 상승이 발생하면서 상승하였으나, 거래량...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/12',
#   'url': 'https://kr.investing.com/analysis/article-200433039',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 말씀드렸던 추가 조정관점 나오면서 단기적인 조정이 이루어진 모습입니다. 하지만 이러한 조정이 전체 추세를 전환시킬 수...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/10',
#   'url': 'https://kr.investing.com/analysis/article-200433013',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 금일 09시부터 재차 상승추세를 이어가려고 하였으나, 상승 끝단의 강한 조정이 출현하면서 하락이탈을 통한 진정세가 나...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/05',
#   'url': 'https://kr.investing.com/analysis/article-200432974',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 주말 간 강한 움직임을 보여주었으나, 저번에 기대했던 미장 이후 재상승 / 하락에 대한 유의미한 후속타는 나오지 않았...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/08/03',
#   'url': 'https://kr.investing.com/analysis/article-200432945',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 기존의 빨간 박스의 저항을 확인하면서 말씀드린 추가 롱 관점이 적용되었습니다. 주말 내에 강한 조정 움직임이 출현하였...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/29',
#   'url': 'https://kr.investing.com/analysis/article-200432915',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트는 추가적으로 상승하면서 피보나치 3.618 지점인 11425 까지 상승했습니다. 때문에 3개월 수렴 후 장기적 불 플래그 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/27',
#   'url': 'https://kr.investing.com/analysis/article-200432876',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트는 21일 기점으로 크게 상승하면서 4월 이후의 수렴을 상방으로 확정지은 모습입니다. 때문에 저번주부터 지속적으로 롱 관점을...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/24',
#   'url': 'https://kr.investing.com/analysis/article-200432856',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인이 2차 상승을 시도하면서 9일 고점을 확실하게 넘긴 상황입니다. 거래량 또한 이전 21일 상승분과 비슷한 수준으로 매수...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/20',
#   'url': 'https://kr.investing.com/analysis/article-200432801',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 기존 추세선 이탈 후 재차 이평선 수렴에 성공하면서 상대적으로 지루한 장세를 보이고 있습니다. 04/29 의 7700...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/17',
#   'url': 'https://kr.investing.com/analysis/article-200432781',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인의 이평선이 천천히 하강하기 시작하면서, 메이저 코인들의 매도세가 증가하는 상황입니다. 때문에 이전 수요일 말씀드렸던 숏...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/13',
#   'url': 'https://kr.investing.com/analysis/article-200432722',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 금일 나스닥 상승이 무색하게, 9200 구간에서 지속적인 횡보 움직임을 보여주고 있습니다. 따라서 크게 의미있는 반등...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/10',
#   'url': 'https://kr.investing.com/analysis/article-200432704',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트는 말씀드린 9500 직전의 9490 까지 상승했으며, 이후 상승 전 가격대보다 하락하는 모습입니다. 때문에 기존의 평행 채...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) 2020/07/08',
#   'url': 'https://kr.investing.com/analysis/article-200432683',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 예상했던 상승 발산 나오면서, 어느정도 횡보에 들어간 모습입니다. 하지만 4시간 120 이평선의 돌파가 이루어졌고, ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432668',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 04/30 이후 장기적으로 수렴만 지속적으로 이어가고 있습니다. 때문에 점차 목표값의 레인지가 좁아지고 있으며, 아직...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432616',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 추가적으로 하방 움직임 대신, 나스닥으로 인하여 동반 상승하는 움직임을 보여주었습니다. 때문에 하락 움직임이 금일은 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432587',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 저번 브리핑 드린 것 처럼 강하게 하락이 이루어 졌습니다. 24일 기점으로 하락세 전환 되었으며, 현재는 이번주 미장...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432550',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 앞서 말씀드린 것 처럼 분출 직전의 상태였고, 500불 가량의 상승이 출현했습니다. 하지만 금일 가격대를 유지 못하고...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) - 06 / 17',
#   'url': 'https://kr.investing.com/analysis/article-200432501',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 하락했던 거래량 보다 적은 매수량으로 이전 고점인 12일의 매물대를 돌파 후 횡보중입니다. 이러한 움직임에는 전일 미...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) - 06 / 15',
#   'url': 'https://kr.investing.com/analysis/article-200432475',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 기대했던 주말간의 상승 추세가 나오지 않고, 큰 반등없이 횡보 후 재차 하락하는 모습입니다. 최근 움직임이 지속적으로...'},
#  {'title': '200615 비트코인이 더위를 먹었나 봅니다',
#   'url': 'https://kr.investing.com/analysis/article-200432465',
#   'summary': '안녕하세요, 저녁에 인사를 드리게 되었습니다.후다닥 시황 보도록 하겠습니다.주봉지난주 저점은 일목구름 구름 상단에서 꼬리가 말려 올라갔으며, 금일 저점 또한 일목구름 구름 안으로 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis) - 06 / 12',
#   'url': 'https://kr.investing.com/analysis/article-200432459',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인이 금일 새벽 상승하면서 재차 상방 움직임을 시작하나 했지만, 최근 비트코인이 나스닥과 커플링 현상을 보이면서 기존 3일...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432430',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.여전히 비트코인은 매물대가 강력하게 작용하고 있으며, 소규모 업비트 펌핑을 제외하고는 크게 움직이는 모습은 아닙니다. 때문에 오...'},
#  {'title': '200611 비트코인 상승 준비 완료? 과연',
#   'url': 'https://kr.investing.com/analysis/article-200432425',
#   'summary': '안녕하세요, 지난 밤 소폭 상승이 있었던 하루네요.오늘도 날이 덥습니다.금일 시황 보도록 하겠습니다.1일봉1일봉 상으로는 어제 말씀드린 것 처럼 추가 상승이 잘 나와줬습니다.지난번...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432400',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.5일 브리핑에서 단기적으로 숏 브리핑을 드렸으며, 어느정도 조정이 나오면서 TP 값을 달성하는 모습이 나왔습니다. 하지만 기대했...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432389',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인이 2일 강한 하락을 보여준 이후로 꾸준하게 반등을 해왔습니다. 하지만 어느 정도 가격대를 올려줬지만, 매수세가 강하게 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432355',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인이 어제 21시경 강하게 움직이면서, 대부분의 메이저 코인에게 변동성 요인을 심어주었습니다. 기존에 작도했던 매물대를 전...'},
#  {'title': '200604 음봉을 만회하려는 소극적인 움직임',
#   'url': 'https://kr.investing.com/analysis/article-200432352',
#   'summary': '좋은 아침입니다. 이슬비가 내리네요저는 이슬 없으면 못삽니다.1일봉일봉상으로는 장대 음봉 출현 후 어느정도 안정을 취해가는 모습입니다.어제 어느정도 반등이 나온 상황이지만, 쉽사리...'},
#  {'title': '200603 지나친 조정 발생, 이후는?',
#   'url': 'https://kr.investing.com/analysis/article-200432339',
#   'summary': '좋은 아침입니다, 여러분.좋은 아침이긴 한데 참 어제의 움직임은 이해가 잘 안 되네요.천천히 뜯어보도록 하겠습니다.1일봉일봉상 결국 $10,400~$10,500 의 벽을 넘지 못하...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432332',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.29일 단기 숏 관점에도 불구하고, 비트코인은 추가 하락보다는 단기 반등을 선택한 모습입니다. 하지만 그렇다고 해서 재차 장기 ...'},
#  {'title': '20/0602 캔들 마감까지는 항상 긴장의 끈을 놓치지 말아야합니다',
#   'url': 'https://kr.investing.com/analysis/article-200432326',
#   'summary': '안녕하세요 여러분 좋은 아침입니다.1일봉제가 지난 금요일 브리핑에서, 후행스팬을 주목하라고 말씀드렸던 것 기억하시나요?후행스팬이 장대 양봉 앞에 조우했기때문에, 주말 간 만달러 이...'},
#  {'title': '200601 새로운 월봉이 시작',
#   'url': 'https://kr.investing.com/analysis/article-200432310',
#   'summary': '지난 주말 잘 보내셨나요?금일은 월봉과 주봉이 새로 시작되는 날이므로월봉부터 보고 넘어가겠습니다.월봉월봉상 가장 먼저 뚫어야할 저항선은 $9,900라인의 구름 하단 입니다.지난달에...'},
#  {'title': '0529 비트코인이 제법 올라왔습니다',
#   'url': 'https://kr.investing.com/analysis/article-200432303',
#   'summary': '안녕하세요, 인터넷 기사님 방문으로 인해 조금 늦었습니다.금일의 시황 보도록 하겠습니다1일봉일봉상 상승률이 매우 좋게 나왔습니다어제 언급한 저항대도 돌파가 나왔구요이런 기세만 유지...'},
#  {'title': '200528 비트코인은 우리를 실망시키지 않습니다',
#   'url': 'https://kr.investing.com/analysis/article-200432292',
#   'summary': '어제는 일정이 있어서 시황이 없었고 금일은 조금 늦었네요. 후딱 보도록 하겠습니다.1일봉아쉽게도, 제가 본 추세까지의 하락이 나오지 않고 도중에 반등이 나와버렸습니다.1.5% 정도...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432287',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.25일 브리핑에서 반등 롱 관점으로 분석을 드렸습니다. 말씀드린대로 크게 하락하는 모습 대신, 어느정도 횡보 이어가면서 무난하게...'},
#  {'title': '[TOMMY] 05/27 비트코인 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200432284',
#   'summary': 'https://kr.tradingview.com/chart/BTCUSD/3MuXPGKT/▶ 비트코인 한시간봉입니다. 현재 검정색 하락채널 상방돌파가 막 나왔네요. 동시에 보라색 하...'},
#  {'title': '비트코인이 상향 돌파할 수 있을 이유 3가지',
#   'url': 'https://kr.investing.com/analysis/article-200432262',
#   'summary': '(2020년 5월 25일 작성된 영문 기사의 번역본)\nInvesting.com 게재를 위해 작성된 글전설적인 트레이더 비트코인에 긍정적인 반응 보여\n2017년 후반부터 전자화폐 자...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432269',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.22일 브리핑도 마찬가지로 지속적인 숏 관점을 제시해 드렸고, 결과적으로 기존 매도세를 이기지 못하고 24일 재차 하락 시작하는...'},
#  {'title': '20/0526 과연 비트코인은 돌아올 수 없는 강을 건넌 것일까?',
#   'url': 'https://kr.investing.com/analysis/article-200432268',
#   'summary': '안녕하세요, 마진퀸 엣지입니다.오늘은 원래 일정대로 아침 시황 분석 업로드 하겠습니다.일봉\n일봉상 역시 어제 하방으로 이탈했던 구간을 결국 뚫지못하고 음봉으로 시작하는 모습입니다....'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432250',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.이전 18일에 말씀 드렸던 숏 관점이 결국 비트코인 1만불을 넘기는 상황이 나오지 않고 하락을 보여줬습니다. 현재는 주요 지지구...'},
#  {'title': '20/0522 이제는 조금 조심해야 할 때',
#   'url': 'https://kr.investing.com/analysis/article-200432242',
#   'summary': '안녕하세요, 요즘 스케줄이 조금 빡빡해서 그랬는지 오늘 늦잠을 자버렸습니다.후다닥.. 퍼블리셔 시작하겠습니다.1 일봉일봉 상으로는 제가 조정 발생 시 지지가 가능하다고 주야장천 말...'},
#  {'title': '20/0520 단기적인 방향은 곧 결정',
#   'url': 'https://kr.investing.com/analysis/article-200432220',
#   'summary': '안녕하세요, 어제 오후엔 하늘이 정말 이쁘더니오늘 아침은 다시 우중충 모드네요.금일 시황은 어제 큰 움직임이 없었고 별 변동사항이 없어서 길지 않을 것 같습니다.-12시간봉1일봉에...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432210',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 15일 숏 브리핑 이후 9100$ 까지 하락하면서 TP2 이상 달성하는 모습입니다. 하지만 추가적인 하락보다는 일요일...'},
#  {'title': '20/0519 비트코인 단기 하락형 깃발 및 추세 결정의 시점 도달',
#   'url': 'https://kr.investing.com/analysis/article-200432208',
#   'summary': '어제의 폭우로 다들 고생하셨습니다저도 미팅이 있어서 서울을 다녀왔는데물에 둥둥 떠다닐 뻔 했네요 핫핫핫어제 퍼블리싱 이후 크게 달라진 점은 없습니다.위아래의 추세를 확인하고 왔다 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432196',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.13일 브리핑의 롱 픽 이후 모든 TP 이상 달성하는 모습이 나왔으며, 큰 폭으로 횡보 파동을 그리고 있습니다. 하지만 알트코인...'},
#  {'title': '20/0518 비트코인 컵앤핸들 패턴 - 목표가는 $11,800?',
#   'url': 'https://kr.investing.com/analysis/article-200432193',
#   'summary': '안녕하세요 새로운 한주가 시작되었습니다.월요일부터 폭우가 쏟아진다는 안 좋은 소식과 함께금일 시황 시작하겠습니다.주봉 상으로는 구름대를 벗어났다. 하락추세 1을 벗어났다. 가 제일...'},
#  {'title': '20/0515 요즘 따라 떡상인 듯 떡상 아닌 스캠같은 너어어어워우예 [OKEX 글로벌 파트너]',
#   'url': 'https://kr.investing.com/analysis/article-200432182',
#   'summary': '안녕하세요 비가 오는 물금입니다.금일은 3일봉 새 캔들이 시작되는 날이므로 체크하고 넘어갑니다.지난 3일봉 캔들은 그 전의 음봉을 무안하게 만들 정도로 하락분을 고대로 만회하는 양...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432174',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.11일 브리핑에서 숏 관점 브리핑 드린 직후, SL 직전인 9163$ 까지 상승 후 8160$ 까지 하락하면서 약 1천 불 가량...'},
#  {'title': '200514 관제탑 여기는BTC...이륙준비 완료.. [OKEX 글로벌 파트너]',
#   'url': 'https://kr.investing.com/analysis/article-200432171',
#   'summary': '안녕하세요 좋은 아침 입니다.-1일봉어제 직면했던 $8.9~$.9.07의 저항선을 돌파하는 움직임이 나왔습니다.단기적으로 직면한 저항은 어제 일봉상의 고점과도 일치하는 기존에 돌파...'},
#  {'title': '20/0513 아직은 때가 아니야?',
#   'url': 'https://kr.investing.com/analysis/article-200432164',
#   'summary': '안녕하세요 좋은아침입니다.봄 스킵하고 바로 여름으로 스왑되는가 싶더니다시 쌀쌀해지네요. 비트코인만큼이나 요즘 날씨가 제정신이 아닌 듯 합니다.금일 브리핑 전 한가지 소식을 전해드리...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432158',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.8일 브리핑 드린 지속적인 조정 가능성이 지난 주말간 출현하면서 최대폭 2천불 가량의 하락이 발생했습니다. 현재는 어느정도 매도...'},
#  {'title': '20/0512 독한 감기는 독감, 반만 걸리면 반감기?',
#   'url': 'https://kr.investing.com/analysis/article-200432152',
#   'summary': '드디어 반감기가 지나갔네요.3일봉 부터 보겠습니다-3일봉https://d18-invdn-com.akamaized.net/content/pic60106612ecd981fb255457...'},
#  {'title': '[TOMMY] 05/11 비트코인 트레이딩 전략',
#   'url': 'https://kr.investing.com/analysis/article-200432149',
#   'summary': '** 투자의 책임은 개인에게 있습니다. 본 전략을 참고만 하시길 바랍니다. **https://kr.tradingview.com/chart/XBTUSD/E8A4f0ee/ - 단기 ▶...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432143',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.4일 브리핑 드렸던 롱 추세가 여전히 강화되면서, 4일 브리핑은 SL로 마무리 되었습니다. 때문에 금일 브리핑은 지지 / 저항만...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432095',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 1일 브리핑 이후 어느정도 재반등을 시도했으나, 추가적인 고점을 높히진 못하고 3일 21시 매도세가 출현했습니다. 현...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432081',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.코인시장은 저번 29일 브리핑 직후 강하게 상승하면서 19년 06/26 상단 장기 추세선을 터치하는 모습이 나왔습니다. 이전 3...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432053',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.24일 브리핑 이후 비트코인은 큰 추세의 상승 평행채널 상단에 도달을 했습니다. 현재 23일 이후에 보여준 매수세 이상으로 재차...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432039',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 20일 브리핑의 숏 타겟가를 달성하고, 강한 매수세를 동반하며 상승하는 모습입니다. 기존의 추세 기울기 완화 상태에서...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200432001',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 17일 브리핑 이후 한 차례 추가 상승을 해줬습니다.하지만 매수세가 강하게 나오는 모습이 아니기 때문에, 현재 고점 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431990',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 15일 브리핑에서 지지 / 저항만 말씀드렸습니다. 결과적으로 비트코인은 3번째 지지 표시한 6475$ 아래인 6463...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431973',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 브리핑 직후 천천히 상승하면서 어느정도 매수세를 유지시키는 모습을 보여주고 있습니다. 그러나 현재 상승과정이 13일 ...'},
#  {'title': 'Kim Echo의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431959',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.10일 브리핑에서 말씀드린 것처럼 6400$ 까지의 하락을 열어뒀으며,브리핑 이후 금일 01시 새벽에 상승 후 큰 폭으로 하락이...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431948',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.8일 브리핑 드렸던 숏 관점이 8일 브리핑 직후부터 출현하기 시작해서, 예상했던 3번째 움직임의 형태를 보여주고 있습니다. 현재...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431933',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.6일 이후 비트코인은 03/01 하락 내심 추세선 까지 도달하면서 금일 단기적으로 상승 후 횡보 진행중에 있습니다. 아직은 단기...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431921',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.3일에 브리핑 드렸던 비트코인은 주말간 상승에 대한 반발로 인해 추가적인 매수 / 매도의 기회를 주면서 강하게 횡보했습니다. 현...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431910',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.금일 브리핑은 기존에 세워뒀던 장기 숏추세 관점을 중단기적인 간팬 작도를 활용하여 점검하는 브리핑을 올려드리려고 합니다.때문에 ...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431888',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.30일 브리핑은 전체적으로 단기 롱 관점으로 브리핑을 드렸습니다.이후 상단에 표기한 빨간 박스의 저항을 확인하고 하락했으며,현재...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431870',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.27일 브리핑 이후 미국의 양적완화 발표가 진행되면서 하방으로 강하게 움직였습니다.비트코인은 지지/저항만 체크를 드렸고, 이더리...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431857',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.비트코인은 이제 나스닥의 상승에 비해서, 크게 따라오지는 못하는 모습을 보여주고 있습니다.이는 당장 급한 자금은 나스닥과 같은 ...'},
#  {'title': 'Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431800',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.화요일에 브리핑 드렸던 주봉의 장기적인 반등 구간에서 반등이 출현했습니다.5900~6900$ 까지의 반등세를 예상했으며, 현재 ...'},
#  {'title': 'TEC_Kim Echo 의 코인 시황분석 (Coin Market Analysis)',
#   'url': 'https://kr.investing.com/analysis/article-200431779',
#   'summary': '안녕하세요, TECWAVE의 Kim Echo 입니다.월요일에 몸 상태가 안좋아서 브리핑 드리지 못했던 만큼, 오늘은 조금 더 자세한 차트 관점을 브리핑 드리기 위해서 주봉 관점을 ...'},
#  {'title': '20/03/11 TEC_Kim Echo 의 코인 시황분석',
#   'url': 'https://kr.investing.com/analysis/article-200431747',
#   'summary': '안녕하세요, TEC WAVE의 Kim Echo 입니다.9일 브리핑 드린 단기 숏 관점이 여전히 유효하게 작용하고 있고, 반발 매수에 대한 가능성이 업비트 알트들의 바이낸스 지갑 관...'},
#  {'title': '20/03/09 TEC_Echo 의 코인 시황분석',
#   'url': 'https://kr.investing.com/analysis/article-200431738',
#   'summary': '안녕하세요, Kim Echo 입니다. 미국 나스닥과 오일의 역대급 하락으로 인하여 비트코인도 휘청이는 모습을 보여주고 있습니다.4일에 브리핑 드렸던 빨간 박스에서의 저항이 이루어지...'},
#  {'title': '2020/03/02 TEC_Echo 의 코인 시황분석',
#   'url': 'https://kr.investing.com/analysis/article-200431691',
#   'summary': '안녕하세요 Kim Echo 입니다. 28일에 출현했던 매도세가 어느정도 진정되면서, 4시간봉에서 의미있는 양봉이 올라오는 중입니다.\n이평선 기준으로 매매를 하실 때, 보통 하락 추...'},
#  {'title': '2020/02/26 TEC_Echo 의 코인 시황분석',
#   'url': 'https://kr.investing.com/analysis/article-200431678',
#   'summary': '안녕하세요 Kim Echo 입니다. 24일 브리핑 이후 비트코인이 큰 폭으로 하락하면서, 말씀드렸던 짧은 숏 추세가 이어졌습니다. 하지만 그 폭이\n상당히 크게 나온 상태입니다....'},
#  {'title': '비트코인 전망 - 기술적 분석 BTCKRW',
#   'url': 'https://kr.investing.com/analysis/article-200431636',
#   'summary': '비트코인 전망 - 기술적 분석 BTCKRW\t비트코인 전망 - 기술적 분석 BTCKRW'},
#  {'title': '비트코인 중장기 전망입니다.',
#   'url': 'https://kr.investing.com/analysis/article-200431637',
#   'summary': '비트코인 중장기 전망입니다.\t비트코인 중장기 전망입니다.'},
#  {'title': '2월 3일 나스닥 매도전략',
#   'url': 'https://kr.investing.com/analysis/article-200431525',
#   'summary': '투자의 책임은 개인에게 있습니다. 본 전략을 참고만 하시길 바랍니다.\n#나스닥 매도 #NQH2020 #3월물 #1시간봉\n- 오렌지 상승 추세선에서 반등이...'},
#  {'title': '오늘의 차트: 페넌트형 패턴 실패, 비트코인 하락 신호',
#   'url': 'https://kr.investing.com/analysis/article-200431086',
#   'summary': '(2019년 11월 11일 작성된 영문 기사의 번역본)\n당장 오늘동안 2번의 강한 지지를 받았으며, 일부 애널리스트들이 암호화폐를 피난처로 지목하는 시장의 리스크 회피 분위기에도 ...'},
#  {'title': '오늘의 차트: 비트코인이 계속 하락하는 이유',
#   'url': 'https://kr.investing.com/analysis/article-200430901',
#   'summary': '(2019년 10월 7일 작성된 영문 기사의 번역본)\n비트코인은 9월 3일 종가로부터 25% 가까이 하락했다. 이 가격은 6월 26일, 고점인 $13,764를 기록한 뒤 하방 편향...'},
#  {'title': '9월3일 XBTUSD 시황',
#   'url': 'https://kr.investing.com/analysis/article-200430717',
#   'summary': '-채널 : 단기상승채널\n-장기추세 : 보합\n-단기추세 : 매수우위(중)\n-시중금리(미체결 약정) 9,300 btc -> 8,400 btc (감소)\n(가격이 ...'},
#  {'title': '9월2일 XBTUSD 오전시황',
#   'url': 'https://kr.investing.com/analysis/article-200430715',
#   'summary': '-채널 : 단기상승채널\n-장기추세 : 매도우위(중)\n-단기추세 : 매수우위(중)\n-시중금리(미체결 약정) 9,200 btc -> 8,900 btc (감소)\n...'},
#  {'title': '오늘의 차트: 비트코인 하락, 하락론자들이 상승론자를 압도',
#   'url': 'https://kr.investing.com/analysis/article-200430703',
#   'summary': '(2019년 8월 29일 작성된 영문 기사의 번역본)\n6월 말 일시적으로 $13,000을 넘기며 236%의 2019년 상승폭을 기록한 비트코인은 그 이후 꾸준히 궤도를 역행해왔다....'},
#  {'title': '비트코인 하방으로?',
#   'url': 'https://kr.investing.com/analysis/article-200430698',
#   'summary': '약 6개월간 유지가 되었던 흰색 상승 추세선에 하방 이탈이 나왔습니다. 많은 투자자들이 눈여겨 보고 있었던 추세선인만큼 이탈 시에 많은 사람들이 손절을 쳤을...'},
#  {'title': '어센딩 트라이엥글',
#   'url': 'https://kr.investing.com/analysis/article-200430652',
#   'summary': '안녕하세요. 비트코인 시황입니다.\n-복기\n매수, 매도 모두 익절을 볼 수 있었던 자리였습니다. 수익 축하드립니다.\n-추세 -채널 -패턴\n상승 채널의 지지를 ...'},
#  {'title': '수렴후 하락이탈, 패턴 붕괴, 하락세돌입',
#   'url': 'https://kr.investing.com/analysis/article-200430622',
#   'summary': '안녕하세요. 비트코인 시황입니다.\n-복기\n하락 쐐기 패턴에서 약지지 후 바로 하락 이탈하여 채널 하단 까지 내려왔습니다. 범위내에서 진입하셨고 EP1에서 탈...'},
#  {'title': '현물 브리핑(비트코인)',
#   'url': 'https://kr.investing.com/analysis/article-200430607',
#   'summary': '8월12일 BTC/KRW 빗썸/업비트 #위소보\n-채널 : 가속상승채널\n-장기추세 : 매도우위(중)\n-단기추세 : 매수 우위(중)\n-패턴: 상승삼각형\n-시간...'},
#  {'title': '횡보 박스권 방향은~?',
#   'url': 'https://kr.investing.com/analysis/article-200430602',
#   'summary': '안녕하세요. 비트코인 시황입니다.\n-복기\n4H OB 사이에서 주고 받고 진행중, 장기 하락채널 저항을 확실히 뚫지 못함.\n-추세 -채널\n장기 하락 채널의 상...'},
#  {'title': '채널 상단까지 단숨에 상승, 이번에 저항일까.. 상승돌파일까?',
#   'url': 'https://kr.investing.com/analysis/article-200430582',
#   'summary': 'HH: $11971 $LL: 9080\n안녕하세요. 비트코인 시황입니다.\n-복기\n단기 상승채널 상단 짧은 저항으로 매도 전략은 일차적으로 성공적이였고 그 위로...'},
#  {'title': '가속 상승세타는 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200430574',
#   'summary': 'HH: 13272 $LL: 9080\n안녕하세요. 비트코인 시황입니다.\n-복기\n상승 채널을 벗어나지 않고 꾸준한 상승세를 보이고 있습니다.\n어제 1차 4H O...'},
#  {'title': '횡보중~ 방향 터지기 일보직전...',
#   'url': 'https://kr.investing.com/analysis/article-200430551',
#   'summary': 'HL: $10300 LL: 9080\n안녕하세요. 비트코인 시황입니다.\n-복기\n위험도 높았던 4H OB 상단 리테스트 매수는 역시 리스크가 컸습니다.\n채널 상...'},
#  {'title': '비트코인 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200430549',
#   'summary': '투자의 책임은 개인에게 있습니다. 본 전략을 참고만 하시길 바랍니다.\n종목: XBTUSD\nEP1:8730.0\nEP2:8450.0\nSL: 8325.0\nTP1:...'},
#  {'title': '또 스윙로우 실패... 스캠무빙, 이게 비트코인이지 !',
#   'url': 'https://kr.investing.com/analysis/article-200430543',
#   'summary': 'HL: $10300, LL:$9080\n안녕하세요. 비트코인 시황입니다.\n-복기\nSwing Low 실패로 되돌아온 비트코인 가격\n$9080 하방이탈 실패\n-추...'},
#  {'title': '4H 오더블럭의 힘! 양방향으로 타점 굳',
#   'url': 'https://kr.investing.com/analysis/article-200430537',
#   'summary': '4H HL: $11132, LL:$9080 안녕하세요. 비트코인 시황입니다. -복기 공격적으로 저항의 4H OB ($10135.5~$9940)에서 매도로 대응. 성공적 수익 축하...'},
#  {'title': '비트코인: 하락 채널 상방 돌파! 하지만 저항 OB에서 걸림',
#   'url': 'https://kr.investing.com/analysis/article-200430531',
#   'summary': '4H HL: $11132, LL:$9080 안녕하세요. 비트코인 시황입니다. -복기 지지, 저항 4H OB 사이에서 매수/매도 전략 결과적으로 지지 4H OB에서 반등후 저항 4...'},
#  {'title': '4H OB진입후 반등! 아직 하락세가 끝난게 아닌것 같습니다.',
#   'url': 'https://kr.investing.com/analysis/article-200430525',
#   'summary': 'HL: $11132, LL:$9080 안녕하세요. 비트코인 시황입니다. 어제 분석글에서 장기 상승 추세선 돌파 및 4H OB에서 지지를 받을 가능성을 말했었습니다. 비트코인이 떨...'},
#  {'title': '비트코인: 하락세 돌입, 지지선 이탈이 목표',
#   'url': 'https://kr.investing.com/analysis/article-200430518',
#   'summary': 'HL: $11132, LL:$9080안녕하세요. 비트코인 시황입니다. 4시간봉에서 장기 상승 추세선 지지를 받고 있습니다. 어제 새벽 1시 캔들부터 지지를 테스트 하고 있습니다....'},
#  {'title': '비트코인: 추가 하락 되었지만 반등?',
#   'url': 'https://kr.investing.com/analysis/article-200430501',
#   'summary': '안녕하세요. 비트코인 4H 시황입니다. 전고점: $13920, HH: $13272, 저점 LL: $9080\n어제 추가 하락 가능성에 대해서 말씀드렸습니다. $9200을 뚫고 신저...'},
#  {'title': '오늘의 차트: 비트코인의 25% 하락, 하락의 첫 단계',
#   'url': 'https://kr.investing.com/analysis/article-200430498',
#   'summary': '(2019년 7월 17일 작성된 영문 기사의 번역본)\n고작 일주일 만에 25%에 달하는 손실을 입은 비트코인은 이제 공식적인 약세장에 접어들었다 - 정부와 규제기관의 비판이 단순히...'},
#  {'title': '비트코인: 이번엔 스윙로우 실패~ 반등각 잡나?',
#   'url': 'https://kr.investing.com/analysis/article-200430490',
#   'summary': '안녕하세요. 비트코인 4H 시황입니다. 전고점: $13920, HH: $13272, LL: $9650 어제부터 하락하던 비트코인이 Swing Low (전고점 밑으로 캔들 마감)이...'},
#  {'title': '오늘의 차트: 트럼프와 파월, 잠재적 비트코인 매수 기회 제공',
#   'url': 'https://kr.investing.com/analysis/article-200430489',
#   'summary': '(2019년 7월 15일 작성된 영문 기사의 번역본)\n비트코인이 트럼프의 비난을 매수 기회로 뒤바꾸면서 $10,000대에 안착한 것일까, 아니면 상황이 나아지기 전에 훨씬 더 나빠...'},
#  {'title': '누가 페이스북의 새로운 리브라 코인을 사용하겠는가?',
#   'url': 'https://kr.investing.com/analysis/article-200430465',
#   'summary': "혹시 놓쳤다면, 페이스북(NASDAQ:FB)은 화요일에 '리브라'라는 새로운 글로벌 암호화폐를 출범시킬 계획을 발표했다.\n암호화폐는 마스터카드(NYSE:MA), 페이팔, 우버(NY..."},
#  {'title': '비트코인: 고점 갱신후 상승 랠리!',
#   'url': 'https://kr.investing.com/analysis/article-200430458',
#   'summary': '안녕하세요. 비트코인 시황입니다. (4H)전고점 $13920, 저점 LL $9650, 신고점 HH $12796\n비트코인이 수렴을 끝내고 어제 오후부터 상승을 진행하고 있습니다. ...'},
#  {'title': '비트코인: OB지지는 받는 듯, 한차례 상승 끝으로 어디로',
#   'url': 'https://kr.investing.com/analysis/article-200430451',
#   'summary': '1. 현 구간은 길고긴 횡보의 모양세를 보이고 있습니다.\n2. 금주를 포함해 3주가량 더 횡보를 할 것으로 예상되고 이후에는 위아래 3천불 이상 움직일 자리입니다. - 현재로서는...'},
#  {'title': '비트코인: 아직도 아리까리한 자리',
#   'url': 'https://kr.investing.com/analysis/article-200430448',
#   'summary': '1. 안녕하세요. 며칠 브리핑은 쉬면서 이런저런 생각도 정리하고 제가 하던 매매법도 정리하면서 비트가 횡보하는거 보고 숨넘어가는 중입니다. - 단타 트레이더분들은 이 구간은 양방...'},
#  {'title': '비트코인: 하향 쐐기 이탈, 그러나 거래량은 부족',
#   'url': 'https://kr.investing.com/analysis/article-200430436',
#   'summary': '안녕하세요. 비트코인 시황입니다. 고점 HH $13920, 신저점 LL $9650\n어제의 하향 쐐기에서 저점이 더 낮춰지면서 저점을 갱신했습니다. 그러나 역시 일봉 마감이 말아 ...'},
#  {'title': '비트코인: 하락중, 신저점 갱신',
#   'url': 'https://kr.investing.com/analysis/article-200430429',
#   'summary': '안녕하세요. 비트코인 시황입니다. 고점 HH $13,920, 신저점 LL $9,950\n어제 서서히 하락할 가능성을 말씀드렸습니다. 어제 오늘 바로 지지선을 뚫으면서 하락중인 모습...'},
#  {'title': '비트코인 월봉 마감 분석: 주봉관점에서는 한차례 더 상승이 남아',
#   'url': 'https://kr.investing.com/analysis/article-200430425',
#   'summary': '1. 긴 위꼬리 캔들을 만들면서 월봉을 마감했습니다.\n- 냉정하게 살피면 긴 하락추세에 대한 짧은 반등은 마무리 되었다고 볼 수 있습니다.\n- 이 과정에서 하락추세의 618구간까...'},
#  {'title': '스텔라루멘 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200430416',
#   'summary': '투자의 책임은 개인에게 있습니다. 본 전략을 참고만 하시길 바랍니다.\n종목: 스텔라루멘 (XLM/KRW) 업비트 거래소\n진입가1: 122진입가2: 113손절가: 107목표가1: ...'},
#  {'title': '(비트코인 업비트 시황) 드디어 조정이?',
#   'url': 'https://kr.investing.com/analysis/article-200430415',
#   'summary': '1. 기다리던 시원한 음봉이 터졌습니다. 하지만, 기대하던 수준이 아니어서 추가로 탑승하기엔 좀 어려운 면이 있습니다.\n2. 4H 기준으로는 한번더 치고 올라갈 여력이 있어보이는...'},
#  {'title': '비트코인의 이번 상승세가 다른 6가지 이유',
#   'url': 'https://kr.investing.com/analysis/article-200430412',
#   'summary': '(2019년 6월 25일 작성된 영문 기사의 번역본)\n비트코인이 돌아왔다. 현재 비트코인은 2018년이 닥치기 전, 기세가 최고조에 달해 $20,000를 향해 상승하던 2017년...'},
#  {'title': '업비트 에스티피 매매전략',
#   'url': 'https://kr.investing.com/analysis/article-200430407',
#   'summary': '투자의 책임은 개인에게 있습니다. 본 전략을 참고만 하시길 바랍니다.진입가1: 0.00000508진입가2: 0.00000450손절가: 0.00000420목표가1: 0.0000056...'},
#  {'title': '되돌림을 기다려야 할지, 숏을 태워야 할지. / XBTUSD',
#   'url': 'https://kr.investing.com/analysis/article-200430403',
#   'summary': '1. 작년 12월 10일 저점을 찍은 이후 비트는 15주 내내 횡보하다가 4월 1일 만우절을 맞아 거짓말 같은 양봉을 만든뒤 계속 상승세를 이어오고 있습니다. - 파동 카운팅, 피...'},
#  {'title': '다시 Swing High 성공!',
#   'url': 'https://kr.investing.com/analysis/article-200430400',
#   'summary': '안녕하세요. 어제 거래량 감소와 수렴이 진행되고 있다고 말씀드렸습니다. 차트에 보이는것과 같이 어센딩 트라이엥글 돌파하였고 거래량까지 나오면서 패턴 완성했습니다. 그에 따라 전고점...'},
#  {'title': 'Higher Low 갱신, OB들 반등? 저항선?',
#   'url': 'https://kr.investing.com/analysis/article-200430389',
#   'summary': '안녕하세요. 어제 1H OB 말씀드렸는데 그 위치에서 저항이 나오면서 저점을 갱신하고 상승 추세선도 하락 이탈하였습니다.\n현재는 상승 추세선을 리테스트 하고 있는 상황입니다.\nHi...'},
#  {'title': '비트코인: 한차례 되돌림을 기다리며',
#   'url': 'https://kr.investing.com/analysis/article-200430384',
#   'summary': '1. 주봉관점에서는 롱을 타기는 조금 꺼려지는 구간입니다.\n2. 단타 관점에선 8.8K선을 스탑으로 9K 에서 진입해 9.4K이상을 노리고 들어가볼까 합니다.\n3. 만약 해당 구...'},
#  {'title': 'Swing High 성공 후 사향 쐐기 패턴 보이는 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200430369',
#   'summary': '안녕하세요. 계속해서 고점을 돌파하며 Swing High를 성공시키고 있는 상황입니다. 이번 Lower High는 $8336.5입니다.\n4H 분석입니다.\n고점과 저점을 높이는 중...'},
#  {'title': '드디어 Swing High 성공!!, 저항선 리테스트 매매전략.',
#   'url': 'https://kr.investing.com/analysis/article-200430364',
#   'summary': "안녕하세요. 드디어 비트코인이 '하락 저항선'을 상방 돌파하면서 고점을 높혔습니다. Lower High($8273)이 갱신되었습니다.\n봉마감이 아쉽지만 $8200근처에서 마 되면..."},
#  {'title': '연속된 Swing High 실패, 수렴의 막바지, 비트코인의 방향은?',
#   'url': 'https://kr.investing.com/analysis/article-200430357',
#   'summary': '안녕하세요. 비트인은 하락채널, 하락저항선에서 저항을 받고 있습니다.\n고점을 높히지 못하고 연속해서 Swing High 실패로 이어지고 있습니다.\n거래량은 계속해서 줄어들고 있습...'},
#  {'title': '비트코인: 숏냄새가 물씬하지만 롱을 치고싶은 구간',
#   'url': 'https://kr.investing.com/analysis/article-200196736',
#   'summary': '1. 연관 아이디어의 지난 월봉 마감 시황에서 언급했다시피, 월초는 약세에 주봉관점에서도 조정을 기대하며 하방의 오더블럭 A에서 매수를 하겠다고 분석했습니다.\n2. 연관아이디어의 ...'},
#  {'title': 'Swing Low 실패? 약반등 후 대칭 삼각 수렴으로 하락세 연장',
#   'url': 'https://kr.investing.com/analysis/article-200196733',
#   'summary': '안녕하세요. 주봉이 마무리된 상황에 대해서 분석하겠습니다.\n어제 분석글에서 이렇게 마무리 된다면 추가 하락을 예상할 수 있다고 말씀드렸습니다.\n주봉은 음봉 도지 후 장대 음봉으로 ...'},
#  {'title': '비트코인 단기저항선 돌파! 약 상승 추세 어디까지 이어질까?',
#   'url': 'https://kr.investing.com/analysis/article-200196729',
#   'summary': "안녕하세요.\n어제의 브리핑에서 말했던 약 상승세를 통해서 비트코인의 반등이 진행되고 있습니다. Lower Low는 그대로 $7435에 유지중입니다. '넥라인'을 한번 돌파하면서 ..."},
#  {'title': '약반등 진행중, 어디까지 올라올까?',
#   'url': 'https://kr.investing.com/analysis/article-200196724',
#   'summary': '안녕하세요. 어제의 브리핑에서 말했던것과 크게 다른 관점은 없습니다. Lower Low 그대로 $7435에 유지중입니다. 어제보다 반등세가 조금 올라오면서 보조지표들의 약 반등이...'},
#  {'title': '지지되었던 넥라인을 통해서 4H OB의 매도 관점',
#   'url': 'https://kr.investing.com/analysis/article-200196723',
#   'summary': '안녕하세요. 어제 추가 하락을 말씀드리고 바로 오늘 새벽 추가 하락이 나왔습니다.\n4H입니다.\n신저점을 돌파하면서 Lower Low가 $7435를 기록했습니다.\n예전 분석에서 언...'},
#  {'title': '저점 갱신! 비트코인 추세전환!?',
#   'url': 'https://kr.investing.com/analysis/article-200196717',
#   'summary': '비트코인 분석입니다.\n어제 월봉, 주봉에서 말씀 드렸던 하락 혹은 조정에 대한 관점이 벌써 진행되었습니다.\n오늘은 일봉, 4H관점에서 단기간 흐름에 대해서 분석해보겠습니다.\n일봉...'},
#  {'title': '비트코인: 꺾인 상승 추세? 장기적 관점, 마무리된 5월과 주봉분석',
#   'url': 'https://kr.investing.com/analysis/article-200196709',
#   'summary': '안녕하세요. 6월 첫째 주가 시작되고 5월이 마무리되었습니다. 간단하게 마감된 월봉과 주봉에 초점을 맞추겠습니다.\n월봉입니다.\n마감되었던 5월은 비트코인 가격은 $5250에서 약...'},
#  {'title': '차트 교육: 오더블럭? 그게 도대체 뭔데?',
#   'url': 'https://kr.investing.com/analysis/article-200196703',
#   'summary': '.'},
#  {'title': '비트코인: 작년이랑 다르다? 인생 숏? 후오비에 주목',
#   'url': 'https://kr.investing.com/analysis/article-200196693',
#   'summary': '1. 오랫만에 거래소 종합비교를 올립니다. - 비트맥스를 메인으로 각 거래소 하드월렛에서 테더의 유동량이 많은 거래소를 중심으로 비교합니다.\n2. 기본적으로 암호화폐 거래소의 캔...'},
#  {'title': '고점과 저점을 뚫지 못하며 횡보중인 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200196691',
#   'summary': '안녕하세요. 비트코인 오후 시황입니다.\n어제의 시황에서 바뀐점에 대해서 말씀 드리겠습니다. 어제 저녁부터 새벽까지 한차례 알트코인들의 순환 펌핑이 있었습니다. 메이저 코인에서는 ...'},
#  {'title': '횡보따리 횡보따~ 단기 숏한번 눈팅만 하겠습니다',
#   'url': 'https://kr.investing.com/analysis/article-200196684',
#   'summary': '1. 주말 사이에 큰 변동은 없이 구간을 횡보하면서 4H에서는 지지하던 OB를 서서히 뚫고 내려오는 중입니다.\n2. 1D 기준으로 MC 매매를 적용하기에는 아직은 조금 이른 ...'},
#  {'title': '비트코인 "단기" 분석 Wyckoff Method 관점',
#   'url': 'https://kr.investing.com/analysis/article-200196678',
#   'summary': '비트코인 1시간봉에서 나타나는 Wyckoff Method 패턴관점에서의 해석 글입니다.\nD단계 : D단계는 C단계에서의 리테스트 과정에서 거래량이 줄어들며 진행됩니다. 단기적으로...'},
#  {'title': 'BNB의 상승 신화 어디까지?',
#   'url': 'https://kr.investing.com/analysis/article-200196669',
#   'summary': '1. 홍철없는 홍철팀 마냥 상방에 저항이 되는 오더블럭이 하나도 없습니다.\n2. 그간 BNB는 거래소 코인의 신화가 되기에 충분했고, 그 신화를 이어가는 과정으로 보고 있습니다....'},
#  {'title': '비트코인 가속 상승채널 이탈! 하방으로?',
#   'url': 'https://kr.investing.com/analysis/article-200196662',
#   'summary': "안녕하세요. 비트코인 4H 차트 분석입니다.\n'가속 상승채널'은 어제 부로 하방 이탈이 나왔지만 다시 중요한 상승채널의 중간값 지지를 받으면서 다시 '상승채널' 위쪽으로 올라왔습..."},
#  {'title': '아직은 조금더 올라가보자: BITCOIN',
#   'url': 'https://kr.investing.com/analysis/article-200196656',
#   'summary': '1. 오더블럭, 피보나치 그리고 스윙하이-스윙로우로 추세를 캐치하는 넥스젠의 트레이더 입니다.\n2. 현재는 한차례 짚어드린바대로 여전히 상승 여력이 남아있어 상승의 움직임을 보여...'},
#  {'title': '$2000불 급락, 비트코인 추세는?',
#   'url': 'https://kr.investing.com/analysis/article-200196643',
#   'summary': '비트코인 시황입니다.\n오후에 큰폭의 하락이 나오면서 추세가 제대로 꺾인 상황입니다.\n하락 당시 피보나치 되돌림 비율의 70.5%에서 지지되었고 큰 상승 채널의 밑단에서 지지 받은...'},
#  {'title': '위클리 코믹: 무덤에서 되돌아온 비트코인! 다음 강세장의 시작인가?',
#   'url': 'https://kr.investing.com/analysis/article-200196640',
#   'summary': 'Investing.com - 비트코인은 거의 1년만의 최고가를 갱신하며 파란만장한 일주일을 보냈다.\n목요일 5:25 ET (09:25 GMT) 기준으로 비트파이넥스(Bitfine...'},
#  {'title': 'NTI-A, N-WAVE로 본 비트코인! 어디까지 갈까?',
#   'url': 'https://kr.investing.com/analysis/article-200196631',
#   'summary': '자세한 내용은 사진의 글을 참고해주시길 바랍니다.'},
#  {'title': '상승장? 상승장의 요건은 11700의 돌파다.',
#   'url': 'https://kr.investing.com/analysis/article-200196625',
#   'summary': '설명은 본문의 이미지 내에 기재했습니다.'},
#  {'title': '잠에서 깨어난 고래 - 아시아 암호화폐시장에 다가올 미래는?',
#   'url': 'https://kr.investing.com/analysis/article-200196620',
#   'summary': '암호화폐의 대규모 계정이 고래라 불리는 거대투자자들의 의견이나 움직임은 일반 트레이더에게 매우 중요한 판단기준이다. 고래의 행동을 분석하고 정확히 따라만 해도 투자에 성공할 수 있...'},
#  {'title': '이범배! 롱칸다 포에바! 6776까지 한번 가보자. /XBTUSD/2019-05-10',
#   'url': 'https://kr.investing.com/analysis/article-200196618',
#   'summary': '1. 지난 관점의 복기 - 그간 롱롱 거린거 아직 덜 끝났습니다. - 아래 연관아이디어로 연결한 1300불짜리 롱은 진행중입니다.\n2. NTI-A & N-WAVE - 저희...'},
#  {'title': '비트코인 시황: 어디서 숏타는 냄새 나지 않아요?',
#   'url': 'https://kr.investing.com/analysis/article-200196616',
#   'summary': '1. 지난 브리핑의 복기 - N-wave 관점에서 5975공략이 끝났고 OB의 EQ (5990선) 공략이 시작되면서 어제는 고점을 6K로 끌어올렸습니다. - 한차례 상승파동을 기...'},
#  {'title': '바이낸스 발 FUD 하락의 시작인가?',
#   'url': 'https://kr.investing.com/analysis/article-200196611',
#   'summary': '안녕하세요. 즐거운 연휴 되셨기를 바랍니다.\n오늘 오전 바이낸스에서 7,000개의 BTC가 해킹당했다는 뉴스를 접했습니다. 그후 비트코인은 약간의 하락을 보여주었고 바이낸스 거래소...'},
#  {'title': '이유있는 기다림, 그리고 565불 익절!',
#   'url': 'https://kr.investing.com/analysis/article-200196608',
#   'summary': '1. 지난 분석의 복기 - 한달전 MC매매법에 따라 매수 관점에서 접근해보자고 매매전략을 나눴습니다.- 그리고 한달이 지난 오늘 565불의 수익을 얻었는데, 현물 기준 10% 수...'},
#  {'title': '비트코인: 숏나기가 예상되지만 대체로 맑음 입니다.',
#   'url': 'https://kr.investing.com/analysis/article-200196602',
#   'summary': '1. 지난 분석의 복기 - 이평선의 눌림, ob의 중첩이라 돌파롱을 권했고, 그 결과 양봉 마감과 아무런OB가 없는 무주공산에 진입했습니다.\n2. OB 관점 - 기존 저항이 된 ...'},
#  {'title': '길고 긴 리플 하락장이 끝났을까요?',
#   'url': 'https://kr.investing.com/analysis/article-200196594',
#   'summary': '1. 저희가 늘 말씀드리지만 추세장 뒤엔 횡보장(조정장)이 오고 다시 추세장이 시작됩니다. - 암호화폐 차트에서는 그 횡보장(조정장)이 뭐같이 길거나, 추세장이 뭐같이 긴게 함정...'},
#  {'title': '4주차 비트코인, 추세 꺾였나?',
#   'url': 'https://kr.investing.com/analysis/article-200196590',
#   'summary': '안녕하세요. 개인적으로 지난 한 주가 아주 길게 느껴졌습니다. 지난주 가장 핫했던 이슈는 바로 비트파이넥스 거래소의 테더 이슈겠죠. 이것으로 인해 FUD가 진행되었고 급격한 패닉셀...'},
#  {'title': '비트코인, 연말까지 10K 가려면 여기를 뚫어내야한다.',
#   'url': 'https://kr.investing.com/analysis/article-200196582',
#   'summary': '1. 지난 브리핑의 복기 - 아직까지 큰 숏자리라고 보지는 않는다고 말씀드리면서 모험가 롱자리를 안내드렸습니다. - 캔들관점에서 쉬어가는 캔들이 나올 가능성이 있다고 언급을 드렸...'},
#  {'title': '돌파직전? 혹은 되돌림직전? 갈피를 못잡는 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200196577',
#   'summary': '◎ 비트맥스 일봉 분석 / 2019-04-241. 지난 브리핑의 복기- 오더블럭을 밟고 상승을 기대했으나 그냥 장대봉이 나오면서 상단 OB에 브레이크가 걸린 상황입니다.- 큰 숏...'},
#  {'title': '비트코인 분석: 오더블럭을 돌파한 이후 전고점 갱신할 수 있을까?',
#   'url': 'https://kr.investing.com/analysis/article-200196572',
#   'summary': '1. 지난 브리핑의 복기 - 큰 폭의 조정보다는 단기조정을 하면서 완만한 횡보를 할 것으로 보지만 추가 상승여력이 남은 것으로 해석하고 있다고 언급했습니다.\n2. OB 관점 - ...'},
#  {'title': '비트코인: 주봉은 양봉 마감을 했지만 이번 주는 횡보의 기운이 더 강함',
#   'url': 'https://kr.investing.com/analysis/article-200196568',
#   'summary': '1. 지난 분석의 복기 - 상승을 이어가려는 시도가 이어지는 것으로 보고 있다고 말씀드렸습니다만 시원하게 상단 OB를 돌파하지 못하고 있습니다. - 유럽과 미국의 부활절 휴가기간...'},
#  {'title': '비트코인 브리핑: 상승을 이어가려는 시도가 계속 보입니다.',
#   'url': 'https://kr.investing.com/analysis/article-200196556',
#   'summary': '1. 지난 브리핑 복기 - 새로운 초록색 오더블럭이 만들어졌는데 여기 지지 테스트가 나와야 추가 상승이 이어지는 관점을 말씀드렸습니다. - 그리고 오늘 귀신같이 지지테스트가 나왔...'},
#  {'title': '(비트코인 브리핑) 초록색 OB의 지지 테스트가 필요합니다.',
#   'url': 'https://kr.investing.com/analysis/article-200196551',
#   'summary': '1. 지난 브리핑의 복기 - 저희 채널에서는 초록색 OB의 지지테스트를 노리고 상단 OB의 EQ인 5252.5에서 진입해 초록색 OB의 EQ인 5091까지 진입하는 전략을 공유했...'},
#  {'title': '이 박스권 언제까지 이어질까?',
#   'url': 'https://kr.investing.com/analysis/article-200196544',
#   'summary': '1. 지난 브리핑 복기 - 목표했던 오더블럭 매매법에 따른 목표수익 4%를 무난히 달성하고 롱에 재진입을 한 상태입니다.\n2. 오더블럭 관점 - 하방 오더블럭의 지지 테스트가 나...'},
#  {'title': '비트코인은 상방쐐기후 반등없이 횡보중..',
#   'url': 'https://kr.investing.com/analysis/article-200196535',
#   'summary': '◎ 비트맥스 1H-4H 분석 / 19-04-12 1. 어제 브리핑의 복기 - 7개 봉 이내 큰폭의 변동이 없으면 횡보로 이어갈 가능성이 높다고 언급을 했는데 기간내 하방으로 움직...'},
#  {'title': 'OB를 이용한 현상황 비트코인 대응방법',
#   'url': 'https://kr.investing.com/analysis/article-200196529',
#   'summary': '◎ 비트맥스 1D 분석 / 19-04-11\n1. 오더블럭 및 캔들 관점 - 캔들 생성과정이 양봉, 음봉, 양봉 다시 오늘은 음봉으로 이어지고 있습니다. - 내일 9시 마감시 양봉...'},
#  {'title': '[넥스젠 비트코인 시황] 5.9K냐 4.3K냐 그것이 문제로다',
#   'url': 'https://kr.investing.com/analysis/article-200196524',
#   'summary': '◎ 비트맥스 주봉 분석\n1. 보라색 화살표의 캔들이 생성되고 쉬어가는 팽이, 이후 저점을 올리는 양봉 패넌트가 이어지면서 상승추세를 계속 만들었습니다.\n2. 현 구간에서 피보나치 ...'},
#  {'title': '피보나치 되돌림은 예상되지만, 정차한 곳이 마음에 들지 않는다.',
#   'url': 'https://kr.investing.com/analysis/article-200196516',
#   'summary': '◎ 비트맥스 1D 분석 : 2019/04/05\n1. 장대봉이후 3~4일간은 숏 진입 계획은 없다는 말씀을 드리고 2일이 지나고 있습니다.- 오늘과 내일 양봉이 이어질 경우 어제 ...'},
#  {'title': '[넥스젠 비트코인 분석] 돌파 롱 혹은 되돌림 롱?',
#   'url': 'https://kr.investing.com/analysis/article-200196494',
#   'summary': '◎ 비트코인 1D 분석1. 지난 분석에서 조정을 기대한다는 말씀을 드렸지만, 다시 4K 언저리에서 움직이고 있습니다. - 주요 저항이 되는 상단 OB를 돌파하지 못하고 있는 상황에...'},
#  {'title': '넥스젠 비트코인(XBTUSD) 시황 브리핑',
#   'url': 'https://kr.investing.com/analysis/article-200196482',
#   'summary': '◎ 비트맥스 1D 분석 : 2019/03/26\n1. 어제 주봉분석에서 두군데 롱자리를 기다린다고 말씀드렸습니다. - 일봉에서도 기본적인 전략은 동일합니다. - 다만 구간구간 진입 ...'},
#  {'title': '쿼드리가CX: 사태가 미궁에 빠져들면서 분명해지는 암호화폐 교훈',
#   'url': 'https://kr.investing.com/analysis/article-200196428',
#   'summary': '(2019년 3월 11일 작성된 영문 기사의 번역본)\n12월, CEO인 제럴드 코튼(Gerald Cotton)이 인도 여행 중 사망하기 전까지만 해도 캐나다의 암호화폐 거래소인 쿼...'},
#  {'title': '기술적 분석으로 보는 비트코인',
#   'url': 'https://kr.investing.com/analysis/article-200196333',
#   'summary': '(부제 : 주식시장, 크립토커런시 시장 모두 움직임이 심상치 않다.)\n안녕하세요.기술적 분석을 통해 시장의 흐름에 대해 글을 올리는 MBY_Lab 정 순용입니다.이번에는 요즘 큰 ...'},
#  {'title': '2018년 리뷰: 전세계에서 급락을 보인 암호화폐',
#   'url': 'https://kr.investing.com/analysis/article-200196217',
#   'summary': '(2018년 12월 26일 작성된 영문 기사의 번역본)\n올 한해는 암호화폐 시장의 거품이 꺼진 해로, 전세계에서 그 여파를 확인할 수 있었다. 시장 전반이 타격을 입었으며 그 어떤...'},
#  {'title': '크립토커런시의 방향에 영향을 주는 것 (부제 : 새총은 고무줄을 뒤로 많이 잡아 당길수록 멀리나간다.)',
#   'url': 'https://kr.investing.com/analysis/article-200196170',
#   'summary': '안녕하세요.크립토커런시 시장 기술적 분석과 강의를 진행하고 있는 MBY_Lab 정 순용 입니다.지금부터 18년도 12월 8일 토요일 시장 브리핑 진행 하도록 하겠습니다.\n1. 크립...'},
#  {'title': '비트코인 주가 상승을 위한 조건과 현재 상황 (부제 : 꽃이 지면 양분이 된다.)',
#   'url': 'https://kr.investing.com/analysis/article-200196159',
#   'summary': '안녕하세요. 크립토커런시 시장 기술적 분석과 강의를 진행하고 있는 MBY_Lab 정 순용 입니다.지금부터 18년도 12월 5일 수요일 시장 브리핑 진행 하도록 하겠으며, 첫 기고인...'},
#  {'title': '암호화폐 투자를 원하십니까? 거래소 선택은 여기를 참고하세요',
#   'url': 'https://kr.investing.com/analysis/article-200196130',
#   'summary': '(2018년 11월 22일 작성된 영문 기사의 번역본)\n비트코인이나 이더리움, 비트코인 캐시, XRP 같은 암호화폐가 합법성을 얻기 시작하며, 자산 다양성을 추구하는 투자자들이 이...'},
#  {'title': '오늘의 차트: 비트코인은 다음 어느 방향으로?',
#   'url': 'https://kr.investing.com/analysis/article-200195973',
#   'summary': '(영문 번역)\n비트코인이 수요일 싱가포르의 작은 거래소에서 $9,000 위로 올랐으나 전세계 평균가격은 $6,402.8근처에 머물렀다. 이 디지털 코인이 왜 월드 익스체인지 서비스...'},
#  {'title': '오늘의 차트: 비트코인 하락 (그리고 더 하락할 수도)',
#   'url': 'https://kr.investing.com/analysis/article-200195943',
#   'summary': '(영문 번역)\n비트코인 어제 10%의 큰 폭으로 하락하며 2개월만의 최저점까지 빠졌다. 이 하락은 한국의 암호화폐 거래소 코인레일이 주말에 해킹을 당했다고 트윗을 한 이후 발생했다...'},
#  {'title': '라이트닝 네트워크의 꾸준하지만 더딘 적용은 비트코인에 긍정적인가?',
#   'url': 'https://kr.investing.com/analysis/article-200195921',
#   'summary': '(영문 번역)\n블록체인 기반으로 작동하며, 비트코인의 확장성 문제를 해결하는 방법으로 알려진 세컨드 레이어 테크놀로지인 라이트닝 네트워크는 아직 초기 단계임에도 불구하고 점차 주목...'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df
# Out:
#                                              title  \
# 0               [ 비트코인 ] 21/07/08 TOMMY의 비트코인 매매전략
# 1                  2분기 암호화폐 리뷰: 높은 변동성, 당면한 이슈 4가지
# 2                       [TOMMY] 21/07/07 비트코인 매매전략
# 3           암호화폐 시장, 상반기 리뷰 및 하반기 주의 사항/ THE PULSE
# 4                      비트코인 가격 변동을 반영하는 저렴한 신규 ETF
# ..                                             ...
# 190  비트코인 주가 상승을 위한 조건과 현재 상황 (부제 : 꽃이 지면 양분이 된다.)
# 191              암호화폐 투자를 원하십니까? 거래소 선택은 여기를 참고하세요
# 192                      오늘의 차트: 비트코인은 다음 어느 방향으로?
# 193                 오늘의 차트: 비트코인 하락 (그리고 더 하락할 수도)
# 194           라이트닝 네트워크의 꾸준하지만 더딘 적용은 비트코인에 긍정적인가?
#
#                                                    url  \
# 0    https://kr.investing.com/analysis/article-2004...
# 1    https://kr.investing.com/analysis/article-2004...
# 2    https://kr.investing.com/analysis/article-2004...
# 3    https://kr.investing.com/analysis/article-2004...
# 4    https://kr.investing.com/analysis/article-2004...
# ..                                                 ...
# 190  https://kr.investing.com/analysis/article-2001...
# 191  https://kr.investing.com/analysis/article-2001...
# 192  https://kr.investing.com/analysis/article-2001...
# 193  https://kr.investing.com/analysis/article-2001...
# 194  https://kr.investing.com/analysis/article-2001...
#
#                                                summary
# 0    - 비트코인 4시간 봉입니다.- 장기적 수렴(초록색)과 단기적 수렴(보라색)의 하방...
# 1    (2021년 7월 5일 작성된 영문 기사의 번역본)\nInvesting.com 게재...
# 2    - 장기적수렴(초록색)과 단기적수렴(보라색)의 가능성을 모두다 보여주고 있는 비트코...
# 3    오늘은 암호화폐 시장의 상반기 실적을 정리해보고 하반기 주의 사항을 살펴보겠습니다....
# 4    (2021년)\nInvesting.com 게재를 위해 작성된 글4월 14일부터 약세...
# ..                                                 ...
# 190  안녕하세요. 크립토커런시 시장 기술적 분석과 강의를 진행하고 있는 MBY_Lab 정...
# 191  (2018년 11월 22일 작성된 영문 기사의 번역본)\n비트코인이나 이더리움, 비...
# 192  (영문 번역)\n비트코인이 수요일 싱가포르의 작은 거래소에서 $9,000 위로 올랐...
# 193  (영문 번역)\n비트코인 어제 10%의 큰 폭으로 하락하며 2개월만의 최저점까지 빠...
# 194  (영문 번역)\n블록체인 기반으로 작동하며, 비트코인의 확장성 문제를 해결하는 방법...
#
# [195 rows x 3 columns]

# %% [markdown]
# ### 암호화폐 뉴스 가져오기

# %% [markdown]
# ### 크롤링 URL 주소

# %%
base_url = 'https://kr.investing.com'
uri = '/news/cryptocurrency-news'
url = base_url + uri
url
# Out:
# 'https://kr.investing.com/news/cryptocurrency-news'

# %% [markdown]
# ### 세션 연결

# %%
session = requests.session()
session

# %% [markdown]
# ### 응답 받기

# %%
response = session.get(url)
response
# Out:
# <Response [403]>

# %% [markdown]
# ### 세션 헤더 설정

# %%
session.headers['User-Agent']= 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'

# %% [markdown]
# ### 다시 응답받기

# %%
response = session.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### html을 텍스트로 parsing

# %%
html = response.text

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
#  <!DOCTYPE HTML>
#
# <html class="kr" dir="ltr" geo="KR" lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml" xmlns:schema="http://schema.org/">
# <head>
# <script type="text/javascript">
#     function OptanonWrapper() { }
#
#     // temp for checks
#     </script>
# <style>
# 	.ot-floating-button {
# 		z-index:12 !important;
# 	}
# </style>
# <script src="https://i-invdn-com.investing.com/js/jquery-6.4.9.04.min.js"></script>
# <script>
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#             (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#             m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#         })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     </script>
# <script type="text/javascript">
#         window.helpers = {
#             'getCookie': function (k){var v="; "+document.cookie;var p=v.split("; "+k+"=");if(p.length===2)return p.pop().split(";").shift();else return null},
#             'setCookie': function (k,v,d){var e='';if(typeof d!=='undefined'){var n=new Date;n.setTime(n.getTime()+864e5*d);e+=';expires="';e+=n.toGMTString();e+='"';}document.cookie=k+'='+v+';path=/' + e},
#             'delCookie': function (k){document.cookie=k+'=;path=/;expires=-1'},
#             'isNumber': function (n){return !isNaN(n)&&typeof n!==undefined&&n!==null&&n!==''},
#             'removeClass': function (e,c){if(document.documentElement.classList){e.classList.remove(c);}else{var r=new RegExp('(^|\\s)'+c+'(\\s|$)', 'g');e.className=e.className.replace(r, c)}},
#             'addClass': function (e,c){if(document.documentElement.classList){e.classList.add(c);}else{if(e.className.indexOf(c)<0){if((e.className!==''&&e.className.charAt[e.className.length-1]===' ')||e.className===''){e.className+=c}else{e.className+=' '+c}}}},
#             'hasClass': function (e,c){if(document.documentElement.classList){e.classList.contains(c);}else{return e.className.indexOf(c)>=0}},
#         };
#     </script>
# <script src="https://i-invdn-com.investing.com/js/n/toolset-1.20.min.js"></script>
# <script src="https://i-invdn-com.investing.com/js/protectedMedia.js"></script>
# <script src="https://i-invdn-com.investing.com/js/logger-1.02.min.js"></script>
# <script>
#
# /**
#  * Protected Media Score politics:
#  * 1. fraudScore means: fraud [2 - clean - 100 fraud]
#  * 2. suspScore means: suspicious [2 - clean - 100 suspicious]
#  * 3. se means means: load by search engine or ad crawler (for Google Publishers recommended to not block this
#  * so Google can score your page for quality
#  *
#  * JIRA: ADTECH-625
#  */
# const PM_COOKIE_NAME = "protectedMedia";
# const protectedMediaCookie = getCookie(PM_COOKIE_NAME);
# window.fraud = 0;
# if(protectedMediaCookie === "") { // only hit once per user
# 	PMScore({
# 			callback: function(result) {
# 		if(result.status.indexOf("timeout") !== -1) {
# 			console.log("timeout: " + JSON.stringify(result));
# 		}
# 		else { // success PM call
# 			if(result.status.indexOf("se") !== -1 && result.se !== 0) {
# 				// Load by Search engine or ad crawler (for Google Publishers, recommended to not block this so Google
# 				// can score your page for quality
# 				console.log("google bot / ad crawler detected");
# 				return;
# 			}
# 			// mark the PM score to user (first time)
# 			setCookie(PM_COOKIE_NAME, result.fraudScore ,365, "/");
#
# 			if (result.fraudScore > 70) { // result.suspScore > 70
# 				console.log("fraud: " + JSON.stringify(result));
# 			}
# 			else {
# 				console.log("clean: " + JSON.stringify(result));
# 			}
# 		}
# 	},
# 			mode: "rt",
# 			timeout: 4000,
# 		})
# 	}
# else { // user or bot already tagged by protected media (used for second load only)
# 	if(protectedMediaCookie > 70) {
# 		window.fraud = 1;
# 	}
# }
# </script>
# <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
# <script>
#     window.isGDPR   = 0;
#     window.isCCPA 	= 0;
#
#     const loadGpt = () => {
# 		let gptScript = document.createElement( 'script' );
# 		gptScript.onload = function () {
# 			console.log('gpt loaded');
# 		};
# 		gptScript.async = true;
# 		gptScript.src = 'https://securepubads.g.doubleclick.net/tag/js/gpt.js';
# 		document.head.appendChild(gptScript);
#     }
#
#     if( window.isGDPR ){
#         const consentSetInterval = setInterval(() => {
#             if( typeof window.__tcfapi !== 'undefined' )
#             {
#                 clearInterval(consentSetInterval);
#                 window.__tcfapi( 'addEventListener', 2, function( tcData,listenerSuccess )
#                 {
# 					if(listenerSuccess) {
# 						if( tcData && (tcData.eventStatus === 'tcloaded' || tcData.eventStatus === 'useractioncomplete') ) {
# 							var hasDeviceStorageAndAccessConsent = tcData.purpose.consents[1] || false;
# 							// Google Requires Consent for Purpose 1
# 							if (hasDeviceStorageAndAccessConsent) {
# 								// GLOBAL VENDOR LIST - https://iabeurope.eu/vendor-list-tcf-v2-0/
# 								// CHECK FOR GOOGLE ADVERTISING PRODUCTS CONSENT. (IAB Vendor ID 755)
# 								var hasGoogleAdvertisingProductsConsent = tcData.vendor.consents[755] || false;
# 								// Check if the user gave Google Advertising Products consent (iab vendor 755)
# 								if(hasGoogleAdvertisingProductsConsent) {
# 									console.log("gpt loaded gdpr-ccpa")
# 									loadGpt();
# 								}
# 							}
# 						}
# 					}
#                 })
#             }
#
#         }, 50);
#
#     } else {
#         loadGpt();
#     }
#
#
#     var allKeyValue = {"Section":"content","Sub_Section":"CryptoCurrency-News","Charts_Page":"no","Page_URL":"\/news\/cryptocurrency-news","Domain":"kr.investing.com","smd":"1766db1c43896dc831c38dae4f4c78fc-1625922045","protected_media":"0","udid":"1766db1c43896dc831c38dae4f4c78fc","edition_id":"18","Traffic_Type":"OG","User_type":"Not_Logged_in","prebid_page":"0"};
#     var googletagGA = window.helpers.getCookie('_ga');
#
#     if (googletagGA) {
#         allKeyValue.CID = googletagGA.substr(6);
#     }
#
#     // todo: change the screen width logic and move it from here to separate task
#     var screenWidthForAds= screen.width || 1366,
#         screenWidthValue,
#         adBreakPoints = [1336,1440,1920];
#
#     if (screenWidthForAds < adBreakPoints[0]){ screenWidthValue = 'small' }
#     else if (screenWidthForAds >= adBreakPoints[0] && screenWidthForAds <= adBreakPoints[1]) {
#         screenWidthValue = 'medium'
#     }
#     else if (screenWidthForAds > adBreakPoints[1]) {
#         screenWidthValue = 'big'
#     }
#
#     allKeyValue.screen_width = screenWidthValue;
# </script>
# <script type="text/javascript">
#         window.googletag = window.googletag || {};
#         window.googletag.cmd = window.googletag.cmd || [];
#
#         window.loadSideBlockAd3 = function () {
#             googletag.cmd.push(function () {
#                 _.defineSlot({"platform":"desktop","sizes":[[300,250],[300,600]],"adSlotDivID":"div-gpt-ad-1370187203350-sb3","adUnitDivAttributes":{"advertisementText":"\uad11\uace0"},"print":true,"preBid":false,"excludedSections":["ccpa"],"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Sideblock_3_viewable"});
#                 googletag.display('div-gpt-ad-1370187203350-sb3');
#
# 				                _addAdvertisementText('div-gpt-ad-1370187203350-sb3', '광고');
# 				            });
#
#             scrollng_ad('scrollingRightBox', 'footerWrapper');
#         };
#
#         window.a892ffe2982c = {
# 			defineSlots: function () {
#
# 				_.attachEvents();
# 				_.each( allKeyValue, function (val, key) { _.setTargeting(key, val) });
# 				_.each({"Billboard_Default":{"platform":"desktop","sizes":[[970,250],[970,90],[728,90]],"adSlotDivID":"div-gpt-ad-1441189641022-6","print":true,"preBid":true,"adUnitDivAttributes":{"advertisementText":"\uad11\uace0","resize":"1","style":"height:276px;"},"collapseDiv":[true],"excludedSections":["ccpa","webinars"],"overrideRules":[{"conditions":{"relevantSections":["FX","indices","equities","etfs","Commodities","funds","ratesbonds","Crypto","certificates"]},"rewrite":{"adUnitDivAttributes":{"closeButton":"1","advertisementText":"\uad11\uace0","resize":"1"}}}],"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Billboard_Default"},"Sideblock_1_Default":{"platform":"desktop","sizes":[300,600],"adSlotDivID":"div-gpt-ad-1370187203350-sb1","excludedSections":["Education","portfolio","brokers","directory"],"adUnitDivAttributes":{"style":"margin-top:18px;","advertisementText":"\uad11\uace0"},"print":true,"preBid":true,"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Sideblock_1_Default"},"Sideblock_2_Default":{"platform":"desktop","sizes":[300,250],"adSlotDivID":"div-gpt-ad-1370187203350-sb2","excludedSections":["Education","portfolio","brokers","directory"],"adUnitDivAttributes":{"advertisementText":"\uad11\uace0"},"print":true,"preBid":true,"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Sideblock_2_Default"},"TNB_Right_Rail_1":{"platform":"desktop","sizes":["fluid"],"adSlotDivID":"div-gpt-ad-1587967538923-0","collapseDiv":[true,true],"adUnitDivAttributes":{"style":"width:300px;height:85px;"},"print":true,"preBid":false,"excludedSections":["ccpa","webinars"],"overrideRules":[{"conditions":{"relevantSites":[1]},"rewrite":{"excludedSections":["ccpa","webinars","Homepage"]}}],"defineSlot":"\/6938\/FP_KR_site\/FP_KR_TNB_Right_Rail_1"},"Not_Out_of_page_video_Content_Float_No_SF":{"platform":"desktop","sizes":[[300,169],[1,1]],"adSlotDivID":"div-gpt-ad-1531124357521-0","collapseDiv":[true],"excludedSites":[6],"excludedSections":["Homepage","Education","portfolio","brokers","webinars","majorIndices","indicesFuture"],"adUnitDivAttributes":{"style":"width:300px;height:180px;"},"overrideRules":[{"conditions":{"relevantSites":[70,62,72,2,37,13,4,10,49,8,32,53,5,9,7,50,52,30,51,68]},"rewrite":{"excludedSections":["Homepage","Education","portfolio","brokers","webinars"]}},{"conditions":{"relevantSites":[1,18]},"rewrite":{"excludedSections":["Homepage","Education","portfolio","brokers","webinars","majorIndices","indicesFuture"]}}],"print":true,"preBid":false,"defineSlot":"\/6938\/FP_KR_site\/FP_KR_Not_Out_of_page_video_Content_Float_No_SF"}}, _.defineSlot);
# 			},
#             isPrebid: false
# 		}
#
#         window.googletag.cmd.push(function () {
#
#                 window.a892ffe2982c.defineSlots();
#             //if is not gdpr compliant - get personal ads
#             if (!window.isGDPR || (window.isGDPR && getCookie('CMP_CONSENT') === '1')) {
#                 window.googletag.pubads().setRequestNonPersonalizedAds(0);
#             }
#
#             // ADX ccpa (optout - 1YYN) restricted data processing
#             if( window.isCCPA && getCookie('usprivacy') === '1YYN')
#             {
#                 console.log('CCPA privacy restrict data processing');
#                 window.googletag.pubads().setPrivacySettings({
#                     'restrictDataProcessing': true
#                 });
#             }
#             window.googletag.pubads().enableSingleRequest();
#             window.googletag.enableServices();
#         })
#
#         function _addAdvertisementText(elementKey, text) {
#             let dfpElement = document.getElementById(elementKey);
#             if (dfpElement) {
#                 let advertisementDiv = _.createAdvertisementPrefix(text);
#                 dfpElement.parentElement.prepend(advertisementDiv);
#             }
#         }
#     </script>
# <link href="https://i-invdn-com.investing.com" rel="dns-prefetch">
# <link href="https://a-invdn-com.investing.com" rel="dns-prefetch"/>
# <title>암호화폐 뉴스 - Investing.com</title>
# <link href="https://kr.investing.com/rss/news_301.rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <link href="https://kr.investing.com/news/cryptocurrency-news" rel="canonical"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@Investing_Korea" name="twitter:site"/>
# <meta content="암호화폐 뉴스 - Investing.com" name="twitter:title"/>
# <meta content="최신 암호화폐 뉴스 - 비트코인, 이더리움, 라이트코인, 리플, ICO를 포함한 주요 암호화폐에 대한 최신 뉴스를 받아보세요." name="twitter:description"/>
# <meta content="https://i-invdn-com.investing.com/redesign/images/seo/investing_300X300.png" name="twitter:image"/>
# <meta content="암호화폐 뉴스 - Investing.com" property="og:title"/>
# <meta content="최신 암호화폐 뉴스 - 비트코인, 이더리움, 라이트코인, 리플, ICO를 포함한 주요 암호화폐에 대한 최신 뉴스를 받아보세요." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://kr.investing.com/news/cryptocurrency-news" property="og:url"/>
# <meta content="https://i-invdn-com.investing.com/redesign/images/seo/investing_300X300.png" property="og:image"/>
# <meta content="Investing.com 한국어" property="og:site_name"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://i-invdn-com.investing.com/logos/favicon.ico" rel="shortcut icon"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="ko-kr" http-equiv="content-language"/>
# <link href="https://m.kr.investing.com/news/cryptocurrency-news" media="only screen and (max-width: 640px)" rel="alternate"/> <meta content="최신 암호화폐 뉴스 - 비트코인, 이더리움, 라이트코인, 리플, ICO를 포함한 주요 암호화폐에 대한 최신 뉴스를 받아보세요." name="description"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <meta content="867e13c8aeefe44c96c098634fb27ffe" name="baidu_ssp_verify"/> <link href="https://kr.investing.com/news/cryptocurrency-news/2" rel="next"/>
# <meta content="DTRxWXB3vjNUsTCPICWo9yzZmIllylXYkRevEXo7szg" name="google-site-verification"/>
# <link href="https://i-invdn-com.investing.com/css/mainOldMin_v3b.css" rel="stylesheet" type="text/css"/>
# <link href="https://i-invdn-com.investing.com/css/newMainCssMin_v76y.css" rel="stylesheet" type="text/css"/>
# <link href="https://i-invdn-com.investing.com/css/printContent_v10.css" media="print" rel="stylesheet" type="text/css">
# <script type="text/javascript">
#         var domainId = "18";
#         window.CDN_URL = "https://i-invdn-com.investing.com";
#     </script>
# <script>
#             (function() {
#                 var po = document.createElement('script');
#                 po.type = 'text/javascript';
#                 po.async = true;
#                 po.defer = true;
#                 po.src = 'https://apis.google.com/js/platform.js?onload=loadAfterGApiReady';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(po, s);
#             })();
#
#             function loadAfterGApiReady() {
#                 gapi.load('auth2', function () {
#                     auth2 = gapi.auth2.init({
#                         'client_id' : '606447380154-9825jtap5as2sm0f868m536j6v8ptgo7.apps.googleusercontent.com',
#                         'cookiepolicy' : 'single_host_origin',
#                         'requestvisibleactions' : 'http://schemas.google.com/AddActivity',
#                         'apppackagename' : 'com.fusionmedia.investing',
#                         'scope' : 'email'
#                     });
#
#                     if (window.isSignupPage) {
#                         window.btnEventList.push('customBtn2');
#                     }
#                     window.renderButtons && window.renderButtons();
#                 });
#             }
#
#         </script>
# <script src="https://i-invdn-com.investing.com/js/n/notifications-1.02.min.js" type="text/javascript"></script>
# <script async="" src="https://i-invdn-com.investing.com/js/lazysizes.min.js" type="text/javascript"></script>
# <script src="https://i-invdn-com.investing.com/js/n/utils-0.16.min.js" type="text/javascript"></script>
# <script src="https://i-invdn-com.investing.com/js/main-1.17.279.min.js" type="text/javascript"></script>
# <!--[if (gte IE 6)&(lte IE 7)]>
# <script src="https://i-invdn-com.investing.com/js/jquery.pseudo-1.1.min.js"></script>
# <![endif]-->
# <script type="text/javascript">
#         window.login_url = '/members-admin/login';
# 		        window.close_word = '닫기';
#         window.lightbox_image = '이미지';
#         window.lightbox_from = '어떤 통화를';
# 		        var FP = {
#             global  : {
#                 _defaultDomain  : 'kr.investing.com',
#                 _textAlign      : 'left'
#             }
#         };
#         var userType;
#         var userSupportedType ;
#     </script>
# <script type="text/javascript">
#         /* Modernizr 2.0.6 (Custom Build) | MIT & BSD
# 		 * Build: http://www.modernizr.com/download/#-csstransitions-iepp-cssclasses-testprop-testallprops-domprefixes
# 		 */
#         window.Modernizr=function(a,b,c){function A(a,b){var c=a.charAt(0).toUpperCase()+a.substr(1),d=(a+" "+n.join(c+" ")+c).split(" ");return z(d,b)}function z(a,b){for(var d in a)if(k[a[d]]!==c)return b=="pfx"?a[d]:!0;return!1}function y(a,b){return!!~(""+a).indexOf(b)}function x(a,b){return typeof a===b}function w(a,b){return v(prefixes.join(a+";")+(b||""))}function v(a){k.cssText=a}var d="2.0.6",e={},f=!0,g=b.documentElement,h=b.head||b.getElementsByTagName("head")[0],i="modernizr",j=b.createElement(i),k=j.style,l,m=Object.prototype.toString,n="Webkit Moz O ms Khtml".split(" "),o={},p={},q={},r=[],s,t={}.hasOwnProperty,u;!x(t,c)&&!x(t.call,c)?u=function(a,b){return t.call(a,b)}:u=function(a,b){return b in a&&x(a.constructor.prototype[b],c)},o.csstransitions=function(){return A("transitionProperty")};for(var B in o)u(o,B)&&(s=B.toLowerCase(),e[s]=o[B](),r.push((e[s]?"":"no-")+s));v(""),j=l=null,a.attachEvent&&function(){var a=b.createElement("div");a.innerHTML="<elem></elem>";return a.childNodes.length!==1}()&&function(a,b){function s(a){var b=-1;while(++b<g)a.createElement(f[b])}a.iepp=a.iepp||{};var d=a.iepp,e=d.html5elements||"abbr|article|aside|audio|canvas|datalist|details|figcaption|figure|footer|header|hgroup|mark|meter|nav|output|progress|section|summary|time|video",f=e.split("|"),g=f.length,h=new RegExp("(^|\\s)("+e+")","gi"),i=new RegExp("<(/*)("+e+")","gi"),j=/^\s*[\{\}]\s*$/,k=new RegExp("(^|[^\\n]*?\\s)("+e+")([^\\n]*)({[\\n\\w\\W]*?})","gi"),l=b.createDocumentFragment(),m=b.documentElement,n=m.firstChild,o=b.createElement("body"),p=b.createElement("style"),q=/print|all/,r;d.getCSS=function(a,b){if(a+""===c)return"";var e=-1,f=a.length,g,h=[];while(++e<f){g=a[e];if(g.disabled)continue;b=g.media||b,q.test(b)&&h.push(d.getCSS(g.imports,b),g.cssText),b="all"}return h.join("")},d.parseCSS=function(a){var b=[],c;while((c=k.exec(a))!=null)b.push(((j.exec(c[1])?"\n":c[1])+c[2]+c[3]).replace(h,"$1.iepp_$2")+c[4]);return b.join("\n")},d.writeHTML=function(){var a=-1;r=r||b.body;while(++a<g){var c=b.getElementsByTagName(f[a]),d=c.length,e=-1;while(++e<d)c[e].className.indexOf("iepp_")<0&&(c[e].className+=" iepp_"+f[a])}l.appendChild(r),m.appendChild(o),o.className=r.className,o.id=r.id,o.innerHTML=r.innerHTML.replace(i,"<$1font")},d._beforePrint=function(){p.styleSheet.cssText=d.parseCSS(d.getCSS(b.styleSheets,"all")),d.writeHTML()},d.restoreHTML=function(){o.innerHTML="",m.removeChild(o),m.appendChild(r)},d._afterPrint=function(){d.restoreHTML(),p.styleSheet.cssText=""},s(b),s(l);d.disablePP||(n.insertBefore(p,n.firstChild),p.media="print",p.className="iepp-printshim",a.attachEvent("onbeforeprint",d._beforePrint),a.attachEvent("onafterprint",d._afterPrint))}(a,b),e._version=d,e._domPrefixes=n,e.testProp=function(a){return z([a])},e.testAllProps=A,g.className=g.className.replace(/\bno-js\b/,"")+(f?" js "+r.join(" "):"");return e}(this,this.document);
#         window.ie = (function(){var undef,v = 3,div = document.createElement('div'),all = div.getElementsByTagName('i');while (div.innerHTML = '<!--[if gt IE ' + (++v) + ']><i></i><![endif]-->',all[0]);return v > 4 ? v : undef;}());
#     </script>
# <style>
#         .googleContentRec {display:inline-block;width:650px;height:300px;}
#
#     </style>
# <style>
#         /* INPUTS OVERWRITES */
#         .combineSearchBox {border:1px solid #737373;} /* overwrite main css */
#         .combineSearchBox.newInput.inputTextBox, .portfolioSearch .newInput.inputTextBox  {padding:0;}
#     </style>
# <!--[if (IE 8)|(IE 9)]>
# <link rel="stylesheet" type="text/css" href="https://i-invdn-com.investing.com/css/ie8-9main_v2b.css">
# <![endif]-->
# <!--[if IE 8]>
# <link rel="stylesheet" type="text/css" href="https://i-invdn-com.investing.com/css/ie8main_v2a.css">
# <![endif]-->
# <!--[if IE 7]>
# <link rel="stylesheet" type="text/css" href="https://i-invdn-com.investing.com/css/ie7main_v1i.css">
# <![endif]-->
# <style>
#         .MainTableDirectory .HeadTitlesRow TH {text-align:center; font-weight:bold;}
#     </style>
# <style>
#         .openTbl TH.icon {text-align:center;}         .openTbl TH.icon SPAN {position:relative; top:2px;}
#     </style>
# <script>
#         var oldIE = false, explorerEight = false ,explorerNine = false, sponsoredArticle;
#     </script>
# <!--[if lte IE 7]>
# 	<script>
# 		oldIE = true;
# 	</script>
# 	<![endif]-->
# <!--[if (IE 8)]>
# 	<script>
# 		explorerEight = true;
# 	</script>
# 	<![endif]-->
# <!--[if (IE 9)]>
# 	<script>
# 		explorerNine = true;
# 	</script>
# 	<![endif]-->
# <script>var da088b1400f80f8e48e79f51aca7d88="8dc7be5fa6002bb55bac03bbc4177a65";</script>
# <script data-obct="" type="text/javascript">
#     /** DO NOT MODIFY THIS CODE**/
#     !function(_window, _document) {
#         var OB_ADV_ID='00d807ecaf50797b1d395f73b69546fffe';
#         if (_window.obApi) {var toArray = function(object) {return Object.prototype.toString.call(object) === '[object Array]' ? object : [object];};_window.obApi.marketerId = toArray(_window.obApi.marketerId).concat(toArray(OB_ADV_ID));return;}
#         var api = _window.obApi = function() {api.dispatch ? api.dispatch.apply(api, arguments) : api.queue.push(arguments);};api.version = '1.1';api.loaded = true;api.marketerId = OB_ADV_ID;api.queue = [];var tag = _document.createElement('script');tag.async = true;tag.src = '//amplify.outbrain.com/cp/obtp.js';tag.type = 'text/javascript';var script = _document.getElementsByTagName('script')[0];script.parentNode.insertBefore(tag, script);}(window, document);
#     obApi('track', 'PAGE_VIEW');
# </script><script></script>
# <script type="text/javascript">
#         window.pubsubDebugData = {
#             dfp:{
#                 iframes:[],
#                 scripts:[]
#             },
#             code:{
#                 scripts:[]
#             }
#         };
#
#         function sendPrimisEventToPubSub(params)
#         {
#             $.ajax({
#                 url: "/pubsub/Service/message",
#                 type:'POST',
#                 data: params
#             });
#         }
#
#         function getSekindoParamsFromDFPScript()
#         {
#             var sekindoParams = {};
#             var iframes = $('body').find('iframe');
#             for (var i = 0; i < iframes.length; i++) {
#                 window.pubsubDebugData.dfp.iframes[i] = iframes[i].id;
#                 if(iframes[i].id && (iframes[i].id.indexOf('_video_') !== -1)){
#                     var scripts = iframes[i].contentWindow.document.getElementsByTagName("script");
#                     for (var q = 0; q < scripts.length; q++) {
#                         window.pubsubDebugData.dfp.scripts[i] = scripts[q].src;
#                         if (scripts[q].src && (scripts[q].src.indexOf('https://live.sekindo.com/live/liveView.php') !== -1)) {
#                             var url = new URL(scripts[q].src);
#                             var queryParams = new URLSearchParams(url.search);
#                             if(queryParams.get('s') && queryParams.get('vp_template')){
#                                 sekindoParams.media_placement_id = queryParams.get('s');
#                                 sekindoParams.vp_template = queryParams.get('vp_template');
#                                 sekindoParams.delivery_system = 'dfp';
#                                 break;
#                             }
#                         }
#                     }
#                 }
#             }
#
#             return sekindoParams;
#         }
#
#         function getSekindoParamsFromCodeScript()
#         {
#             var params = {};
#             var scripts = $('body').find('script');
#             for (var i = 0; i < scripts.length; i++) {
#                 window.pubsubDebugData.code.scripts[i] = scripts[i].src;
#                 if (scripts[i].src && (scripts[i].src.indexOf('https://live.sekindo.com/live/liveView.php') !== -1)) {
#                     var url = new URL(scripts[i].src)
#                     var queryParams = new URLSearchParams(url.search);
#                     if(queryParams.get('s') && queryParams.get('vp_template')){
#                         params.media_placement_id = queryParams.get('s');
#                         params.vp_template = queryParams.get('vp_template');
#                         params.delivery_system = 'code';
#                         break;
#                     }
#                 }
#             }
#
#             return params;
#         }
#
#         window.addEventListener('primisPlayerInit', function (e) {
#             var player = e.detail;
#
#             /**
#              * Ad started event
#              */
#             player.addEventListener('adStarted', function (val){
#                 var sekindoParams = getSekindoParamsFromDFPScript();
#                 if($.isEmptyObject(sekindoParams)){
#                     sekindoParams = getSekindoParamsFromCodeScript();
#                 }
#
#                 cb_params = {};
#                 cb_params.impValue = val.impValue;
#                 cb_params.servingFee = val.servingFee;
#                 sekindoParams.cb_params = cb_params;
#                 sekindoParams.event_type = 'adStarted';
#                 sekindoParams.debug = window.pubsubDebugData;
#
#                 sendPrimisEventToPubSub(sekindoParams);
#             });
#
#             /**
#              * Video Start event
#              */
#             player.addEventListener('videoStart', function (val){
#                 console.log('Playing video: ' + val.title);
#             });
#         });
#     </script>
# <script async="" src="/cdn-cgi/bm/cv/669835187/api.js"></script></link></link></head>
# <body class="takeover dfpTakeovers ">
# <div class="sideNotificationZone" id="sideNotificationZone">
# <div class="floatingAlertWrapper alertWrapper js-notification-item displayNone">
# <div class="alertNotifIcon"><span class="js-icon"></span></div>
# <div class="alertNotifData">
# <a class="alertDataTitle js-title"></a>
# <span class="alertDataDetails js-small-text"></span>
# </div>
# <a class="js-manage-alerts gearIconSmall genToolTip oneliner reverseToolTip" data-tooltip="알림 관리"></a>
# <span class="alertCloseIconSmall js-close"></span>
# </div>
# </div>
# <div class="breakingNews">
# <div class="floatingAlertWrapper">
# <span class="breakingNewsTitle bold">긴급 속보</span>
# <span class="breakingNewsText js-breaking-news-content"></span>
# </div>
# <span class="closeIcon js-close"></span>
# </div>
# <div class="generalOverlay js-general-overlay displayNone"></div>
# <script>
#         $('.js-general-overlay').on('click', $.stopProp);
#     </script>
# <div class="earAdv left js-floaty-flyer">
# </div>
# <script>
#             $('.js-floaty-flyer').css('position', $(window).height() <= 909 ? 'absolute' : 'fixed');
#         </script>
# <div class="wrapper">
# <header>
# <div class="topBar">
# <div class="topBarInnerWrapper">
# <a class="topBarLogo" href="/">
# <img alt="Investing.com-선두의 금융 포털" class="investingLogo" src="https://i-invdn-com.investing.com/logos/investing-com-logo.png"/>
# </a>
# <div id="topBarPopup" load="topBarSpinner"></div>
# <div class="js-search-overlay topSearchOverlay displayNone"></div>
# <div class="searchDiv newSearchDiv js-main-search-wrapper">
# <div class="searchBoxContainer topBarSearch topBarInputSelected">
# <input autocomplete="off" class="searchText arial_12 lightgrayFont js-main-search-bar" placeholder="웹사이트 검색" type="text" value=""/>
# <label class="searchGlassIcon js-magnifying-glass-icon"> </label>
# <i class="cssSpinner"></i>
# </div>
# <div class="js-results-dialog displayNone">
# <div class="js-query-results newSearch_topBar newSearch_topBarResults displayNone">
# <div class="searchMain">
# <div class="js-query-quotes-header textBox groupHeader searchPopup_results">
# <a class="js-quote-header-link">시세</a>
# <div class="js-quote-types-dropdown newSearchSelect selectWrap">
# <a class="newBtnDropdown noHover">
# <span class="js-dropdown-text-input inputDropDown">모든 상품 유형</span>
# <i class="bottunImageDoubleArrow buttonWhiteImageDownArrow"></i>
# </a>
# <ul class="dropdownBtnList displayNone js-quote-types-dropdown-ul">
# <li data-value="all">모든 상품 유형</li><li data-value="indice">지수</li><li data-value="equities">주식</li><li data-value="etf">ETFs</li><li data-value="fund">펀드</li><li data-value="commodity">원자재</li><li data-value="currency">통화</li><li data-value="crypto">암호화폐</li><li data-value="bond">채권</li><li data-value="certificate">증서</li> </ul>
# </div>
# </div>
# <div class="js-scrollable-results-wrapper newResultsContainer">
# <div class="js-table-results tableWrapper"></div>
# </div>
# <div class="js-query-no-results noResults displayNone">
# <i class="searchNoResultsNew"></i>
# <p class="lighterGrayFont">다시 검색해주세요</p>
# </div>
# <div class="searchResultsFooter">
# <i class="blueSearchGlassIcon middle"></i>
# <a class="js-footer-link" href="/">~을 위한 웹사이트를 검색하십시오: <span class="js-footer-link-text bold"></span></a>
# </div>
# </div>
# <div class="js-right-side-results searchAside"></div>
# </div>
# <div class="js-default-search-results newSearch_topBar">
# <div class="searchMain js-main-group-results"></div>
# <div class="searchAside">
# <div class="searchAside_item">
# <a class="asideTitle" href="/news/most-popular-news">
# <div class="js-search-ga-header groupHeader" ga-label="Popular News">인기 있는 뉴스</div>
# <span class="js-search-ga-more" ga-label="Popular News - More">더 많은</span>
# </a>
# <div class="js-search-ga-items articles mediumTitle1" ga-label="Popular News - Article"><article class="js-article-item articleItem " data-id="663965">
# <a class="img" href="/news/economy/article-663965"><img alt="카카오 익절한 투자자에…" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEB5S0BB_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';" 단언한="" 돼"="" 쉽게="" 안="" 이유"="" 팔아선=""/></a> <div class="textDiv">
# <a class="title" href="/news/economy/article-663965" title="카카오 익절한 투자자에…" 단언한="" 돼"="" 쉽게="" 안="" 이유"="" 팔아선="">카카오 익절한 투자자에…"쉽게 팔아선 안 돼" 단언한 이유</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="663989">
# <a class="img" href="/news/stock-market-news/article-663989"><img alt="미국 시장은 위로 마감하였습니다. 다우 존스는 1.30% 위로." class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEA6Q02Q_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
# <a class="title" href="/news/stock-market-news/article-663989" title="미국 시장은 위로 마감하였습니다. 다우 존스는 1.30% 위로.">미국 시장은 위로 마감하였습니다. 다우 존스는 1.30% 위로.</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="664037">
# <a class="img" href="/news/economy/article-664037"><img [한경우의="" alt="" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC0Q0MJ_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';" 日="" 넘을="" 도약="" 수="" 스터디]"="" 없다더니"…'k-배터리'로="" 죽어도="" 케이스="" 한수위=""/></a> <div class="textDiv">
# <a [한경우의="" class="title" href="/news/economy/article-664037" title="" 日="" 넘을="" 도약="" 수="" 스터디]"="" 없다더니"…'k-배터리'로="" 죽어도="" 케이스="" 한수위="">"日 죽어도 넘을 수 없다더니"…'K-배터리'로 한수위 도약 [한경우의 케이스 스터디]</a>
# </div>
# <div class="clear"></div>
# </article></div>
# </div>
# <div class="searchAside_item js-popular-analysis-wrapper">
# <a class="asideTitle" href="/analysis/most-popular-analysis">
# <div class="js-search-ga-header groupHeader" ga-label="Popular Analysis">인기 있는 분석</div>
# <span class="js-search-ga-more" ga-label="Popular Analysis - More">더 많은</span>
# </a>
# <div class="js-search-ga-items articles smallTitle1 analysisImg js-popular-analysis-items" ga-label="Popular Analysis - Article"><article class="js-article-item articleItem " data-id="200436762">
# <a class="img" href="/analysis/article-200436762"><img class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/64d1bde737a0a390b098991e222b1deb.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436762" title="코로나 확산 발 증시 조정: 7월 증시 각오했어도 투자심리를 흔드는데.">코로나 확산 발 증시 조정: 7월 증시 각오했어도 투자심리를 흔드는데.</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="200436773">
# <a class="img" href="/analysis/article-200436773"><img class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/64d1bde737a0a390b098991e222b1deb.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436773" title="이틀 연속 증시 급락, 정작 두려운 것은 사람들의 마음">이틀 연속 증시 급락, 정작 두려운 것은 사람들의 마음</a>
# </div>
# <div class="clear"></div>
# </article><article class="js-article-item articleItem " data-id="200436747">
# <a class="img" href="/analysis/article-200436747"><img class="lazyload" data-src="https://d18-invdn-com.investing.com/company_logo/b7b3772ca3a5b5e670b8d6203582dce1.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/anonym.gif';"/></a> <div class="textDiv">
# <a class="title" href="/analysis/article-200436747" title="한국이 선진국 지위 얻고 잃는 것들">한국이 선진국 지위 얻고 잃는 것들</a>
# </div>
# <div class="clear"></div>
# </article></div>
# </div>
# </div>
# </div>
# </div>
# <div class="js-group-template textBox displayNone">
# <div class="js-group-title groupHeader"></div>
# <div class="js-group-results newResultsContainer">
# </div>
# </div>
# <div class="js-news-items-group-template searchAside_item displayNone">
# <a class="asideTitle js-group-more-link">
# <div class="js-group-title groupHeader"></div>
# <span>더 많은</span>
# </a>
# <div class="js-group-results articles smallTitle1 analysisImg"></div>
# </div>
# <a class="row js-quote-row-template js-quote-item displayNone">
# <span class="first flag"><i class="ceFlags middle js-quote-item-flag"></i></span>
# <span class="second js-quote-item-symbol symbolName"></span>
# <span class="third js-quote-item-name"></span>
# <span class="fourth typeExchange js-quote-item-type"></span>
# </a>
# <article class="js-news-item-template articleItem displayNone">
# <a class="js-news-item-link" href="/">
# <img class="js-news-item-img" src="https://d1-invdn-com.investing.com/company_logo/d01b563261bcf223986f7ac222680343.jpg"/>
# <div class="js-news-item-name textDiv"></div>
# </a>
# </article>
# <div class="js-tool-item-template displayNone">
# <a class="js-tool-item-link eventsAndTools">
# <span class="js-tool-item-name"></span>
# </a>
# </div>
# </div>
# <script type="text/javascript">
# 	window.topBarSearchData = {
# 		texts: {
# 			recentSearchText: '나의 최근 검색',
# 			popularSearchText: '인기 검색',
#             newsSearchText: '뉴스',
#             analysisSearchText: '분석',
#             economicEventsSearchText: '경제 이벤트',
#             toolsSearchText: '도구 및 섹션',
# 			authorsSearchText: '저자',
# 			webinarsSearchText: '웹세미나'
# 		},
# 		popularSearches: [{"pairId":"6957","link":"\/equities\/dassault-system","symbol":"DAST","name":"Dassault Systemes SE","flag":"France","type":"\uc8fc\uc2dd - \ud30c\ub9ac","ci":"22"},{"pairId":"13147","link":"\/equities\/enquest","symbol":"ENQ","name":"EnQuest","flag":"UK","type":"\uc8fc\uc2dd - \ub7f0\ub358","ci":"4"},{"pairId":"13887","link":"\/equities\/china-cosco-holdings","symbol":"1919","name":"COSCO SHIPPING Holdings Co Ltd H","flag":"Hong_Kong","type":"\uc8fc\uc2dd - \ud64d\ucf69","ci":"39"},{"pairId":"961882","link":"\/equities\/leopard-resources-nl","symbol":"CIODD","name":"Connected IO Ltd","flag":"Australia","type":"\uc8fc\uc2dd - \uc2dc\ub4dc\ub2c8","ci":"25"},{"pairId":"1056240","link":"\/equities\/nanosphere-health","symbol":"NSHS","name":"Nanosphere Health Sciences Inc","flag":"Canada","type":"\uc8fc\uc2dd - CSE","ci":"6"}]	};
# </script> <div class="topBarTools">
# <span class="topBarUserAvatar js-open-auth-trigger-inside" data-page-type="topBar" id="userAccount">
# <div class="topBarText"><a class="login bold" href="javascript:void(0);" onclick="overlay.overlayLogin();">로그인</a>/<a class="register bold" href="javascript:void(0);" onclick="overlay.overlayRegister(); topBarPopup.trackTopBarGAEvent('Sign Up')">무료 등록</a></div> </span>
# <span class="topBarIconWrap" id="topBarAlertCenterBtn">
# <i class="topBarAlertsIcon"></i><i class="topBarAlertBadge js-badge arial_10 displayNone">0</i></span>
# <div class="newSigninPopup tooltipPopup displayNone js-top-bar-signin-popup bigArrowTopbar js-open-auth-trigger-inside">
# <div class="header js-header">최근 알림</div>
# <div class="content">
# <span class="signinIcon js-icon"></span>
# <div class="signInText js-explain-text">상품, 경제 이벤트 및 팔로우하는 저자의 콘텐츠에 대한 알림을 만들려면 등록하세요.</div>
# <a class="newButton orange" href="javascript:void(0);" id="signUPBtn" onclick="overlay.overlayRegister();">무료 등록</a> <div class="align_center">이미 계정이 있으세요? <a class="bold" href="javascript:overlay.overlayLogin();">로그인</a></div>
# </div>
# </div> <span class="topBarIconWrap" id="portfolioTopBarBtn">
# <i class="topBarPortfolioIcon"></i></span>
# <span class="topBarIconWrap" id="topBarMarketBtn">
# <i class="topBarWorldMarketsIcon"></i></span>
# <div class="langSelect inlineblock">
# <div class="inlineblock pointer" id="langSelect" onmouseout="flagsDropDown.render();" onmouseover="$('#editionContainer').fadeOut('fast'); flagsDropDown.render();"><span class="ceFlags South_Korea middle inlineblock"></span></div>
# <div class="tooltipPopup countrySelPopup bigArrowTopbar noHeader displayNone" id="TopFlagsContainer" onmouseout="flagsDropDown.render();" onmouseover="flagsDropDown.render();">
# <div class="content">
# <ul><li><a href="https://www.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to www.investing.com'); setTimeout('document.location = \'https://www.investing.com\'', 500);return false;"><span class="ceFlags USA"></span>English (USA)</a></li><li><a href="https://br.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to br.investing.com'); setTimeout('document.location = \'https://br.investing.com\'', 500);return false;"><span class="ceFlags Brazil"></span>Português (Brasil)</a></li><li><a href="https://uk.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to uk.investing.com'); setTimeout('document.location = \'https://uk.investing.com\'', 500);return false;"><span class="ceFlags UK"></span>English (UK)</a></li><li><a href="https://ru.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to ru.investing.com'); setTimeout('document.location = \'https://ru.investing.com\'', 500);return false;"><span class="ceFlags Russian_Federation"></span>Русский</a></li><li><a href="https://in.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to in.investing.com'); setTimeout('document.location = \'https://in.investing.com\'', 500);return false;"><span class="ceFlags India"></span>English (India)</a></li><li><a href="https://tr.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to tr.investing.com'); setTimeout('document.location = \'https://tr.investing.com\'', 500);return false;"><span class="ceFlags Turkey"></span>Türkçe</a></li><li><a href="https://ca.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to ca.investing.com'); setTimeout('document.location = \'https://ca.investing.com\'', 500);return false;"><span class="ceFlags Canada"></span>English (Canada)</a></li><li><a href="https://sa.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to sa.investing.com'); setTimeout('document.location = \'https://sa.investing.com\'', 500);return false;"><span class="ceFlags Saudi_Arabia"></span>‏العربية‏</a></li><li><a href="https://au.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to au.investing.com'); setTimeout('document.location = \'https://au.investing.com\'', 500);return false;"><span class="ceFlags Australia"></span>English (Australia)</a></li><li><a href="https://gr.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to gr.investing.com'); setTimeout('document.location = \'https://gr.investing.com\'', 500);return false;"><span class="ceFlags Greece"></span>Ελληνικά</a></li><li><a href="https://za.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to za.investing.com'); setTimeout('document.location = \'https://za.investing.com\'', 500);return false;"><span class="ceFlags South_Africa"></span>English (South Africa)</a></li><li><a href="https://se.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to se.investing.com'); setTimeout('document.location = \'https://se.investing.com\'', 500);return false;"><span class="ceFlags Sweden"></span>Svenska</a></li><li><a href="https://ph.investing.com" onclick="ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'Users Choice', 'Redirect to ph.investing.com'); setTimeout('document.location = \'https://ph.investing.com\'', 500);return false;"><span class="ceFlags Philippines"></span>English (Philippines)</a></li><li><a href="https://fi.investing.com" onclick="ga('allSitesTrack ...
# </div>
# <div class="topBarTableBox chooseEdition tooltipPopup bigArrowTopbar " id="topAlertBarContainer" style="display:none;">
# <div class="popupInnerWrapper">
# <div class="header"><span><i class="ceFlags South_Korea"></i></span><span class="chooseEditionHeaderText">한국어판 이용가능</span><a class="bugCloseIcon" href="javascript:void(0);" onclick="postponeEdition(14, 'Click on X')"></a> </div>
# <div class="content">
# Investing.com을 <span class="bold">한국어</span> 버전으로 보시겠습니까? </div>
# <div class="topPortfolioFooter">
# <a alt="아니오" class="newBtn LightGray noIcon" href="javascript:void(0);" onclick="postponeEdition(14, 'No Thanks')">아니오</a><a alt="예" class="newBtn LightGray noIcon" href="javascript:void(0);" onclick='setEdition("kr" , "https")'>예</a> </div>
# </div>
# </div>
# <script type="text/javascript">
#     function setEdition(target, d_p) {
#         // set cookie for default edition
#         //document.cookie ="myEdition="+target+"; expires=Fri, 1 Jan 2038 01:23:45 GMT; path=/";
#         if(!d_p) d_p = 'http';
#         var days=90;
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         var expires = "; expires="+date.toGMTString();
#         var currentTime = (new Date).getTime();
#         document.cookie = "editionPostpone="+currentTime+expires+"; path=/";
#
#         ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'System Recommend', 'Redirect to '+target+'.investing.com');
# 		setTimeout('document.location = "'+d_p+'://'+ target +'.investing.com?ref=www"', 500);
# 	}
#
#     function postponeEdition(days, reason) {
#         if (days!=14) days=1;
#         //$('#editionLoading').removeClass("displayNone").addClass("inlineblock");
#         // set cookie for days not to show bar again
#         //change time from 7 days to 14 (2 weeks), Gil Palikaras, JIRA-26314
#         var date = new Date();
#         date.setTime(date.getTime()+(days*24*60*60*1000));
#         var expires = "; expires="+date.toGMTString();
#         var currentTime = (new Date).getTime();
#         document.cookie = "editionPostpone="+currentTime+expires+"; path=/";
#         closeTopAlert();
#         ga('allSitesTracker.send', 'event', 'Edition Redirect Popup', 'System Recommend', reason);
#     }
#     function closeTopAlert(){
#         $('#topAlertBarContainer').fadeOut('fast');
#     }
#
#     $(document).ready (function(){
#                 var timer = setInterval(function() {
#             if ($('#mainPopUpBannerDIV').is( ":hidden" )==true) {
#                 clearInterval(timer);
#                 //openTopAlert(2000);
#             }
#         }, 200);
#             });
# </script>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
# 	loader([{
# 		type: 'component', value: 'Translate'
# 	}]).ready(function(Translate) {
# 		Translate
# 			.setDictionary('TopBarAlertsSignInPopup', {
# 				'popupHeader': '최근 알림',
# 				'notLoggedInText': "\uc0c1\ud488, \uacbd\uc81c \uc774\ubca4\ud2b8 \ubc0f \ud314\ub85c\uc6b0\ud558\ub294 \uc800\uc790\uc758 \ucf58\ud150\uce20\uc5d0 \ub300\ud55c \uc54c\ub9bc\uc744 \ub9cc\ub4e4\ub824\uba74 \ub4f1\ub85d\ud558\uc138\uc694.",
# 				'iconClasses': 'signinIcon',
# 				'popupClasses': 'topBarAlertsSignInPopup'
# 			})
# 			.setDictionary('TopBarPortfolioSignInPopup', {
# 				'popupHeader': '포트폴리오',
# 				'notLoggedInText': "investing.com\uc758 \ud3ec\ud2b8\ud3f4\ub9ac\uc624 \ub3c4\uad6c\ub85c \uc790\uc2e0\ub9cc\uc758 \uad00\uc2ec\ubaa9\ub85d\uacfc \ubcf4\uc720\uc885\ubaa9\uc744 \ub9cc\ub4e4\uace0 \uad00\ub9ac\ud558\ub824\uba74 \ub4f1\ub85d\ud558\uc2ed\uc2dc\uc624.",
# 				'iconClasses': 'signinIconPortfolio',
# 				'popupClasses': 'topBarPortfolioBox'
# 			});
# 	})
# </script>
# <div class="navBar" id="navBar">
# <nav class="navMenuWrapper" id="navMenu">
# <ul class="navMenuUL">
# <li>
# <a class="nav" href="/markets/">시장</a>
# <ul class="subMenuNav">
# <li class="row">
# <a href="/currencies/">외환</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/currencies/single-currency-crosses">단일 환율</a></li>
# <li><a href="/currencies/streaming-forex-rates-majors">주요 통화 환율</a></li>
# <li><a href="/currencies/live-currency-cross-rates">실시간 환율 시세</a></li>
# <li><a href="/currencies/exchange-rates-table">환율표</a></li>
# <li><a href="/currencies/us-dollar-index">미국 달러 지수</a></li>
# <li><a href="/currencies/fx-futures">외환선물</a></li>
# <li><a href="/currencies/forex-options">Forex 옵션</a></li> </ul>
# <ul class="popular">
# <li><a href="/currencies/usd-krw">달러/원</a></li>
# <li><a href="/currencies/eur-krw">유로/원</a></li>
# <li><a href="/currencies/jpy-krw">엔/원</a></li>
# <li><a href="/currencies/eur-usd">유로/달러</a></li>
# <li><a href="/currencies/usd-jpy">달러/엔</a></li>
# <li><a href="/currencies/cny-krw">중국 위안/원</a></li>
# <li><a href="/currencies/usd-cny">달러/중국 위안</a></li>
# <li><a href="/crypto/bitcoin/btc-usd">비트코인/달러</a></li>
# </ul>
# </div> </li>
# <li class="row">
# <a href="/commodities/">원자재</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/commodities/real-time-futures">실시간 상품</a></li>
# <li><a href="/commodities/metals">금속</a></li>
# <li><a href="/commodities/softs">농산물</a></li>
# <li><a href="/commodities/meats">육류</a></li>
# <li><a href="/commodities/energy">에너지</a></li>
# <li><a href="/commodities/grains">곡물</a></li>
# <li><a href="/indices/commodities-indices">원자재 지수</a></li> </ul>
# <ul class="popular">
# <li><a href="/commodities/gold">금</a></li>
# <li><a href="/commodities/crude-oil">WTI유</a></li>
# <li><a href="/commodities/silver">은</a></li>
# <li><a href="/commodities/natural-gas">천연가스</a></li>
# <li><a href="/commodities/copper">구리</a></li>
# <li><a href="/commodities/us-wheat">미국 소맥</a></li>
# </ul>
# </div> </li>
# <li class="row">
# <a href="/indices/">지수</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/indices/south-korea-indices">한국 지수</a></li>
# <li><a href="/indices/major-indices">세계 주요 지수</a></li>
# <li><a href="/indices/global-indices">글로벌 지표</a></li>
# <li><a href="/indices/indices-futures">지수 선물</a></li>
# <li><a href="/indices/indices-cfds">지수 CFD</a></li> </ul>
# <ul class="popular">
# <li><a href="/indices/germany-30">DAX</a></li>
# <li><a href="/indices/us-30">다우존스</a></li>
# <li><a href="/indices/us-spx-500">S&amp;P; 500</a></li>
# <li><a href="/indices/nq-100">나스닥 100</a></li>
# <li><a href="/indices/uk-100">영국 FTSE</a></li>
# <li><a href="/indices/korea-200-futures">코스피200 선물 (F)</a></li>
# <li><a href="/indices/japan-ni225">닛케이</a></li>
# <li><a href="/indices/vn">VN</a></li>
# </ul>
# </div> </li>
# <li class="row">
# <a href="/equities/">주식</a>
# <div class="navBarDropDown">
# <ul class="main">
# <li><a href="/stock-screener/">주식 종목검색기</a></li>
# <li><a href="/equities/trending-stocks">추세주</a></li>
# <li><a href="/equities/south-korea">한국</a></li>
# <li><a href="/equities/asia-pacific">아시아</a></li>
# ...
#
#
#         ga('allSitesTracker.set', 'dimension127', 0);
#     ga('require', 'displayfeatures');
#     ga('allSitesTracker.set', 'dimension73','Web');
#     ga('allSitesTracker.set', 'dimension17', getCookie('_ga').substr(6));
#     ga('allSitesTracker.set', 'dimension1', 0);
# 		ga('allSitesTracker.set', 'dimension49', '1766db1c43896dc831c38dae4f4c78fc-1625922045');
# 	ga('allSitesTracker.set', 'dimension58', '1');	ga('allSitesTracker.set', 'dimension38', '1766db1c43896dc831c38dae4f4c78fc');	ga('allSitesTracker.set', 'dimension95', '18');
#
#     	ga('set', 'dimension73','Web');
#
# 	ga('allSitesTracker.set', 'dimension106', 'No');
# 	ga('allSitesTracker.set', 'dimension54', 'No');
#
# 	var myDate = new Date();
# 	ga('allSitesTracker.set', 'dimension81',myDate.getFullYear() + '/' +('0' + (myDate.getMonth()+1)).slice(-2)+ '/' +  ('0' + (myDate.getDate()+1)).slice(-2) + ' '+('0' + (myDate.getHours()+1)).slice(-2)+ ':'+('0' + (myDate.getMinutes())).slice(-2)+ ':'+('0' + (myDate.getSeconds()+1)).slice(-2));
#
#     ga('send', 'pageview');
#     ga('allSitesTracker.set','&uid', 0);
# 	<!-- Crypto Dimension LD -->
# 	    <!--Adblock Check-->
#
# 	jQuery(document).ready(checkAds());
#
# 	function checkAds(){
#
# 		function isIE() {
# 			var ua = window.navigator.userAgent;
# 			var trident = ua.indexOf('Trident/');
# 			var edge = ua.indexOf('Edge/');
# 			var msie = ua.indexOf('MSIE ');
# 			return Math.max(msie,edge,trident)>0;
#
# 		}
#
# 		var isIE = isIE();
# 		var isChrome = /Chrome/.test(navigator.userAgent) && /Google Inc/.test(navigator.vendor) && !isIE;
# 		var isFireFox = /Firefox/.test(navigator.userAgent);
# 		var isSafari = /Safari/.test(navigator.userAgent) && /Apple Computer/.test(navigator.vendor);
# 		var isOneOfThoseBrowsers = [isIE,isChrome,isFireFox,isSafari].indexOf(true)>-1;
#
# 		var b = 2;
#
# 		//var hasAdsenseBlock = !!$('#adsense').length;
# 		//var hasShadowDom = (!!$("html")[0].shadowRoot);
# 		//var headerIsShown = ($(".midHeader").height() > 0 && $(".midHeader").css('display') !== 'none');
#
#
# 		if (window.google_ad_status == 1){
#
#     		var adbBlk = getCookie('adbBLk');
#     		if(isOneOfThoseBrowsers && adbBlk>0){
#         		ga('allSitesTracker.set', 'dimension22', '18_Blk_No');
#         		setCookie('adbBLk',18,-1000);
#     		}
#
#     	}else{
#
#     	    b = 1;
#             $('#TopTextAd').css('display','flex');
#
# 			if(isOneOfThoseBrowsers) {
# 				setCookie('adbBLk',18,1000,'/');
# 				ga('allSitesTracker.set', 'dimension21', '18_Blk_Yes');
#
# 							}
#     	}
#
# 		$.ajax({
# 		    url: "/jp.php?b="+b+"&k=Njs0ZjIwZTk1Mm40NzJkNDJrYjo3ZmAwPTsyZTFkMDw1NGZiYG5lYWM1PTIyOWU-MWM_OTJiNWVmZ2FuOzk3azYpNH0yPGViNX5uIjcmZDkyN2IkN3dgNz1uMm0xYzBtNWJmY2AvZX1jMT1pMm9lbDFnPzsyYDUxZjNhajsjNyM2cDQ_MiBlfQ==&d=1&i=1625922045&e=3667184710&lip=hk-prod-weblegacy-58d7f44ff7-qshtt&ti=1625922045",
# 		    type: 'get',
# 		    cache: false,
# 		    type: 'GET',
# 		    dataType: 'html',
# 		    success: function (data) {
# 		    	  console.log('server jp b1 hk-prod-weblegacy-58d7f44ff7-qshtt');
# 		    }
# 		});
#
#     }
#
#
# 	ga('allSitesTracker.send', 'pageview');
# 	<!--End Adblock Check-->
#
#
# </script>
# <script>
# //disabled is a temporary argument for testing purposes
# var BoxesEvents = function($,ga,disabled)
# {
# 	var e_stack = []; //each event is pushed to this stack
# 	//this objcet links urls to event types
#     var boxes = {"side_central_banks":"centralbanks","webmaster_tools":"wmt","Most_Popular_News":"mostpop","broker_promotions":"sb_promotions","marketMoversBoxWrapper":"sb_marketmovers","QBS_2_inner":"sb_indices","QBS_3_inner":"sb_commodities","QBS_1_inner":"sb_forex","QBS_4_inner":"sb_bonds","TSB_1_inner":"tsb_fx","TSB_2_inner":"tsb_commodities","TSB_3_inner":"tsb_indices","TSB_4_inner":"tsb_stocks"};
#
#     var resume_click_event = function(ev)
#     {
#     	if (ev['link']==='') {return;}
#         window.location.href = ev['link'];
#     }
#
#
# 	var register_events = function()
# 	{
# 	    for (var id in boxes)
# 	    {
# 		    (function(id){
# 			    var _$b = $('#'+id);
# 			    if (_$b.length < 1) {return;}
#
# 			    //box click event
# 			    _$b.mouseup(function(e){
# 					if (e.button === 2) {return true;} //right mouse button
# 					var middleMouse = e.button === 1;
# 				    if (!middleMouse) {e.preventDefault();}
# 				    var box_event = boxes[id];
# 				    e_stack.push({'event':box_event,'link':''});
# 				    var ce = null; //current event
# 				    //function creator
# 				    var callbackCreate = function(data) {return function() {resume_click_event(data);}}
# 		            var hitCallback = null;
#
# 				    while(ce = e_stack.pop())
# 				    {
# 						if (ce['link'].substr(0,10) === "javascript") {continue;}//if the link is javascript call ignore it
# 						hitCallback = middleMouse ? function(){} : callbackCreate(ce);
# 				    	//if a link with no event do nothing
# 					    if (ce['event'] == '') {hitCallback(); return true;}
#
# 				    					        window.ga('t0.send',{
#                             'hitType': 'event',
#                             'eventCategory': 'side-box-events',
#                             'eventAction': ce['event'],
#                             'eventValue' : 1,
#                             'hitCallback': hitCallback //resume click event
# 				            }
# 				        );
# 				        //fallback if ga doesn't work
# 				        window.setTimeout(hitCallback,1500);
# 				    }
# 				    return middleMouse;
# 			    });
#
# 			    //link event
#                 _$b.on('mouseup','a',function(e){
# 					if (e.button === 2) {return true;} //right mouse button
#                 	e.preventDefault();
# 					var url = this.getAttribute('href');
# 					var event = this.getAttribute('data-gae');
# 					e_stack.push({'event':'','link':url});
# 					if (event)
# 					{
# 						e_stack.pop();
# 						e_stack.push({'event':event,'link':url});
# 					}
# 				  });
#
# 		    })(id);
# 	    }
# 	};
#
#     var init = function()
#     {
#         if (disabled) {return;}
#         if (typeof $ !== 'function') {return;}
#         if (typeof ga !== 'function') {return;}
#         register_events();
#     }();
# }(window.jQuery,window.ga,true);
# </script>
#
# <script type="text/javascript">
# 	if(!window.googletag) {
# 		window.googletag = {cmd: []};
# 	}
# 	googletag.cmd.push(function() {  googletag.pubads().enableSingleRequest();  googletag.enableServices();
# 	            	});        if (sponsoredArticle) {
#         googletag.cmd.push(function() { googletag.display(sponsoredArticle); });
#         }
#         </script><script type="text/javascript">
# 	$(document).ready(function () {
# 	googletag.cmd.push(function() {  googletag.pubads().enableSingleRequest();  googletag.enableServices();
# 	            	});
# 		});</script> <script type="text/javascript">
#             (function () {
#             	let $ad3;
#                 $(window).on('scroll.ad3', $.throttle(function () {
#                     if (typeof(loadFooterBanner) === 'function'){
#                         loadFooterBanner();
#                         loadFooterBanner = function(){}
#                     }
#                     if (!$ad3) {
#                     	$ad3 = $('#ad3');
#                     }
#                     if (window.loadSideBlockAd3 && typeof(googletag.defineSlot) === 'function' && $.isInView($ad3, true, 20)) {
#                         window.loadSideBlockAd3();
#                         window.loadSideBlockAd3 = null;
# 						$(window).off('scroll.ad3');
#                     }
#                 }, 16))
#             })()
#         </script>
# <div class="signupWrap js-gen-popup displayNone" id="PromoteSignUpPopUp"> <div class="left">
# <ul class="textsWrap">
# <li class="title"><span>무료</span>로 등록하시고 다음 혜택을 누리세요.</li>
# <li><i class="regBellIcon"></i> <span>실시간 알림</span></li>
# <li><i class="regPortfolioIcon"></i> <span>고급 포트폴리오 기능</span></li>
# <li><i class="regChartIcon"></i> <span>맞춤형 차트</span></li>
# <li><i class="regSyncIcon"></i> <span>완벽하게 동기화된 앱</span></li>
# </ul>
# <span class="bigGraph"></span>
# </div>
# <div class="right">
# <i class="popupCloseIcon largeBannerCloser"></i>
# <div class="signingPopup">
# <div _button="fb" class="signingBtn facebookBtn">
# <span class="logo"></span>
# <span class="text">페이스북에 가입</span>
# </div>
# <div _button="go" class="signingBtn googleBtn" id="googleAuthBtn">
# <span class="logo"></span>
# <span class="text">구글에 가입</span>
# </div>
# <div class="orSeparator">
# <span>혹은</span>
# </div>
# <a _button="email" class="newBtn newButton orange" href="javascript:void(0);">이메일로 가입</a> </div>
# </div>
# </div>
# <script>
# (function(){
# 	var buttonsToGaLabelMap = {
# 		'fb': 'Continue with Facebook',
#         'go': 'Continue with Google',
#         'email': 'Sign up with Email',
#         'vk': 'Continue with VK'
#     };
#
# 	function showPromoteSignUpPopUp(className) {
# 		var isBrokerPromotionPopupVisible = $('.js-promotion-popup').is(':visible'),
#             isInBrokerPromotionPage = window.siteData.pageType.is(['chart', 'streaming-chart', 'technical']); // According to product we don't want to display this popup on pages where we might show broker promotion
#
# 		if (!(isBrokerPromotionPopupVisible || isInBrokerPromotionPage)) {
# 			setCookie('r_p_s_n', 1, 30);
# 			window.btnEventList.push('googleAuthBtn');
# 			$.getScript('https://i-invdn-com.investing.com/js/google_plus_login-1.32.min.js', function () {
# 			});
# 			if ((function (a) {
# 					if (/(android|bb\d+|meego).+mobile|avantgo|bada\/|blackberry|blazer|compal|elaine|fennec|hiptop|iemobile|ip(hone|od)|iris|kindle|lge |maemo|midp|mmp|mobile.+firefox|netfront|opera m(ob|in)i|palm( os)?|phone|p(ixi|re)\/|plucker|pocket|psp|series(4|6)0|symbian|treo|up\.(browser|link)|vodafone|wap|windows ce|xda|xiino/i.test(a) || /1207|6310|6590|3gso|4thp|50[1-6]i|770s|802s|a wa|abac|ac(er|oo|s\-)|ai(ko|rn)|al(av|ca|co)|amoi|an(ex|ny|yw)|aptu|ar(ch|go)|as(te|us)|attw|au(di|\-m|r |s )|avan|be(ck|ll|nq)|bi(lb|rd)|bl(ac|az)|br(e|v)w|bumb|bw\-(n|u)|c55\/|capi|ccwa|cdm\-|cell|chtm|cldc|cmd\-|co(mp|nd)|craw|da(it|ll|ng)|dbte|dc\-s|devi|dica|dmob|do(c|p)o|ds(12|\-d)|el(49|ai)|em(l2|ul)|er(ic|k0)|esl8|ez([4-7]0|os|wa|ze)|fetc|fly(\-|_)|g1 u|g560|gene|gf\-5|g\-mo|go(\.w|od)|gr(ad|un)|haie|hcit|hd\-(m|p|t)|hei\-|hi(pt|ta)|hp( i|ip)|hs\-c|ht(c(\-| |_|a|g|p|s|t)|tp)|hu(aw|tc)|i\-(20|go|ma)|i230|iac( |\-|\/)|ibro|idea|ig01|ikom|im1k|inno|ipaq|iris|ja(t|v)a|jbro|jemu|jigs|kddi|keji|kgt( |\/)|klon|kpt |kwc\-|kyo(c|k)|le(no|xi)|lg( g|\/(k|l|u)|50|54|\-[a-w])|libw|lynx|m1\-w|m3ga|m50\/|ma(te|ui|xo)|mc(01|21|ca)|m\-cr|me(rc|ri)|mi(o8|oa|ts)|mmef|mo(01|02|bi|de|do|t(\-| |o|v)|zz)|mt(50|p1|v )|mwbp|mywa|n10[0-2]|n20[2-3]|n30(0|2)|n50(0|2|5)|n7(0(0|1)|10)|ne((c|m)\-|on|tf|wf|wg|wt)|nok(6|i)|nzph|o2im|op(ti|wv)|oran|owg1|p800|pan(a|d|t)|pdxg|pg(13|\-([1-8]|c))|phil|pire|pl(ay|uc)|pn\-2|po(ck|rt|se)|prox|psio|pt\-g|qa\-a|qc(07|12|21|32|60|\-[2-7]|i\-)|qtek|r380|r600|raks|rim9|ro(ve|zo)|s55\/|sa(ge|ma|mm|ms|ny|va)|sc(01|h\-|oo|p\-)|sdk\/|se(c(\-|0|1)|47|mc|nd|ri)|sgh\-|shar|sie(\-|m)|sk\-0|sl(45|id)|sm(al|ar|b3|it|t5)|so(ft|ny)|sp(01|h\-|v\-|v )|sy(01|mb)|t2(18|50)|t6(00|10|18)|ta(gt|lk)|tcl\-|tdg\-|tel(i|m)|tim\-|t\-mo|to(pl|sh)|ts(70|m\-|m3|m5)|tx\-9|up(\.b|g1|si)|utst|v400|v750|veri|vi(rg|te)|vk(40|5[0-3]|\-v)|vm40|voda|vulc|vx(52|53|60|61|70|80|81|83|85|98)|w3c(\-| )|webc|whit|wi(g |nc|nw)|wmlb|wonu|x700|yas\-|your|zeto|zte\-/i.test(a.substr(0, 4))) return true; else return false;
# 				})(navigator.userAgent || navigator.vendor || window.opera)) {//disable for mobile devices
# 				return;
# 			}
#
# 			var $popUp = $('#PromoteSignUpPopUp').addClass(className);
#
# 			$popUp.find('.popupCloseIcon').click(function () {
# 				components.GeneralOverlay.hide();
# 				//ga()
# 			});
#
# 			$popUp.find('[_button]').click(function () {
# 				var button = $(this).attr('_button');
# 				overlay.authCompleteAction = {"type": 'promoteSignUpPopUp'};
# 				sendGaOnSocialButtons(button);
#
# 				switch (button) {
# 					case 'vk':
# 						overlay.vk_login();
# 						break;
# 					case 'fb':
# 						overlay.facebook_login();
# 						break;
# 					case 'email':
# 						components.GeneralOverlay.hide();
# 						overlay.overlayRegister();
# 						registrationFormJs.emailSigningUP();
# 						break;
# 				}
# 			});
#
# 			$('.generalOverlay').addClass('js-promotional');
# 			components.GeneralOverlay.show({
# 				$popup: $popUp, center: true, onHide: function () {
# 					$('.generalOverlay').removeClass('js-promotional');
# 				}
# 			});
#
# 			ga('allSitesTracker.send', 'event', 'Registration Pop Up', 'Pop Up Impression', {
# 				'metric11': 1,
#                 'nonInteraction': true
# 			});
# 		}
# 	}
#
# 	function sendGaOnSocialButtons(button) {
# 		buttonsToGaLabelMap[button] && window.ga && window.ga('allSitesTracker.send', 'event', 'Registration Pop Up', 'Clicks on Registration CTAs', buttonsToGaLabelMap[button]);
# 	}
#
#     $(window).on('mouseleave', function(e) {
#         var $signinPopup = $('.signingPopup'),
#             y = e.pageY - $(document).scrollTop();
#             if ( !$signinPopup.is(':visible')
#                 &&
#                 (((y - 10) < 1 || y >= $(window).height())
#                 ||
#                 (e.pageX < 1 || e.pageX >= $(window).width()))
#             ) {
#                 $(window).off('mouseleave');
#                 showPromoteSignUpPopUp('dark_graph');
#             }
#     });
# })()
# </script>
# <script type="text/javascript">(function(){window['__CF$cv$params']={r:'66c9fa0dfe0a12ea',m:'8e68400825350ce80310aab224df02f72f5b3999-1625922045-1800-AQkYSV/aGIBt8zxcVbJiLdbvhykqXQ5ce6Ju9slGil4+j8D+d5tRY7tKj1T7Gv6WbLz6XScbf/fKOduNd/rEMmdtwhVN6FHhFI8SHDG8xJpwOVqv0DlXGh5eV8fIG7FXQKexbCv4/VmqnfO7f8GQ1pM=',s:[0x967054d224,0x220ef2c964],}})();</script><script data-cf-beacon='{"rayId":"66c9fa0dfe0a12ea","token":"00ab903b5e184b1a9d53b0a7a5085300","version":"2021.6.0","si":10}' defer="" src="https://static.cloudflareinsights.com/beacon.min.js"></script>
#
# <img height="1" src="https://secure.adnxs.com/seg?t=2&amp;add=19833489" width="1">
# <script>var TimeZoneID = +"88";window.timezoneOffset = +"32400";window.stream = "https://stream33.forexpros.com:443";</script><script>window.uid = 0</script><script>
#
# 			$(function(){
# 				$(window).trigger("socketRetry",[["pid-37426:","pid-8987:","pid-8839:","pid-8874:","pid-172:","pid-178:","pid-8827:","isOpenExch-60:","isOpenExch-4:","isOpenExch-20:","isOpenPair-8987:","isOpenPair-8839:","isOpenPair-8874:","isOpenPair-8827:","domain-18:"]]);
# 			});
# 			</script><script>function refresher() { void (0);}</script><script>
#     	var _comscore = _comscore || [];
#     	_comscore.push(
#     	{ c1: "2", c2: "16896267" }
#
#     	);
#     	(function()
#     	{ var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); }
#
#     	)();
#     	</script> <script type="text/javascript">
#                 var google_conversion_id = 1000940071;
#                 var google_custom_params = window.google_tag_params;
#                 var google_remarketing_only = true;
#             </script><script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript"></script>
# <noscript><div style="display:inline;"><img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1000940071/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/></div></noscript>
# <script>
# 		!function(f,b,e,v,n,t,s)
# 		{if(f.fbq)return;n=f.fbq=function()
# 		{n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)};
# 		if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
# 		n.queue=[];t=b.createElement(e);t.async=!0;
# 		t.src=v;s=b.getElementsByTagName(e)[0];
# 		s.parentNode.insertBefore(t,s)}(window, document,'script',
# 		'https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '751110881643258');
# 		fbq('track', 'PageView');
# 	</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=751110881643258&amp;ev=PageView&amp;noscript=1" style="display:none" width="1">
# </img></noscript>
# <script type="text/javascript">
#         fbq = window.fbq || $.noop;
#     </script>
# </img>

# %%
item_list = soup.select('.largeTitle > article')
item_list
# Out:
# [<article class="js-article-item articleItem " data-id="664000">
#  <a class="img" href="/news/cryptocurrency-news/article-664000"><img alt="EOS 가격이 21% 급등" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED990HX_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-664000" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 12 시간 전</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 토요일 09:12 (00:12 GMT)에 21.19% 급등하여 4.3537에 거...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="663967">
#  <a class="img" href="/news/cryptocurrency-news/article-663967"><img alt="EOS 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED9A0RJ-ORUBS_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-663967" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 23 시간 전</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 금요일 22:30 (13:30 GMT)에 10.08% 상승하여 3.9566에 거...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="663661">
#  <a class="img" href="/news/stock-market-news/article-663661"><img alt="가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEE890EH_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/stock-market-news/article-663661" title="가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나">가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나</a>
#  <span class="articleDetails"><span>부터 인포스탁데일리</span><span class="date"> - 2021년 07월 09일</span></span> <p>이 시각 현재 글로벌 가상화폐 시황. (제공: 코인마켓캡)
#  [인포스탁데일리=윤서연 기자] 비트코인을 비롯한 대부분의 가상화폐가 급락하고 있다. 전 세계적으로 델타...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem sponsoredArticle ">
#  <a class="img" href="/jp.php?v2=YyM0amM0ZD5mMjkwN200NDdkZD8yMTcwMSZnNTA6ZC1iJD43NW00cjY-bnBlOTFrN0QwbzM7YXczZWY0M3JjIGMkNGpjM2Q6ZjI5NzdyNHU3a2Q8MjU3NDEmZyQwOg=="><img class="lazyload" data-src="https://i-invdn-com.investing.com/news/8694974853_S.png"/></a> <div class="textDiv">
#  <span class="sponsoredBadge arial_11" data-sponsored="파트너 뉴스"></span>
#  <a class="title" href="/jp.php?v2=YyM0amM0ZD5mMjkwN200NDdkZD8yMTcwMSZnNTA6ZC1iJD43NW00cjY-bnBlOTFrN0QwbzM7YXczZWY0M3JjIGMkNGpjM2Q6ZjI5NzdyNHU3a2Q8MjU3NDEmZyQwOg==" title="키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행">키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행</a>
#  <span class="articleDetails"><span>부터 <a href="/education-providers/investing.com-studios">Investing.com Studios</a></span></span> <p>키움증권(대표이사 이현)은 6월 14일부터 8월 6일까지 해외선물옵션 신규/휴면 고객을 대상으로 최대 200만원을 증정하는 첫 거래 이벤트를 진행한다고 밝혔다.</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="663607">
#  <a class="img" href="/news/cryptocurrency-news/article-663607"><img alt="'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEE890EH_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-663607" title="'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]">'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]</a>
#  <span class="articleDetails"><span>부터 Hankyung</span><span class="date"> - 2021년 07월 09일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/cryptocurrency-news/article-663607#comments"><i class="commentIcon"></i>8</a>
#  </span> <p>사진=게티이미지뱅크
#  가상자산(암호화폐) 시장이 약세를 보이고 있다. 최근 전 세계에서 신종 코로나바이러스 감염증(코로나19) 델타 변이 확산세가 부각되면서 글로벌...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-external-link-wrapper articleItem" data-content-type="news" data-id="663647" data-link="https://invst.ly/vdj49" data-provider-name="중앙일보 | 경제">
#  <a class="js-external-link img" href="https://invst.ly/vdj49" rel="nofollow" target="_blank">
#  <img alt="델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDAC13D_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png'">
#  </img></a>
#  <div class="textDiv">
#  <a class="js-external-link title" href="https://invst.ly/vdj49" rel="nofollow" target="_blank" title="델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락">델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락</a>
#  <div class="articleDetails"><span>부터 중앙일보 | 경제</span><span class="date"> - 2021년 07월 09일</span></div>
#  <p>전 세계에 퍼진 신종 코로나바이러스 감염증(코로나19) 델타 변이의 공포가 암호화폐 시장에도 번졌다. 9일 암호화폐 시황 중계사이트 코인마켓캡에 따르면 10시 3...</p>
#  </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="663385">
#  <a class="img" href="/news/cryptocurrency-news/article-663385"><img alt="이더리움 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEB3E0UM_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-663385" title="이더리움 가격이 10% 하락">이더리움 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 07월 08일</span></span> <p>Investing.com - 이더리움 가격이 Investing.com Index에서 목요일 20:04 (11:04 GMT)에 10.03% 하락하여 2,134.58...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="662223">
#  <a class="img" href="/news/cryptocurrency-news/article-662223"><img alt="비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEE211WU_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-662223" title="비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향">비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향</a>
#  <span class="articleDetails"><span>부터 인포스탁데일리</span><span class="date"> - 2021년 07월 07일</span></span> <p>현재 시각 주요 암호화폐 시황. 제공=코인마켓캡
#  [인포스탁데일리=윤서연 기자] 중국 베이징 당국의 암호화폐 단속 소식이 전해지자 비트코인이 소폭 하락하는 등 대부...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="660800">
#  <a class="img" href="/news/cryptocurrency-news/article-660800"><img alt="프리톤이 자체 디파이 생태계 개발에 나선다" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDA71MJ_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-660800" title="프리톤이 자체 디파이 생태계 개발에 나선다">프리톤이 자체 디파이 생태계 개발에 나선다</a>
#  <span class="articleDetails"><span>부터 CoinTelegraph</span><span class="date"> - 2021년 07월 05일</span></span> <p>텔레그램의 자체 블록체인 프로젝트 톤을 전신으로 탄생한 프리톤이 디파이 생태계 개발 속도를 높인다.
#  5일 프리톤은 모든 이용자들이 탈중앙금융(De-Fi, 디파이)...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="660566">
#  <a class="img" href="/news/cryptocurrency-news/article-660566"><img alt="'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/south_korea_150x108_S_1416304730.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-660566" title="'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락">'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락</a>
#  <span class="articleDetails"><span>부터 인포스탁데일리</span><span class="date"> - 2021년 07월 05일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/cryptocurrency-news/article-660566#comments"><i class="commentIcon"></i>20</a>
#  </span> <p>김정주 NXC 대표 [사진=넥슨]
#  [인포스탁데일리=박상인 기자] 김정주 회장 부부가 다수 지분을 보유하고 있는 NXC의 자회사인 넥슨(넥슨 일본법인)이 비트코인에...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="660339">
#  <a class="img" href="/news/cryptocurrency-news/article-660339"><img alt="카르다노 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED703B3_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-660339" title="카르다노 가격이 10% 상승">카르다노 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 07월 03일</span></span> <p>Investing.com - 카르다노 가격이 Investing.com Index에서 토요일 18:40 (09:40 GMT)에 10.23% 상승하여 1.431014...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="660245">
#  <a class="img" href="/news/economy/article-660245"><img 3만="" [코인="" alt="美 월가 투자 전문가들 " class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEB8R0JA_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';" 달러보다="" 비트코인="" 시세]"="" 아래"="" 연말=""/></a> <div class="textDiv">
#  <a 3만="" [코인="" class="title" href="/news/economy/article-660245" title="美 월가 투자 전문가들 " 달러보다="" 비트코인="" 시세]"="" 아래"="" 연말="">美 월가 투자 전문가들 "연말 비트코인 3만 달러보다 아래" [코인 시세]</a>
#  <span class="articleDetails"><span>부터 Hankyung</span><span class="date"> - 2021년 07월 02일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/economy/article-660245#comments"><i class="commentIcon"></i>11</a>
#  </span> <p>사진=REUTERS
#  전반적인 가상자산(암호화폐) 시장이 약세를 보이는 가운데 다수의 투자 전문가가 올해 안에 비트코인(BTC)이 반등하지 못할 것으로 전망했다.
#  ...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="658863">
#  <a class="img" href="/news/cryptocurrency-news/article-658863"><img alt="프리톤 " class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED6U1NX_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';" 스테이블코인으로="" 이더리움="" 자체="" 해결""="" 확장성=""/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-658863" title="프리톤 " 스테이블코인으로="" 이더리움="" 자체="" 해결""="" 확장성="">프리톤 "자체 스테이블코인으로 이더리움 확장성 해결"</a>
#  <span class="articleDetails"><span>부터 CoinTelegraph</span><span class="date"> - 2021년 06월 30일</span></span> <p>프리톤이 다양한 활용이 가능한 자체 스테이블코인을 발행한다.
#  30일 프리톤은 올 여름 이더리움의 확장성을 해결할 수 있는 자체 스테이블코인(가치안정화폐)을 발행한...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="658862">
#  <a class="img" href="/news/cryptocurrency-news/article-658862"><img alt="메타히어로, 3D 스캐닝으로 NFT 아바타 만든다" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC410B3_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-658862" title="메타히어로, 3D 스캐닝으로 NFT 아바타 만든다">메타히어로, 3D 스캐닝으로 NFT 아바타 만든다</a>
#  <span class="articleDetails"><span>부터 CoinTelegraph</span><span class="date"> - 2021년 06월 30일</span></span> <p>초고화질(UHD) 3차원(3D) 스캐닝 기술에 블록체인을 접목한 사업을 전개하는 메타히어로는 울프스튜디오와 파트너십을 맺고 자체 유틸리티토큰을 프리세일로 선보였다...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="658500">
#  <a class="img" href="/news/stock-market-news/article-658500"><img alt="비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEE0F1MP_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/stock-market-news/article-658500" title="비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파">비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파</a>
#  <span class="articleDetails"><span>부터 인포스탁데일리</span><span class="date"> - 2021년 06월 30일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/stock-market-news/article-658500#comments"><i class="commentIcon"></i>1</a>
#  </span> <p>비트코인 연출 이미지. 사진= 픽사베이
#  [인포스탁데일리=윤서연 기자] 비트코인이 3만 6000달러를 돌파하면서 이틀 연속 상승세를 이어가고 있다. 저항선으로 여겨...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="658149">
#  <a class="img" href="/news/cryptocurrency-news/article-658149"><img alt="이더리움 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC6413U_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-658149" title="이더리움 가격이 10% 상승">이더리움 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 29일</span></span> <p>Investing.com - 이더리움 가격이 Investing.com Index에서 화요일 22:30 (13:30 GMT)에 10.08% 상승하여 2,211.87...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="658118">
#  <a class="img" href="/news/cryptocurrency-news/article-658118"><img alt="XRP 가격이 11% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPED831IK_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-658118" title="XRP 가격이 11% 상승">XRP 가격이 11% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 29일</span></span> <p>Investing.com - XRP 가격이 Investing.com Index에서 화요일 20:51 (11:51 GMT)에 10.50% 상승하여 0.69284에 ...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="658056">
#  <a class="img" href="/news/cryptocurrency-news/article-658056"><img alt="프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDA71MJ_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-658056" title="프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다">프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다</a>
#  <span class="articleDetails"><span>부터 CoinTelegraph</span><span class="date"> - 2021년 06월 29일</span></span> <p>텔레그램의 자체 블록체인인 톤을 전신으로 탄생한 프리톤이 이더리움의 확장성을 개선해 탈중앙금융(De-Fi, 디파이) 시장을 확대하기 위한 시도에 나섰다.
#  29일...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="657488">
#  <a class="img" href="/news/cryptocurrency-news/article-657488"><img alt="라이트코인 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEB701AO_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-657488" title="라이트코인 가격이 10% 상승">라이트코인 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 29일</span></span> <p>Investing.com - 라이트코인 가격이 Investing.com Index에서 월요일 06:23 (21:23 GMT)에 10.02% 상승하여 137.969...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="657454">
#  <a class="img" href="/news/cryptocurrency-news/article-657454"><img alt="EOS 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDAE0PJ-ORUBS_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-657454" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 29일</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 월요일 01:26 (16:26 GMT)에 10.02% 상승하여 3.8970에 거...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="657278">
#  <a class="img" href="/news/cryptocurrency-news/article-657278"><img alt="이더리움 가격이 11% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDAE0PJ-ORUBS_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-657278" title="이더리움 가격이 11% 상승">이더리움 가격이 11% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 28일</span></span> <p>Investing.com - 이더리움 가격이 Investing.com Index에서 월요일 17:16 (08:16 GMT)에 10.60% 상승하여 2,065.83...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656514">
#  <a class="img" href="/news/cryptocurrency-news/article-656514"><img alt="라이트코인 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED09124_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656514" title="라이트코인 가격이 10% 하락">라이트코인 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 26일</span></span> <p>Investing.com - 라이트코인 가격이 Investing.com Index에서 토요일 17:56 (08:56 GMT)에 10.21% 하락하여 118.782...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656510">
#  <a class="img" href="/news/cryptocurrency-news/article-656510"><img alt="비트코인 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED09124_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656510" title="비트코인 가격이 10% 하락">비트코인 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 26일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/cryptocurrency-news/article-656510#comments"><i class="commentIcon"></i>4</a>
#  </span> <p>Investing.com - 비트코인 가격이 Investing.com Index에서 토요일 16:38 (07:38 GMT)에 10.35% 하락하여 30,884.1...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656494">
#  <a class="img" href="/news/cryptocurrency-news/article-656494"><img alt="EOS 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEBBM0M5_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656494" title="EOS 가격이 10% 하락">EOS 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 26일</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 토요일 09:02 (00:02 GMT)에 10.29% 하락하여 3.5159에 거...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656475">
#  <a class="img" href="/news/cryptocurrency-news/article-656475"><img alt="카르다노 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC410B3_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656475" title="카르다노 가격이 10% 하락">카르다노 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 26일</span></span> <p>Investing.com - 카르다노 가격이 Investing.com Index에서 금요일 01:38 (16:38 GMT)에 10.07% 하락하여 1.248891...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656472">
#  <a class="img" href="/news/cryptocurrency-news/article-656472"><img alt="이더리움 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED6U1NX_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656472" title="이더리움 가격이 10% 하락">이더리움 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 26일</span></span> <p>Investing.com - 이더리움 가격이 Investing.com Index에서 금요일 01:26 (16:26 GMT)에 10.44% 하락하여 1,801.77...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656471">
#  <a class="img" href="/news/cryptocurrency-news/article-656471"><img alt="XRP 가격이 10% 하락" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED09124_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656471" title="XRP 가격이 10% 하락">XRP 가격이 10% 하락</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 26일</span></span> <p>Investing.com - XRP 가격이 Investing.com Index에서 금요일 01:22 (16:22 GMT)에 10.08% 하락하여 0.61025에 ...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656281">
#  <a class="img" href="/news/cryptocurrency-news/article-656281"><img alt="비트코인 역대급 악재 터지나" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEE0H04E_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656281" title="비트코인 역대급 악재 터지나">비트코인 역대급 악재 터지나</a>
#  <span class="articleDetails"><span>부터 Economic Review</span><span class="date"> - 2021년 06월 25일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/cryptocurrency-news/article-656281#comments"><i class="commentIcon"></i>77</a>
#  </span> <p>[이코노믹리뷰=최진홍 기자] 비트코인 등 암호화폐 시장의 불확실성이 심해지면서 ‘매물폭탄’ 경고까지 나왔다.
#  최근 비트코인 시세는 중국발 악재로 휘청였으나 엘살바...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656252">
#  <a class="img" href="/news/cryptocurrency-news/article-656252"><img alt="프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC410B3_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656252" title="프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다">프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다</a>
#  <span class="articleDetails"><span>부터 CoinTelegraph</span><span class="date"> - 2021년 06월 25일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/cryptocurrency-news/article-656252#comments"><i class="commentIcon"></i>1</a>
#  </span> <p>메신저 앱 텔레그램의 블록체인 프로젝트인 톤(TON)을 기반으로 새롭게 탄생한 커뮤니티 중심의 프리톤(Free TON)이 탈중앙금융(De-Fi, 디파이) 시장 진...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="656113">
#  <a class="img" href="/news/cryptocurrency-news/article-656113"><img alt="라이트코인 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDA611J_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-656113" title="라이트코인 가격이 10% 상승">라이트코인 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 25일</span></span> <p>Investing.com - 라이트코인 가격이 Investing.com Index에서 금요일 11:16 (02:16 GMT)에 10.24% 상승하여 137.569...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="655912">
#  <a class="img" href="/news/cryptocurrency-news/article-655912"><img alt="비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEE890EH_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-655912" title="비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]">비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]</a>
#  <span class="articleDetails"><span>부터 Hankyung</span><span class="date"> - 2021년 06월 25일</span>
#  <a class="js-scrollto-comment commentsBubbleCnt" href="/news/cryptocurrency-news/article-655912#comments"><i class="commentIcon"></i>3</a>
#  </span> <p>사진=게티이미지뱅크
#  가상자산(암호화폐) 시장이 강세를 보이고 있다. 최근 가상자산 가격이 빠르게 하락하면서 저가 매수세가 이어진 영향으로 풀이된다.
#  25일 오전 ...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="655869">
#  <a class="img" href="/news/cryptocurrency-news/article-655869"><img alt="EOS 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPED8B0RG_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-655869" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 25일</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 목요일 05:03 (20:03 GMT)에 10.06% 상승하여 3.8861에 거...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="655847">
#  <a class="img" href="/news/cryptocurrency-news/article-655847"><img alt="XRP 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED09124_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-655847" title="XRP 가격이 10% 상승">XRP 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 25일</span></span> <p>Investing.com - XRP 가격이 Investing.com Index에서 목요일 02:08 (17:08 GMT)에 10.04% 상승하여 0.68891에 ...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="655836">
#  <a class="img" href="/news/cryptocurrency-news/article-655836"><img alt="카르다노 가격이 10% 상승" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPEDAC13D_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-655836" title="카르다노 가격이 10% 상승">카르다노 가격이 10% 상승</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 25일</span></span> <p>Investing.com - 카르다노 가격이 Investing.com Index에서 목요일 00:18 (15:18 GMT)에 10.43% 상승하여 1.364836...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="655069">
#  <a class="img" href="/news/cryptocurrency-news/article-655069"><img alt="라이트코인 가격이 24% 급등" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXNPEC410B3_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-655069" title="라이트코인 가격이 24% 급등">라이트코인 가격이 24% 급등</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 23일</span></span> <p>Investing.com - 라이트코인 가격이 Investing.com Index에서 수요일 22:24 (13:24 GMT)에 24.45% 급등하여 133.480...</p> </div>
#  <div class="clear"></div>
#  </article>,
#  <article class="js-article-item articleItem " data-id="655068">
#  <a class="img" href="/news/cryptocurrency-news/article-655068"><img alt="EOS 가격이 21% 급등" class="lazyload" data-src="https://i-invdn-com.investing.com/news/bitcoin_150x108_S_1416307016.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
#  <a class="title" href="/news/cryptocurrency-news/article-655068" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>
#  <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 2021년 06월 23일</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 수요일 22:13 (13:13 GMT)에 21.13% 급등하여 3.7695에 거...</p> </div>
#  <div class="clear"></div>
#  </article>]

# %%
item_list[0]
# Out:
# <article class="js-article-item articleItem " data-id="664000">
# <a class="img" href="/news/cryptocurrency-news/article-664000"><img alt="EOS 가격이 21% 급등" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED990HX_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
# <a class="title" href="/news/cryptocurrency-news/article-664000" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>
# <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 12 시간 전</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 토요일 09:12 (00:12 GMT)에 21.19% 급등하여 4.3537에 거...</p> </div>
# <div class="clear"></div>
# </article>

# %% [markdown]
# ### 기사 제목

# %%
item_list[0].select('.title')[0].get_text().strip()
# Out:
# 'EOS 가격이 21% 급등'

# %%
title = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > a')
title
# Out:
# [<a class="title" href="/news/cryptocurrency-news/article-664000" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-663967" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>,
#  <a class="title" href="/news/stock-market-news/article-663661" title="가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나">가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나</a>,
#  <a class="title" href="/jp.php?v2=YyM0amM0ZD5mMjkwN200NDdkZD8yMTcwMSZnNTA6ZC1iJD43NW00cjY-bnBlOTFrN0QwbzM7YXczZWY0M3JjIGMkNGpjM2Q6ZjI5NzdyNHU3a2Q8MjU3NDEmZyQwOg==" title="키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행">키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-663607" title="'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]">'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]</a>,
#  <a class="js-external-link title" href="https://invst.ly/vdj49" rel="nofollow" target="_blank" title="델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락">델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-663385" title="이더리움 가격이 10% 하락">이더리움 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-662223" title="비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향">비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-660800" title="프리톤이 자체 디파이 생태계 개발에 나선다">프리톤이 자체 디파이 생태계 개발에 나선다</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-660566" title="'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락">'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-660339" title="카르다노 가격이 10% 상승">카르다노 가격이 10% 상승</a>,
#  <a 3만="" [코인="" class="title" href="/news/economy/article-660245" title="美 월가 투자 전문가들 " 달러보다="" 비트코인="" 시세]"="" 아래"="" 연말="">美 월가 투자 전문가들 "연말 비트코인 3만 달러보다 아래" [코인 시세]</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658863" title="프리톤 " 스테이블코인으로="" 이더리움="" 자체="" 해결""="" 확장성="">프리톤 "자체 스테이블코인으로 이더리움 확장성 해결"</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658862" title="메타히어로, 3D 스캐닝으로 NFT 아바타 만든다">메타히어로, 3D 스캐닝으로 NFT 아바타 만든다</a>,
#  <a class="title" href="/news/stock-market-news/article-658500" title="비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파">비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658149" title="이더리움 가격이 10% 상승">이더리움 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658118" title="XRP 가격이 11% 상승">XRP 가격이 11% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658056" title="프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다">프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-657488" title="라이트코인 가격이 10% 상승">라이트코인 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-657454" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-657278" title="이더리움 가격이 11% 상승">이더리움 가격이 11% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656514" title="라이트코인 가격이 10% 하락">라이트코인 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656510" title="비트코인 가격이 10% 하락">비트코인 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656494" title="EOS 가격이 10% 하락">EOS 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656475" title="카르다노 가격이 10% 하락">카르다노 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656472" title="이더리움 가격이 10% 하락">이더리움 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656471" title="XRP 가격이 10% 하락">XRP 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656281" title="비트코인 역대급 악재 터지나">비트코인 역대급 악재 터지나</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656252" title="프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다">프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656113" title="라이트코인 가격이 10% 상승">라이트코인 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655912" title="비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]">비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655869" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655847" title="XRP 가격이 10% 상승">XRP 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655836" title="카르다노 가격이 10% 상승">카르다노 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655069" title="라이트코인 가격이 24% 급등">라이트코인 가격이 24% 급등</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655068" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>]

# %% [markdown]
# ### 작성 일자 가져오기

# %%
item_list[0].select('.date')[0].get_text().strip().replace('-\xa0', '')
# Out:
# '12 시간 전'

# %%
date = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > span > span.date')
date
# Out:
# [<span class="date"> - 12 시간 전</span>,
#  <span class="date"> - 23 시간 전</span>,
#  <span class="date"> - 2021년 07월 09일</span>,
#  <span class="date"> - 2021년 07월 09일</span>,
#  <span class="date"> - 2021년 07월 08일</span>,
#  <span class="date"> - 2021년 07월 07일</span>,
#  <span class="date"> - 2021년 07월 05일</span>,
#  <span class="date"> - 2021년 07월 05일</span>,
#  <span class="date"> - 2021년 07월 03일</span>,
#  <span class="date"> - 2021년 07월 02일</span>,
#  <span class="date"> - 2021년 06월 30일</span>,
#  <span class="date"> - 2021년 06월 30일</span>,
#  <span class="date"> - 2021년 06월 30일</span>,
#  <span class="date"> - 2021년 06월 29일</span>,
#  <span class="date"> - 2021년 06월 29일</span>,
#  <span class="date"> - 2021년 06월 29일</span>,
#  <span class="date"> - 2021년 06월 29일</span>,
#  <span class="date"> - 2021년 06월 29일</span>,
#  <span class="date"> - 2021년 06월 28일</span>,
#  <span class="date"> - 2021년 06월 26일</span>,
#  <span class="date"> - 2021년 06월 26일</span>,
#  <span class="date"> - 2021년 06월 26일</span>,
#  <span class="date"> - 2021년 06월 26일</span>,
#  <span class="date"> - 2021년 06월 26일</span>,
#  <span class="date"> - 2021년 06월 26일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 25일</span>,
#  <span class="date"> - 2021년 06월 23일</span>,
#  <span class="date"> - 2021년 06월 23일</span>]

# %% [markdown]
# ### URL 가져오기

# %%
item_list[0]
# Out:
# <article class="js-article-item articleItem " data-id="664000">
# <a class="img" href="/news/cryptocurrency-news/article-664000"><img alt="EOS 가격이 21% 급등" class="lazyload" data-src="https://i-invdn-com.investing.com/news/LYNXMPED990HX_S.jpg" onerror="javascript:this.src='https://i-invdn-com.investing.com/news/news-paper_108x81.png';"/></a> <div class="textDiv">
# <a class="title" href="/news/cryptocurrency-news/article-664000" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>
# <span class="articleDetails"><span>부터 Investing.com</span><span class="date"> - 12 시간 전</span></span> <p>Investing.com - EOS 가격이 Investing.com Index에서 토요일 09:12 (00:12 GMT)에 21.19% 급등하여 4.3537에 거...</p> </div>
# <div class="clear"></div>
# </article>

# %%
item_list[0].select('a')[0].attrs['href'].strip()
# Out:
# '/news/cryptocurrency-news/article-664000'

# %%
uri = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > a')
uri
# Out:
# [<a class="title" href="/news/cryptocurrency-news/article-664000" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-663967" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>,
#  <a class="title" href="/news/stock-market-news/article-663661" title="가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나">가상화폐, 대부분 하락…제2의 ‘크립토 윈터’ 다시오나</a>,
#  <a class="title" href="/jp.php?v2=YyM0amM0ZD5mMjkwN200NDdkZD8yMTcwMSZnNTA6ZC1iJD43NW00cjY-bnBlOTFrN0QwbzM7YXczZWY0M3JjIGMkNGpjM2Q6ZjI5NzdyNHU3a2Q8MjU3NDEmZyQwOg==" title="키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행">키움증권, ‘해외선물옵션 첫 거래 이벤트’ 진행</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-663607" title="'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]">'델타 변이' 공포 시장 덮쳤다…비트코인 3800만원대로↓ [코인 시세]</a>,
#  <a class="js-external-link title" href="https://invst.ly/vdj49" rel="nofollow" target="_blank" title="델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락">델타 공포 덮쳤다…코스피 3200선 붕괴, 이더리움 10% 급락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-663385" title="이더리움 가격이 10% 하락">이더리움 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-662223" title="비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향">비트코인, 3900만원대로 소폭하락…베이징 암호화폐 단속 영향</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-660800" title="프리톤이 자체 디파이 생태계 개발에 나선다">프리톤이 자체 디파이 생태계 개발에 나선다</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-660566" title="'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락">'마이너스의 손' 김정주, 비트코인 458억원 손실...넥슨 주가 30% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-660339" title="카르다노 가격이 10% 상승">카르다노 가격이 10% 상승</a>,
#  <a 3만="" [코인="" class="title" href="/news/economy/article-660245" title="美 월가 투자 전문가들 " 달러보다="" 비트코인="" 시세]"="" 아래"="" 연말="">美 월가 투자 전문가들 "연말 비트코인 3만 달러보다 아래" [코인 시세]</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658863" title="프리톤 " 스테이블코인으로="" 이더리움="" 자체="" 해결""="" 확장성="">프리톤 "자체 스테이블코인으로 이더리움 확장성 해결"</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658862" title="메타히어로, 3D 스캐닝으로 NFT 아바타 만든다">메타히어로, 3D 스캐닝으로 NFT 아바타 만든다</a>,
#  <a class="title" href="/news/stock-market-news/article-658500" title="비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파">비트코인 연이틀 상승세…3만 6000달러 ‘저항선’ 돌파</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658149" title="이더리움 가격이 10% 상승">이더리움 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658118" title="XRP 가격이 11% 상승">XRP 가격이 11% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-658056" title="프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다">프리톤이 브리지 토큰으로 자체 디파이 생태계 확장에 나선다</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-657488" title="라이트코인 가격이 10% 상승">라이트코인 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-657454" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-657278" title="이더리움 가격이 11% 상승">이더리움 가격이 11% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656514" title="라이트코인 가격이 10% 하락">라이트코인 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656510" title="비트코인 가격이 10% 하락">비트코인 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656494" title="EOS 가격이 10% 하락">EOS 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656475" title="카르다노 가격이 10% 하락">카르다노 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656472" title="이더리움 가격이 10% 하락">이더리움 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656471" title="XRP 가격이 10% 하락">XRP 가격이 10% 하락</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656281" title="비트코인 역대급 악재 터지나">비트코인 역대급 악재 터지나</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656252" title="프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다">프리톤, 이더리움 대적할 새로운 디파이 생태계 만든다</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-656113" title="라이트코인 가격이 10% 상승">라이트코인 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655912" title="비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]">비트코인 4000만원대 재돌파…도지코인도 8% 급등 [코인 시세]</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655869" title="EOS 가격이 10% 상승">EOS 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655847" title="XRP 가격이 10% 상승">XRP 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655836" title="카르다노 가격이 10% 상승">카르다노 가격이 10% 상승</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655069" title="라이트코인 가격이 24% 급등">라이트코인 가격이 24% 급등</a>,
#  <a class="title" href="/news/cryptocurrency-news/article-655068" title="EOS 가격이 21% 급등">EOS 가격이 21% 급등</a>]

# %% [markdown]
# ### Summary 가져오기

# %%
item_list[0].select('p')[0].text.strip()
# Out:
# 'Investing.com - EOS 가격이 Investing.com Index에서 토요일 09:12 (00:12 GMT)에 21.19% 급등하여 4.3537에 거...'

# %%
summary = soup.select ('#leftColumn > div.largeTitle > article> div.textDiv > p')
summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-0c9752993f3f> in <module>
# ----> 1 summary = soup.select ('#leftColumn > div.largeTitle > article> div.textDiv > p')
#       2 summary
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, _candidate_generator, limit)
#    1530                     print("    Running candidate generator on %s %s" % (
#    1531                         tag.name, repr(tag.attrs)))
# -> 1532                 for candidate in _use_candidate_generator(tag):
#    1533                     if not isinstance(candidate, Tag):
#    1534                         continue
#
# ~\anaconda3\lib\site-packages\bs4\element.py in recursive_select(tag)
#    1491                         print('    Calling select("%s") recursively on %s %s' % (next_token, tag.name, tag.attrs))
#    1492                         print('-' * 40)
# -> 1493                     for i in tag.select(next_token, recursive_candidate_generator):
#    1494                         if self._select_debug:
#    1495                             print('(Recursive select picked up candidate %s %s)' % (i.name, i.attrs))
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, _candidate_generator, limit)
#    1475             else:
#    1476                 raise ValueError(
# -> 1477                     'Unsupported or invalid CSS selector: "%s"' % token)
#    1478             if recursive_candidate_generator:
#    1479                 # This happens when the selector looks like  "> foo".
#
# ValueError: Unsupported or invalid CSS selector: "article>"

# %% [markdown]
# ### result에 Data 담기

# %%
result = []
title = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > a')
date = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > span > span.date')
uri = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > a')
summary = soup.select ('#leftColumn > div.largeTitle > article> div.textDiv > p')
for i in zip(title, date, uri, summary):
    result.append(
        {
            'title': i[0].text,
            'date': i[1].get_text().strip().replace('-\xa0', ''),
            'url': base_url + i[2].attrs['href'],
            'summary': i[3].text.strip()
        }
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-c6546fc066d8> in <module>
#       3 date = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > span > span.date')
#       4 uri = soup.select('#leftColumn > div.largeTitle > article > div.textDiv > a')
# ----> 5 summary = soup.select ('#leftColumn > div.largeTitle > article> div.textDiv > p')
#       6 for i in zip(title, date, uri, summary):
#       7     result.append(
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, _candidate_generator, limit)
#    1530                     print("    Running candidate generator on %s %s" % (
#    1531                         tag.name, repr(tag.attrs)))
# -> 1532                 for candidate in _use_candidate_generator(tag):
#    1533                     if not isinstance(candidate, Tag):
#    1534                         continue
#
# ~\anaconda3\lib\site-packages\bs4\element.py in recursive_select(tag)
#    1491                         print('    Calling select("%s") recursively on %s %s' % (next_token, tag.name, tag.attrs))
#    1492                         print('-' * 40)
# -> 1493                     for i in tag.select(next_token, recursive_candidate_generator):
#    1494                         if self._select_debug:
#    1495                             print('(Recursive select picked up candidate %s %s)' % (i.name, i.attrs))
#
# ~\anaconda3\lib\site-packages\bs4\element.py in select(self, selector, _candidate_generator, limit)
#    1475             else:
#    1476                 raise ValueError(
# -> 1477                     'Unsupported or invalid CSS selector: "%s"' % token)
#    1478             if recursive_candidate_generator:
#    1479                 # This happens when the selector looks like  "> foo".
#
# ValueError: Unsupported or invalid CSS selector: "article>"

# %%
result
# Out:
# []

# %%
df = pd.DataFrame(result)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_excel('inveting_news.xlsx', index=False)
